# %%
from langchain_naver import ChatClovaX
from typing import List, Dict
from langchain_core.documents import Document
import json

# %%
def load_documents_from_jsonl(file_path: str) -> List[Document]:
    """JSONL 파일에서 Document 로드"""
    documents = []
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            if not line.strip():
                continue
            data = json.loads(line)
            doc = Document(
                page_content=data["page_content"],
                metadata=data["metadata"],
                id=data["id"]
            )
            documents.append(doc)
    return documents

# %%
documents = load_documents_from_jsonl("documents.jsonl")
documents
# Out:
# [Document(id='2019610_clause_1', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}, 'links': [{'자연재해대책법': ['제27조제2항']}]}, page_content='제1조(목적) 이 조례는 「자연재해대책법」 제27조제2항의 규정에 따라 건축물관리자의 제설·제빙에 관한 사항을 구체적으로 정함으로써 눈 또는 얼음으로 인한 주민의 불편을 최소화하고, 안전을 꾀함을 목적으로 한다.'),
#  Document(id='2019610_clause_2', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}, 'links': [{'도로법': [], '농어촌도로정비법': [], '자연재해대책법 시행령': ['제22조의8']}]}, page_content='제2조(정의) 이 조례에서 사용하는 용어의 뜻은 다음과 같다. <개정 2017.7.31.>1. “도로”라 함은 「도로법」에 따른 도로, 그 밖에 일반 교통에 사용되는 모든 곳을 말한다.2. “차도”라 함은 연석선(차도와 보도를 구분하는 돌 등으로 이어진 선을 말한다), 안전표지, 그 밖에 이와 비슷한 공작물로써 그 경계를 표시하여 모든 차의 교통에 사용하도록 된 도로의 부분을 말한다.3. “보도(步道)”라 함은 연석선, 안전표지, 그 밖에 이와 비슷한 공작물로써 그 경계를 표시하여 보행자(유모차 및 신체장애인용 의자차를 포함한다)의 통행에 사용하도록 되어있는 도로의 부분을 말한다. <개정 2017.3.6.>4. “이면도로”라 함은 「도로법」에 따른 고속국도ㆍ일반국도ㆍ지방도ㆍ군도 및 농어촌도로(「농어촌도로정비법」에 따른 도로를 말한다)가 아닌 일반의 교통에 사용되는 도로로서 차도와 보도의 구분이 없는 폭 12미터 미만의 도로를 말한다.5. “보행자전용도로”라 함은 보행자만이 다닐 수 있도록 안전표지 및 그 밖에 이와 비슷한 공작물로써 표시한 도로를 말한다.6. “제설ㆍ제빙작업”이라 함은 도로상의 눈 또는 얼음을 제거하거나 녹게 하는 재료 및 모래 등을 뿌려서 보행자와 차량의 안전한 통행에 지장이 없도록 하는 것을 말한다.7. “건축물관리자”라 함은 건축물의 소유자ㆍ점유자 또는 관리자로서 그 건축물의 관리 책임이 있는 사람을 말한다.8. “시설물의 지붕”이라 함은 「자연재해대책법 시행령」제22조의8에 따른 시설물의 지붕을 말한다. <신설 2017.7.31.>'),
#  Document(id='2019610_clause_3', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제3조(건축물관리자의 제설ㆍ제빙 책임) 건축물관리자는 관리하고 있는 건축물의 대지에 접한 보도, 이면도로, 보행자전용도로, 시설물의 지붕에 대한 제설ㆍ제빙작업을 하여야 한다. <신설 2017.7.31.>'),
#  Document(id='2019610_clause_4', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제4조(제설ㆍ제빙작업의 책임순위) 건축물관리자의 제설ㆍ제빙 책임순위는 다음 각 호와 같다. 다만, 건축물관리자간 합의가 된 경우에는 합의된 순위에 따른다.1. 소유자가 건축물 내에 거주하는 경우에는 소유자, 점유자 또는 관리자 순으로 한다.2. 소유자가 건축물 내에 거주하지 않는 경우에는 점유자, 관리자 또는 소유자 순으로 한다.'),
#  Document(id='2019610_clause_5', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}, 'links': [{'기타': ['별표']}]}, page_content='제5조(제설ㆍ제빙작업의 책임범위) 건축물관리자가 하여야 하는 제설ㆍ제빙작업의 책임범위는 다음 각 호와 같다.(별표 예시도 참조)1. 보도는 건축물의 대지에 접한 보도의 전체 구간2. 이면도로 및 보행자전용도로는 건축물의 대지에 접한 도로의 중앙선 또는 중앙부분까지의 구간3. 시설물의 지붕은 최상층의 지붕면의 구간(옥탑층이 있을 경우 옥탑층의 지붕구간도 포함한다.) 또는 여러 층에 복합적으로 지붕이 형성된 경우 모든 지붕구간 <신설 2017.7.31.>'),
#  Document(id='2019610_clause_6', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제6조(제설ㆍ제빙작업의 시기) 건축물관리자는 제설ㆍ제빙작업을 눈이 그친 때부터 3시간 이내에 완료하여야 한다. 다만, 야간(일몰 후부터 다음 날 일출 전까지)에 눈이 내린 때에는 다음 날 오전 11시까지 제설ㆍ제빙작업을 완료하여야 한다.'),
#  Document(id='2019610_clause_7', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제7조(제설ㆍ제빙작업의 방법) 건축물관리자는 보행자나 차량의 안전한 통행에 지장이 없도록 삽, 빗자루 등의 작업도구를 이용하여 다음 각 호와 같이 제설ㆍ제빙작업을 하여야 한다.1. 보도ㆍ이면도로 및 보행자전용도로의 눈이나 얼음 : 도로의 가장자리나 공터 등으로 옮긴다.2. 얼음 제거가 어려운 경우에는 얼음을 녹게 하는 재료나 모래 등을 사용하고, 얼음이 녹은 후에는 뿌려진 모래 등을 깨끗이 제거한다.3. 시설물의 지붕에서 발생되는 눈은 시설물의 대지 안에 옮긴다. 다만, 대지 안에 여유공간이 없을 경우 보도의 가장자리나 공터 등으로 옮긴다. <신설 2017.7.31.>'),
#  Document(id='2019610_clause_8', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제8조(제설ㆍ제빙작업의 도구 비치ㆍ관리) 건축물관리자는 제설ㆍ제빙작업에 필요한 작업도구를 건축물 내에 매년 12월 1일부터 다음해 3월 15일까지 비치·관리하여야 한다. <개정 2017.7.31.>'),
#  Document(id='2019610_clause_9', metadata={'자치법규ID': '2019610', '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례', '자치법규일련번호': '1298118', '지자체기관명': '경기도 가평군', '시행일자': '20170731', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2623', '전화번호': '031-580-2430', '담당부서명': '건설도시국 건설과', '자치법규발의종류': '', '공포일자': '20170731', '약어': {}}, page_content='제9조(시행규칙) 이 조례의 시행에 필요한 사항은 규칙으로 정한다. <개정 2017.7.31.>'),
#  Document(id='2205553_clause_1', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법': [], '건축물관리법 시행령': [], '건축물관리법 시행규칙': []}]}, page_content='제1조(목적) 이 조례는 「건축물관리법」, 같은 법 시행령 및 같은 법 시행규칙에서 조례로 정하도록 위임된 사항과 그 시행에 필요한 사항을 규정함을 목적으로 한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_2', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'군': '가평군'}}, page_content='제2조(적용 범위) 이 조례는 가평군(이하 “군”이라 한다) 행정구역 안에 있는 건축물 및 그 대지에 적용한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_3', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'법': '건축물관리법'}, 'links': [{'건축물관리법': [], '건축법': []}]}, page_content='제3조(정의) 이 조례에서 사용하는 용어의 뜻은 「건축물관리법」(이하 “법”이라 한다) 및 「건축법」에서 정하는 바에 따른다.'),
#  Document(id='2205553_clause_4', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'영': '건축물관리법 시행령'}, 'links': [{'건축물관리법 시행령': ['제8조제1항제1호'], '다중이용업소의 안전관리에 관한 특별법 시행령': ['제2조제1호나목', '제2조제2호', '제2조제3호', '제2조제4호', '제2조제6호', '제2조제7호', '제2조제7의2호', '제2조제7의5호']}]}, page_content='제4조(정기점검 대상) 「건축물관리법 시행령」(이하 “영”이라 한다) 제8조제1항제1호에서 “조례로 정하는 건축물”이란 같은 건축물에 「다중이용업소의 안전관리에 관한 특별법 시행령」 제2조제1호나목, 제2호, 제3호, 제4호, 제6호, 제7호, 제7의2호, 제7의5호의 용도로 쓰는 바닥면적의 합계가 1천 제곱미터 이상인 건축물을 말한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_5', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'구조전문위원회': '가평군 건축위원회 구조전문위원회'}, 'links': [{'건축물관리법 시행령': ['제9조제1항제2호'], '가평군 건축 조례': ['제10조의2']}]}, page_content='제5조(긴급 점검) 영 제9조제1항제2호에서 “조례로 정하는 경우”란 기초 침하, 좌굴 등 구조적 손상 등으로 건축물의 안전이 의심되는 경우로써 「가평군 건축 조례」 제10조의2에 따른 가평군 건축위원회 구조전문위원회(이하 “구조전문위원회”라 한다)의 자문 결과 점검이 필요하다고 인정하는 경우를 말한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_6', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법': ['제15조제1항제1호'], '건축물의 구조기준 등에 관한 규칙': ['제3조제2항'], '건축물관리법 시행령': ['제10조제1항제7호']}]}, page_content='제6조(소규모 노후 건축물 등 점검의 대상)① 법 제15조제1항제1호에서 “조례로 정하는 규모의 건축물”이란 「건축물의 구조기준 등에 관한 규칙」 제3조제2항의 소규모 건축물 중 구조전문위원회의 자문 결과 점검이 필요하다고 인정하는 경우를 말한다.<개정 2023.12.26.>② 영 제10조제1항제7호에서 “조례로 정하는 건축물”이란 구조 등 안전에 취약하거나 재난의 위험이 있어 구조전문위원회의 자문 결과 점검이 필요하다고 인정하는 건축물을 말한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_7', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법 시행령': ['제11조제1항제2호']}]}, page_content='제7조(안전진단의 대상) 영 제11조제1항제2호에서 “조례로 정하는 경우”란 관할 소방서의 점검 결과 화재안전 성능이 저하됐을 것으로 우려되어 안전진단 요청이 있을 경우를 말한다.<개정 2023.12.26.>'),
#  Document(id='2205553_clause_8', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'점검기관': '영 제12조제4항에 따른 건축물관리 점검기관', '관리자': '법 제2조제3호의 관리자', '군수': '가평군수', '도지사': '경기도지사'}, 'links': [{'건축물관리법 시행령': ['제12조제4항', '제12조제3항'], '건축물관리법': ['제2조제3호'], '건축법': [], '건축사법': [], '건설기술 진흥법': []}]}, page_content='제8조(건축물관리점검기관의 지정 등)① 영 제12조제4항에 따른 건축물관리 점검기관(이하 “점검기관”이라 한다)의 지정은 영 제12조제3항에 따라 작성된 점검기관 명부에 적혀 있는 기관 중에서 무작위 선정(건축물 생애이력 관리시스템 이용)하여 지정하는 것을 원칙으로 한다. 다만, 다음 각 호에 해당하는 경우에는 점검기관으로 지정할 수 없다.1.「건축법」, 「건축사법」, 「건설기술 진흥법」등 관련 법령에 따른 업무정지나 휴업 기간 중에 있는 경우2. 특별한 사유 없이 2회 이상 지정을 거부한 경우3. 건축사사무소를 폐업하거나 건축사 자격을 반납한 경우4. 건설기술용역사업자의 등록이 취소된 경우5. 제3항제1호 각 목의 사유로 건축물관리점검 업무수행이 어려워 지정 제외를 요청한 기관6. 건축물관리점검과 관련하여 법 제2조제3호의 관리자(이하 “관리자”라 한다) 등에게 계약한 대가 이외의 금품을 요구 또는 수수한 자② 가평군수(이하 “군수”라 한다)는 제1항의 각 호에 따라 건축물관리점검기관을 지정할 수 없을 경우 즉시 경기도지사(이하 “도지사”라 한다)에게 통보해야 한다.③ 영 제12조제3항에 따라 명부에 적혀 있는 점검기관은 다음 각 호의 어느 하나에 해당하는 사유가 발생하면 다음 각 호에서 정한 서류를 7일 이내에 군수에게 제출해야 하며, 기한까지 관련 서류를 제출하지 않으면 군수는 해당 기관을 점검기관 지정에서 제외할 수 있다.  이 경우, 군수는 도지사에게 변경사항을 즉시 통보해야 한다.1. 다음 각 목의 어느 하나에 해당하는 사유로 건축물관리점검업무를 수행할 수 없는 경우: 별지 제1호서식의 건축물관리점검기관 지정 연기요청서가. 지병으로 인한 치료 또는 입원한 경우나. 국내외 장기 출장을 간 경우다. 그 밖의 부득이한 사유로 감리업무 수행이 불가능하게 된 경우. 이 경우, 그 사실을 증명하는 서류를 제출한다.2. 건축물관리점검기관 개설 사항에 변경이 생겼을 경우: 변경사항이 기재된 신고확인증 사본<개정 2023.12.26.>3. 「건축법」, 「건축사법」, 「건설기술 진흥법」 등 관련 법령에 따른 업무정지 처분 이상의 행정처분을 받은 경우:  처분서 사본④ 군수는 제1항에 따라 지정한 건축물관리점검기관을 해당 관리자 및 건축물관리점검기관, 도지사에게 통보해야 한다.⑤ 건축물관리점검기관 지정을 통보 받은 관리자와 건축물관리점검기관은 통보 받은 후 3개월 이내에 계약을 체결해야 하며, 건축물관리점검 업무대가는 건축물관리점검지침에 따라 산정해야 한다.'),
#  Document(id='2205553_clause_9', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법 시행령': ['제21조제1항제3호'], '건축법': ['제20조'], '도시 및 주거환경정비법': ['제2조']}]}, page_content='제9조(건축물 해체의 신고) 영 제21조제1항제3호에 따른 “조례로 정하는 건축물”이란 다음 각 호의 어느 하나에 해당하는 경우로 한다.1.「건축법」 제20조에 따른 축조신고 대상 가설건축물 중 견본주택<개정 2023.12.26.>2.「도시 및 주거환경정비법」 제2조의 주거환경개선사업 및 재개발사업을 위한 정비구역 내 건축물(다만, 정비구역 외곽경계의 도로에 접한 대지에 건축된 건축물은 제외한다)<개정 2023.12.26.>'),
#  Document(id='2205553_clause_10', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법 시행령': ['제21조의3제4호', '제23조의4제1항제2호']}]}, page_content='제9조의2(필수확인점의 현장점검) 영 제21조의3제4호에서 “조례로 정하는 경우”란 영 제23조의4제1항제2호에 따른 지붕 해체공정 착수 전을 말한다.[본조신설 2023.12.26.]'),
#  Document(id='2205553_clause_11', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법 시행령': ['제22조제2항', '제22조제1항'], '건축법': [], '건축사법': [], '건설기술 진흥법': []}]}, page_content='제10조(건축물 해체공사감리자의 지정 등)① 영 제22조제2항에 따른 해체공사감리자의 지정은 영 제22조제1항에 따라 작성된 감리자 명부에 적혀 있는 자 중에서 순번에 따라 지정하는 것을 원칙으로 한다. 다만, 다음 각 호에 해당하는 자는 지정할 수 없다.1. 업무정지나 휴업 기간 중에 있는 자2. 특별한 사유 없이 2회 이상 지정을 거부한 자3. 건축사사무소를 폐업하거나 건축사 자격을 반납한 자4. 건설기술용역사업자의 등록이 취소된 경우5. 제4항 각 호의 사유로 해체공사감리 업무 수행이 어려워 지정 제외를 요청한 자6. 해체공사감리와 관련하여 관리자 등에게 계약한 대가 이외의 금품 또는 재산상 이익을 요구 또는 수수한 자② 군수는 제1항의 각 호에 따라 해체공사감리자를 지정할 수 없을 경우 즉시 도지사에게 통보해야 한다.③ 군수는 제1항에 따라 지정한 감리자를 7일 이내에 해당 관리자에게 통보해야 한다.④ 영 제22조제1항에 따라 명부에 적혀 있는 자는 다음 각 호의 어느 하나에 해당하는 사유가 발생하면 다음 각 호에서 정한 서류를 7일 이내에 군수에게 제출해야 한다. 이 경우, 군수는 도지사에게 변경사항을 즉시 보고해야 한다.1. 다음 각 목의 어느 하나에 해당하는 사유로 감리업무를 수행할 수 없는 경우: 별지 제2호서식의 해체공사감리자 지정 연기요청서<개정 2023.12.26.>가. 지병으로 인한 치료 또는 입원한 경우나. 국내외 장기 출장을 간 경우다. 그 밖의 부득이한 사유로 감리업무 수행이 불가능하게 된 경우: 그 사실을 증명하는 서류<개정 2023.12.26.>2. 「건축법」, 「건축사법」, 「건설기술 진흥법」 등 관련 법령에 따른 업무정지 처분 이상의 행정처분을 받은 경우: 처분서 사본3. 「건축사법」또는「건설기술 진흥법」에 따른 감리자격에 변경이 생겼을 경우: 변경 사항이 기재된 신고확인증 사본<개정 2023.12.26.>'),
#  Document(id='2205553_clause_12', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}, 'links': [{'건축물관리법 시행령': ['제23조제4호']}]}, page_content='제11조(건축물 해체공사감리자의 교체) 영 제23조제4호에 따른 감리자 교체 대상을 “조례로 정하는 경우”는 다음 각 호와 같다.1. 해체공사감리자가 감리와 관련하여 관리자 등에게 계약한 대가 이외의 금품을 요구 또는 수수하는 경우2. 해체공사감리자의 직무태만ㆍ품위손상 및 그 밖의 사유로 해체공사감리자로 적합하지 아니하다고 군수가 인정하는 경우'),
#  Document(id='2205553_clause_13', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {'건축물관리센터': '법 제40조제2항에 따른 지역건축물관리지원센터'}, 'links': [{'건축물관리법': ['제40조제2항', '제39조제3항']}]}, page_content='제12조(지역건축물관리지원센터의 설치ㆍ운영)① 군수는 법 제40조제2항에 따른 지역건축물관리지원센터(이하 “건축물관리센터”라 한다)를 설치ㆍ운영할 수 있다.② 건축물관리센터는 법 제39조제3항에 따른 업무와 다음 각 호의 업무를 수행한다.1. 이 법에 따른 안전점검 의무 관리대상이 아닌 건축물의 안전관리 및 안전점검 지원에 관한 사항2. 그 밖에 군수가 건축물의 안전을 위하여 필요하다고 인정하는 경우'),
#  Document(id='2205553_clause_14', metadata={'자치법규ID': '2205553', '자치법규명': '가평군 건축물관리 조례', '자치법규일련번호': '1888393', '지자체기관명': '경기도 가평군', '시행일자': '20231226', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3174', '전화번호': '031-580-4773', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20231226', '약어': {}}, page_content='제13조(시행규칙) 이 조례의 시행에 필요한 사항은 규칙으로 정한다.'),
#  Document(id='2019611_clause_1', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': [], '건축법 시행령': [], '건축법 시행규칙': []}]}, page_content='[제1장 총칙] 제1조(목적) 이 조례는 「건축법」,「건축법 시행령」및「건축법 시행규칙」에서 조례로 정하도록 위임된 사항과 그 시행에 필요한 사항을 정함을 목적으로 한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_2', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'군': '가평군'}}, page_content='[제1장 총칙] 제2조(적용 범위) 이 조례는 가평군(이하 “군”이라 한다) 행정구역 안 건축물 및 그 대지에 적용한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_3', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'영': '건축법 시행령', '법': '건축법'}, 'links': [{'건축법 시행령': ['제6조제1항제7의2호', '제6조제2항제3호', '제6조제2항제5호'], '건축법': ['제5조제3항', '제56조', '제60조', '제61조'], '경기도 건축 조례': ['제3조'], '녹색건축물 조성 지원법': ['제15조제2항', '제15조제3항'], '기타': ['별표 9']}]}, page_content='[제1장 총칙] 제3조(적용의 완화)① 「건축법 시행령」(이하 "영"이라 한다) 제6조제1항제7의2호에 따른 건축물은 축사 및 작물재배사로 대지에 2미터 이상이 접한 너비 3미터 이상의 도로에 한정한다.<개정 2016.4.6.>② 「건축법」(이하 "법"이라 한다) 제5조제3항에 따른 절차 및 방법은 「경기도 건축 조례」제3조를 준용한다.<개정 2016.4.6.>③ 영 제6조제2항제3호에서 “건축조례로 정하는 비율”은 100분의 140이하로 한다.<신설 2015.8.10.>④ 영 제6조제2항제5호에서 “건축조례로 정하는 용적률”은 법 제56조에 따라 해당 지역에 적용되는 용적율에 주민공동시설에 해당하는 용적률을 가산하여 적용한다.<신설 2015.8.10.>⑤ 「녹색건축물 조성 지원법」 제  15조제2항의 기준에 적합한 건축  물의 범위는 다음 각 호로 하며, 같은 법 제15조제3항에 따른 완화 기준은 국토교통부장관이 고시한「건축물의 에너지절약 설계기준」별표 9에 따른다.<신설 2015.8.10.>1. 법 제56조에 따른 건축물의 용적률 : 100분의 115 이하2. 법 제60조 및 제61조에 따른 건축물의 높이 : 100분의 115 이하'),
#  Document(id='2019611_clause_4', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제3조의5'], '기타': ['별표 1제1호나목4)', '별표 1제4호거목']}]}, page_content='[제1장 총칙] 제3조의2(다중주택 및 다중생활시설의 건축기준)① 영 제3조의5 및 별표 1제1호나목4)에서 “건축조례로 정하는 실별 최소 면적, 창문의 설치 및 크기 등의 기준”이란 다음 각 호와 같다.1. 실별 최소 면적은 전용면적 14제곱미터 이상으로 할 것2. 실별 창문은 외기에 접해야 하고 유효면적 1제곱미터 이상 크기로 1개소 이상 설치 할 것② 영 별표 1제4호거목에 따른 “건축조례로 정하는 실별 최소 면적, 창문의 설치 및 크기 등의 기준”은 다음 각 호와 같다.1. 실별 최소 면적은 전용면적 12제곱미터 이상으로 하고, 전용공간에 개별화장실을 포함하는 경우 14제곱미터 이상으로 할 것2. 실별 창문은 외기에 접해야 하고 유효 폭 0.5미터 이상, 유효 높이 1.0미터 이상 크기로 1개소 이상 설치 할 것[본조신설 2023.5.15.]'),
#  Document(id='2019611_clause_5', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제6조', '제57조', '제55조', '제56조', '제22조'], '건축법 시행령': ['제6조의2', '제14조제6항', '제6조의2제1항'], '도로법': [], '자연재해대책법': ['제12조'], '기타': ['별표 3']}]}, page_content='[제1장 총칙] 제4조(기존건축물 등에 대한 특례)① 법 제6조 및 영 제6조의2에 따라 기존 건축물 및 대지가 관계 법령의 규정에 부적합하더라도 건축을 허가할 수 있는 경우는 다음 각 호의 어느 하나에 해당하는 경우로 한다.<종전의 제목 외의 부분에서 이동 및 개정 2024.9.19.>1. 기존 건축물을 재축하는 경우2. 증축하거나 개축하려는 부분이 법령 등에 적합한 경우3. 기존 건축물의 대지가 도시ㆍ군계획시설의 설치 또는 「도로법」에 따른 도로의 설치로 법 제57조에 따라 제27조의 각 호에서 정하는 면적에 미달되는 경우로서 그 기존 건축물을 연면적 합계의 범위에서 증축하거나 개축하는 경우4. 기존 건축물이 도시ㆍ군계획시설 또는 「도로법」에 따른 도로의 설치로 법 제55조 또는 법 제56조에 부적합하게 된 경우로서 화장실ㆍ계단ㆍ승강기의 설치 등 그 건축물의 기능을 유지하기 위하여 그 기존 건축물의 연면적 합계의 범위에서 증축하는 경우5. 2007년 4월 11일 이전에 건축된 기존 건축물의 건축선 및 인접 대지경계선으로부터의 거리가 제34조 관련 별표 3에 미달되는 경우로서 그 기존 건축물을 건축 당시의 법령에 위반되지 않는 범위에서 수직으로 증축하는 경우6. 기존 한옥을 개축하는 경우7. 건축물 대지의 전부 또는 일부가 「자연재해대책법」 제12조에 따른 자연재해위험개선지구에 포함되고 법 제22조에 따른 사용승인 후 20년이 지난 기존 건축물을 재해로 인한 피해 예방을 위하여 연면적의 합계 범위에서 개축하는 경우② 영 제14조제6항에 따라 기존의 건축물 또는 대지가 법령의 제정, 개정이나 영 제6조의2제1항 각 호의 사유로 법령 등에 부적합하게 된 경우에는 용도변경 하고자 하는 부분이 법령 등에 적합한 범위에서 용도변경 할 수 있다.<신설 2024.9.19.>'),
#  Document(id='2019611_clause_6', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'위원회': '가평군 건축위원회'}, 'links': [{'건축법': ['제4조제1항'], '건축법 시행령': ['제5조의5제1항']}]}, page_content='[제2장 건축위원회] 제5조(설치) 법 제4조제1항 및 영 제5조의5제1항에 따라 가평군 건축위원회(이하 “위원회”라 한다)를 둔다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_7', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'군수': '가평군수'}, 'links': [{'건축법 시행령': ['제5조의5 제4항', '제5조의5 제6항']}]}, page_content='[제2장 건축위원회] 제6조(구성)① 위원회는 위원장 및 부위원장 각 1명을 포함하여 25명 이상 150명 이하의 위원으로 구성하되, 당연직으로 임명하는 위원은 전체위원의 4분의 1 이하로 한다. 이 경우, 위촉위원 중 어느 한 쪽 성(性)이 위촉직 위원수의 10분의 6을 초과하지 않아야 한다.<개정 2014.4.18.><개정 2016.4.6.>② 위원장은 업무 담당국장이 되고, 부위원장은 위원 중에서 선출한다.<개정 2020.2.10.>③ 위원회의 당연직 위원은 건축·건설·도시·환경 업무관련 부서의 장 및 관할 소방서 소방방재 업무 담당 과장으로 하고, 위촉직 위원의 자격은 영 제5조의5 제4항에 해당하는 사람에 한하여 위촉하며, 위원회의 임명ㆍ위촉기준은 영 제5조의5 제6항에 따르고 위원으로 임명 또는 위촉된 사람은 별지 제1호서식에 따른 청렴서약서를 가평군수(이하 "군수"라 한다)에게 제출하여야 한다.<개정 2016.4.6.><개정 2021.2.15.>④ 삭제<2014.4.18.><개정 2013.7.10.>⑤ 삭제<2014.4.18.><개정 2009.11.10.>'),
#  Document(id='2019611_clause_8', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}}, page_content='[제2장 건축위원회] 제6조의2(위원의 임기)① 위촉직 위원의 임기는 3년으로 하며, 한 차례에 한정하여 연임할 수 있다.② 삭제<2020.7.27.>'),
#  Document(id='2019611_clause_9', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}}, page_content='[제2장 건축위원회] 제7조(위원장의 직무)① 위원장은 위원회를 대표하고, 위원회의 업무를 총괄한다.<개정 2014.4.18.>② 위원장은 부득이한 사유로 그 직무를 수행할 수 없을 때에는 부위원장이 그 직무를 대행하며, 위원장과 부위원장이 모두 부득이한 사유로 그 직무를 수행할 수 없을 때에는 위원장이 미리 지명한 위원이 그 직무를 대행한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_10', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'심의등': '조정'}, 'links': [{'건축법 시행령': ['제5조의5제1항']}]}, page_content='[제2장 건축위원회] 제8조(기능)① 위원회는 다음 각 호의 사항을 조사ㆍ심의ㆍ조정(이하 “심의등”이라 한다)한다.<개정 2014.4.18.>1. 영 제5조의5제1항 및 그 밖에 이 법령 또는 이 조례에서 심의등을 받도록 한 사항과 군수가 위원회의 자문이 필요하다고 인정하여 토의에 부치는 사항<개정 2014.4.18.>2. 분양을 목적으로 하는 다음 각 목의 건축물<개정 2014.4.18.><개정 2021.2.15.>가. 300세대 이상의 공동주택을 건설하는 단지나. 주택과 주택 외의 시설을 같은 건축물로 건축하는 경우로서 주택의 세대수가 100세대 이상인 건축물<개정 2014.4.18.>다. 일반업무시설 중 오피스텔로서 실의 수가 100실 이상인 건축물라. 가목부터 다목까지에 해당되지 않는 용도의 건축물로서 분양하는 부분의 바닥면적의 합계가 5천제곱미터 이상인 건축물3. 다른 법령에 따라 위원회의 심의등을 받도록 한 사항<신설 2014.4.18.>② 위원장은 제1항에 따른 심의등의 사항에 대하여 보다 충분한 기술적 검토가 필요하다고 인정되는 경우에는 위원회 개최 전에 위원에게 사전 기술 검토를 요청할 수 있다.<개정 2014.4.18.>③ 제2항에 따른 사전 기술 검토를 의뢰 받은 위원은 이를 충분히 검토하고 위원회 개최 시 그 검토 의견을 제시하여야 한다.<개정 2014.4.18.>④ 위원장은 제1항에 대하여 심의 사항의 특성상 필요할 경우에는 서면으로도 심의 할 수 있다.<개정 2014.4.18.>⑤ 삭제<2016.4.6.>'),
#  Document(id='2019611_clause_11', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}}, page_content='[제2장 건축위원회] 제9조(회의)① 위원장은 군수로부터 심의등의 요청을 받은 경우와 위원장이 필요하다고 인정하는 경우에 회의를 소집하며, 그 의장이 된다.<개정 2014.4.18.>② 위원회의 회의(소위원회를 포함한다. 이하 같다)는 재적위원 과반수의 출석으로 개의(開義)하고, 출석위원 과반수의 찬성으로 의결한다.<개정 2014.4.18.><개정 2016.4.6.>③ 위원장은 회의 개최 10일 전까지 회의 안건과 심의등에 참여할 위원을 확정하고, 회의 개최 7일 전까지 회의에 부치는 안건, 회의 일시, 장소 등을 각 위원에게 알려주어야 한다. 다만, 대외적으로 기밀 유지가 필요한 사항이나, 그 밖에 부득이한 사유가 있는 경우에는 그렇지 않다.<개정 2014. 4.18.><개정 2023.5.15.>④ 위원장은 업무수행을 위하여 필요하다고 인정하는 경우에는 관계 공무원, 관계 전문가, 설계자, 시공자 등을 위원회에 출석시켜 발언하게 하거나, 관계 기관 및 단체에 대하여 자료의 제출을 요청할 수 있다.⑤ 위원회의 위원 중 심의등을 신청한 건축물의 건축주나 설계자는 해당 건축물의 심의등에 참석할 수 없다. 다만, 위원이 아닌 건축주ㆍ설계자 및 심의등을 신청한 사람이 희망하는 경우에는 회의에 참여하여 해당 안건에 대하여 설명할 수 있도록 한다.<개정 2014.4.18.>⑥ 위원별 의견, 심의등 결과 및 사유를 관계자가 요구 할 경우에는 공개한다. 다만, 개인식별이 가능한 성명과 녹취 또는 회의록은 제외한다.<개정 2014.4.18.>⑦ 심의등 안건은 원안의결ㆍ조건부 의결ㆍ재심의 의결ㆍ부결로 구분하여 의결한다.<신설 2014.4.18.>⑧ 군수는 심의등을 신청한 사람에게 심의등의 결과(보완 등 조치 할 사항이 있는 경우에는 그 조치할 내용 포함)를 알려야 하며, 위원회는 회의 시 회의록을 작성ㆍ보관하여야 한다.<신설 2014.4.18.>'),
#  Document(id='2019611_clause_12', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'기타': ['제9조']}]}, page_content='[제2장 건축위원회] 제10조(소위원회)① 위원회는 심의사항 중 세부적인 사항 및 위원회에서 위임한 사항을 심의하기 위하여 소위원회를 구성·운영할 수 있다.② 소위원회의 위원장은 위원회의 위원장이 겸하거나 위원회의 위원 중에서 위원장이 지명하는 사람이 된다.③ 소위원회의 위원은 해당 심의 성격에 따라 위원회의 위원 중에서 위원장 또는 소위원회의 위원장이 지명하는 사람이 된다.④ 소위원회의 위원장 및 위원의 임기는 해당 심의 또는 조사사항의 심의결정이 완료될 때까지로 한다.⑤ 소위원회에 위임된 사항 중 위원회가 소위원회 에서 의결된 사항을 위원회의 의결로 갈음하기로 한 경우에는 소위원회의 의결을 위원회의 의결로 갈음할 수 있다.<개정 2014.4.18.>⑥ 소위원회의 회의 운영은 제9조를 준용하되, 구성 등 그 밖에 필요한 사항은 규칙으로 정한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_13', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제4조제2항'], '건축법 시행령': ['제5조의6']}]}, page_content='[제2장 건축위원회] 제10조의2(전문위원회)① 군수는 위원회의 심의를 효율적으로 수행하기 위하여 필요한 경우에는 법 제4조제2항 및 영 제5조의6에 따라 건축계획ㆍ건축구조ㆍ건축설비 등 분야별 전문위원회를 둘 수 있다.② 전문위원회는 건축위원회 위원 중에서 위원장과 해당 분야의 위원 중  2명 이상의 위원으로 구성하되, 필요시 다른 분야의 위원을 추가하여 구성할 수 있다.③ 전문위원회의 위원장은 업무 담당과장이 된다.④ 전문위원회에서 의결된 사항은 건축위원회에서 의결된 것으로 본다.⑤ 위원장은 심의 사항이 경미한 경우 또는 긴급한 사유로 위원이 출석하는 회의를 개최할 시간적 여유가 없는 경우에는 해당 분야별로 서면으로 심의할 수 있다.⑥ 전문위원회 회의 및 운영에 관한 사항, 위원의 제척ㆍ기피ㆍ회피ㆍ해임ㆍ해촉,  수당 및 여비 지급에 관한 사항 등은 건축위원회 회의 운영 규정을 준용한다.'),
#  Document(id='2019611_clause_14', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}}, page_content='[제2장 건축위원회] 제11조(간사)① 위원회의 사무를 처리하기 위하여 간사 1명을 두되, 간사는 관련 업무 팀장이 된다.<개정 2013.7.10.><개정 2014.4.18.>② 간사는 다음 각 호의 사무를 처리한다.1. 위원회의 운영에 관한 사무2. 심의등 안건, 회의록 작성 및 보존<개정 2014.4.18.>3. 위원회의 심의등 결과의 정리 및 보고4. 그 밖에 위원회의 운영에 필요한 사항'),
#  Document(id='2019611_clause_15', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제5조의2', '제5조의3']}]}, page_content='[제2장 건축위원회] 제12조(위원의 제척ㆍ기피ㆍ회피ㆍ해임ㆍ해촉) 위원의 제척ㆍ기피ㆍ회피ㆍ해임ㆍ해촉에 대해서는 영 제5조의2 및 영 제5조의3을 준용한다.[전문개정 2014.4.18.]'),
#  Document(id='2019611_clause_16', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}}, page_content='[제2장 건축위원회] 제13조(비밀엄수의 의무) 위원회의 위원 및 그 밖에 위원회의 업무에 참여한 사람은 그 업무수행상 알게 된 비밀을 누설하여서는 아니 된다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_17', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제5조의5'], '가평군 위원회 실비변상 조례': [], '기타': ['제8조제4항']}]}, page_content='[제2장 건축위원회] 제14조(수당 등) 위원회의 안건을 심의한 위원에게는 예산의 범위에서「건축법 시행령」제5조의5에 따라 다음 각 호에 따라 수당을 지급할 수 있다.1. 위원회에 출석하여 의견서를 제출한 위원에게 「가평군 위원회 실비변상  조례」로 정하는 참석수당과 예산의 범위에서 심사수당을 지급할 수 있다.2. 제1호에 따른 심사수당은 군 소속 공무원과 군의회 의원 자격으로 심의하는 경우에는 제외한다.3. 제8조제4항에 따라 실시하는 서면심의 시에는 제1호에 따른 심사수당을 지급할 수 있다.[전문개정 2014.4.18.]<본조 개정 2017.9.25.>'),
#  Document(id='2019611_clause_18', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'협의회': '가평군 건축복합민원 일괄협의회'}, 'links': [{'건축법': ['제10조제1항', '제11조제1항', '제12조'], '건축법 시행령': ['제10조'], '가평군 민원 처리 규정': ['제12조']}]}, page_content='[제3장 건축물의 건축] 제15조(건축복합민원 일괄협의회)① 군수는 법 제10조제1항 및 법 제11조제1항에 따라 사전결정 및 건축허가를 처리하기 위하여 관계 법령의 확인이 요구되는 경우에는 법 제12조에 따라 관계 행정기관 및 관계 부서의 공무원으로 구성하는 가평군 건축복합민원 일괄협의회(이하 "협의회"라 한다)를 개최하여야 한다.② 협의회는 「가평군 민원 처리 규정」 제12조에 따른 민원실무심의회에서 대행할 수 있다.<개정 2023.5.15.>③ 협의회의 운영은 영 제10조를 따르되, 영에서 규정한 사항 외에 협의회의 운영 등에 대해서는 「가평군 민원 처리 규정」을 준용한다.<개정 2023.5.15.>④ 제1항에 따른 관계 행정기관의 공무원이 부득이한 사정으로 협의회에 불참하였거나, 협의회의 장이 판단하여 서면 협의가 필요하다고 인정할 때에는 기간을 정하여 의견을 제출하게 할 수 있다.[전문개정 2014.4.18.]'),
#  Document(id='2019611_clause_19', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'예치금': '미관 개선과 안전관리에 필요한 비용'}, 'links': [{'건축법': ['제13조제2항', '제13조제4항', '제21조', '제22조'], '건축법 시행령': ['제10조의2제1항'], '건축법 시행규칙': ['제11조']}]}, page_content='[제3장 건축물의 건축] 제16조(건축 공사현장 안전관리 예치금 등)① 법 제13조제2항에 따라 연면적이 1천제곱미터 이상으로  국가 또는 지방자치단체가 건축하는 공용건축물을 제외한 모든 건축물(단, 동물 및 식물 관련시설은 제외)로 건축허가를 받아 착공신고를 하는 건축주는 장기간 건축물의 공사현장이 방치되는 것에 대비하여 미리 미관 개선과 안전관리에 필요한 비용(이하 이 조에서 “예치금”이라 한다)을 예치하여야 한다.<개정 2014.4.18.><개정 2015.8.10.>② 법 제13조제4항에 따른 예치금의 산정, 예치 방법, 반환 등에 대해서는 다음 각 호를 따르고 그 밖에 필요한 사항은 규칙으로 정한다.<개정 2014.4.18.>1. 예치금의 산정:법 제21조에 따른 착공신고 할 때 제출하는 도급계약서상 계약금의 100분의 1(부가가치세 포함)<개정 2014.4.18.>2. 예치금의 예치방법 : 현금일 경우에는 「지방자치단체 회계관리에 관한 훈령」에 따르고, 보증서일 경우에는 영 제10조의2제1항 각 호의 어느 하나에 해당하는 보증서로 예치한다.<개정 2014.4.18.><개정 2023.5.15.>3. 예치금의 반환 : 법 제22조에 따라 건축주가 사용승인 신청할 때 반환 신청하며, 예치금을 미관 개선과 안전관리에 필요한 비용으로 사용하였을 경우에는 사용 후 차액을 되돌려 주고 예치금이 부족하였을 경우에는 추가비용을 납부하여야 한다.<개정 2014.4.18.>4. 보증서의 보증기간은 건축공사 기간에 2년 6개월의 기간을 가산한다.<신설 2019.5.15.>5. 착공신고 후 허가사항변경 등으로 공사도급금액의 변경 또는 기간이 변경될 경우 예치금 또는 기간을 재산정하여 변경 예치토록 하고, 「건축법 시행규칙」 제11조에 따라 건축주가 변경된 경우에는 변경되는 건축주 명의의 보증서를 제출(예치금에 관한 권리가 승계된 경우 제외)하여야 한다.<신설 2019.5.15.>'),
#  Document(id='2019611_clause_20', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제17조제2항', '제11조', '제14조', '제16조', '제19조', '제20조', '제83조'], '건축법 시행규칙': ['제10조제1항'], '가평군 제증명 등 수수료 징수 조례': [], '기타': ['별표 1']}]}, page_content='[제3장 건축물의 건축] 제17조(건축허가 수수료)① 법 제17조제2항 및 같은 법 시행규칙 제10조제1항에 따라 법 제11조·제14조·제16조·제19조·제20조 및 제83조에 따른 사전결정 또는 건축허가를 신청하거나 신고를 하는 사람은 별표 1에서 정하는 수수료를 내야 한다. 다만, 재해복구를 위한 건축물의 건축에 있어서는 그렇지 않다.<개정 2014. 4.18.><개정 2023.5.15.>② 제1항에 따른 수수료는 「가평군 제증명 등 수수료 징수 조례」를 준용하며, 납부한 수수료는 되돌려 주지 아니한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_21', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제20조제1항', '제60조', '제61조'], '건축법 시행령': ['제15조제1항', '제15조제5항제16호', '제15조제7항'], '국토의 계획 및 이용에 관한 법률': ['제64조'], '농지법 시행규칙': ['제3조의2'], '학교시설사업 촉진법': ['제3조']}]}, page_content='[제3장 건축물의 건축] 제18조(가설건축물)① 법 제20조제1항에 따라 군계획시설 또는 군계획시설 예정지에 건축할 수 있는 가설건축물은 3층 이하로서 영 제15조제1항 각 호의 기준에 적합하여야 한다.<개정 2014.4.18.>1. 철근콘크리트조 또는 철골철근콘크리트조가 아닐 것2. 존치기간은 3년 이내일 것. 다만, 군계획사업이 시행될 때까지 그 기간을 연장할 수 있다.<개정 2014.4.18.>3. 3층 이하일 것4. 전기·수도·가스 및 하수도 등 새로운 간선공급설비의 설치를 필요로 하지 아니할 것5. 공동주택·판매시설·운수시설 등으로서 분양을 목적으로 건축하는 건축물이 아닐 것6. 「국토의 계획 및 이용에 관한 법률」 제64조에 적합할 것② 영 제15조제5항제16호에서 “건축 조례로 정하는 건축물”이란 다음 각 호의 건축물을 말한다.<개정 2014.4.18.><개정 2017.9.25.>1. 삭제<2020.7.27.>2. 삭제<2020.7.27.>3. 공장 부지안 소규모 폐기물 저장시설 및 공해배출 저장시설(연면적 200제곱미터 이하인 것에 한정한다)4. 벽이 없는 고정식 원두막5. 주차장, 그 밖에 이와 비슷한 것의 관리사무소로서 알루미늄샷시 구조의 면적 15제곱미터 이하인 것. 다만, 1층에 한정하며 도시미관상 지장이 없어야 한다.6. 공장 용도의 건축물이 있는 대지 안에 설치하는 조립식 경량구조의 창고용, 간이포장용, 간이수선작업용 건물(연면적 18제곱미터 이하인 것에 한정한다)<신설 2009.11.10.>7. 농산물 저온저장고로서 연면적이 35제곱미터 이하인 구조물. 다만, 연면적이 17제곱미터 이하의 이동 가능한 구조는 신고하지 않을 수 있다.<신설 2014.4.18.>8.「농지법 시행규칙」제3조의2에 따른 농막(연면적 20제곱미터 이하)<개정 2017.9.25.>9. 연면적 100㎡ 이상인 간이축사용 보온덮개<신설 2018.4.11.>10. 합성수지 또는 이와 유사한 투시형 재질의 지붕으로서 보행 및 주차통로, 외부계단(지하포함), 출입구, 처마 등 기존 건축물의 외벽으로부터 폭 2.5m 이하(독립형은 기둥으로부터 2.5m 이하) 이고 벽이 없는 비가림용 시설11. 옥상에 방수를 목적으로 옥상바닥에서 최고높이 2미터 이하의 외벽 없이 설치하는 비가림 경사지붕(다만, 법 제60조 및 제61조를 위반하지 아니하고 경량철골조 또는 각파이프조 등 그 밖의 이와 유사한 재질로 된 것으로, 건축사 또는 구조기술사의 구조안전 확인을 받은 경우로 한정)<신설 2023.5.15.>12. 「학교시설사업 촉진법」 제3조에 따른 학교 내에 설치하는 차양 및 비가림시설<신설 2023.5.15.>13. 공동주택 단지 내에서 근로자 근무환경 개선을 위한 휴게시설로 조립식 또는 컨테이너 구조로 지상1층에 설치하는 연면적 20제곱미터 이하의 것(사업계획승인 공동주택 포함)<신설 2023.12.26.>③ 제1항에 따른 가설건축물을 허가할 경우에는 군계획사업의 지장 유무에 대하여 사업관련부서와 협의하여야 한다.<개정 2014.4.18.>④ 영 제15조제7항에 따른 가설건축물 존치기간 연장횟수는 제한 없이 존치기간을 연장할 수 있다.<신설 2023.5.15.>'),
#  Document(id='2019611_clause_22', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제22조제2항 단서', '제27조']}]}, page_content='[제3장 건축물의 건축] 제19조(사용승인을 위한 검사를 실시하지 아니하는 건축물) 법 제22조제2항 단서에 따라 사용승인을 위한 검사를 실시하지 아니하고 사용승인서를 발급 할 수 있는 건축물은 다음 각 호의 어느 하나에 해당하는 건축물로 한다.<개정 2014.4.18.>1. 법 제27조에 따라 건축사가 현장조사ㆍ검사 및 확인업무를 대행하는 건축물<개정 2014.4.18.>2. 삭제<2015.8.10.>'),
#  Document(id='2019611_clause_23', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제23조제4항'], '건축법 시행령': ['제11조제3항제3호', '제18조제2호', '제15조제5항']}]}, page_content='[제3장 건축물의 건축] 제20조(건축물의 설계)① 법 제23조제4항의 표준설계도서에 따라 건축하는 건축물 중 영 제11조제3항제3호에 따른 건축물의 범위는 다음 각 호와 같다.<개정 2009.11.10.><개정 2023.5.15.>1. 연면적이 500제곱미터 이하인 축사·창고·작물재배사 및 그 밖의 농업용 건축물2. 연면적이 200제곱미터 이하인 단독주택② 영 제18조제2호에 따라 설계도서 작성 적용 범위는 영 제15조제5항에서 정한 바에 따른다.<신설 2009.11.10.><개정 2014.4.18.>'),
#  Document(id='2019611_clause_24', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'대가기준': '「건축사법」제19조의3에 따른「공공발주사업에 대한 건축사의 업무범위와 대가기준」'}, 'links': [{'건축법': ['제25조제2항', '제25조제12항'], '건축사법': ['제19조의3'], '공공발주사업에 대한 건축사의 업무범위와 대가기준': ['제14조제2항'], '기타': ['별표 5', '별표 3']}]}, page_content='[제3장 건축물의 건축] 제20조의2(감리비용에 관한 기준 등)① 법 제25조제2항에 따라 허가권자가 공사감리자를 지정하는 경우에 법 제25조제12항에 따른 감리비용에 관한 산출기준은 다음 각 호와 같으며, 건축주는 공사감리자와의 계약 시 이를 준수하여야 한다.1. 비상주감리 :「건축사법」제19조의3에 따른「공공발주사업에 대한 건축사의 업무범위와 대가기준」(이하 “대가기준”이라 한다) 별표 5를 준용2. 상주감리 : 대가기준 제14조제2항에 따른 실비정액가산식을 준용② 제1항에 따른 감리비용 산출 시 공사비는 해당 건축공사의 공사내역서 또는 건물신축단가표(한국감정원)의 용도별 평균값을 적용한다.③ 제1항에 따른 감리비용 산출 시 건축물의 종별 구분은 대가기준 별표 3 건축물의 종별 구분에 따른다.④ 제2항에 따라 산출한 공사비가 대가기준 별표 5에서 규정한 공사비의 중간에 있는 경우에는 직선보간법에 따라서 다음과 같이 산정한다.<img src="/flDownload.do?flSeq=150924175&gubun=ELISIMG" alt="img150924175"onError="this.style.visibility=\'hidden\'">⑤ 건축주와 공사감리자는 제1항에 따라 산정된 건축공사감리비의 10분의 1의 범위에서 그 금액을 가중하거나 감경할 수 있다.⑥ 허가권자는 법 제25조제2항에 따라 공사감리자를 지정하는 건축물의 건축주가 사용승인을 신청할 때에는 감리비용을 지불한 입금내역서, 세금계산서, 통장사본 등을 제출하도록 요구하여 제1항에 따른 감리비용이 지불되었는지를 확인하여야 한다.'),
#  Document(id='2019611_clause_25', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제27조제1항', '제11조', '제14조', '제16조', '제19조제2항', '제20조제1항', '제22조'], '건축법 시행령': ['제20조제1항', '제20조제2항'], '건축법 시행규칙': ['제21조']}]}, page_content='[제3장 건축물의 건축] 제21조(현장조사·검사 및 확인업무의 대행)① 법 제27조제1항 및 영 제20조제1항에 따라 군수가 현장조사·검사 및 확인업무를 대행하게 할 수 있는 범위는 다음 각 호의 어느 하나에 해당하는 업무로 한다.<개정 2014.4.18.>1. 법 제11조  및 제14조에 따른 건축허가,건축신고 전 현장조사·검사 및 확인업무<개정 2014.4.18.><개정 2015.8.10.>2. 법 제16조에 따른 건축허가 및 신고사항의 변경 전 현장조사ㆍ검사 및 확인업무<개정 2014.4.18.><개정 2015.8.10.>3. 법 제19조제2항에 따른 용도변경(건축사가 설계하는 경우에 한정한다) 허가 전 현장조사·검사 및 확인업무<개정 2014.4.18.>4. 법 제20조제1항에 따른 가설건축물 허가 전 현장조사·검사 및 확인업무<개정 2014.4.18.>5. 법 제22조에 따른 사용승인 및 임시 사용승인 전 현장조사·검사 및 확인업무<개정 2014.4.18.>6. 그 밖에 군수가 행하여야 하는 현장조사·검사 및 확인업무 중 필요하다고 인정하는 업무<개정 2014.4.18.>② 군수는 영 제20조제2항에 따라 도지사가 작성·관리하는 명부에서 업무대행건축사를 지정한다.<개정 2021.8.4.>③ 제2항에 따라 업무대행자로 지정된 사람은 현장을 조사하여 「건축법 시행규칙」 제21조에서 정한 서식에 따라 사용승인조사 및 검사조서를 군수에게 제출하여야 한다.<신설 2021.8.4.>'),
#  Document(id='2019611_clause_26', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제27조제3항', '제11조', '제14조', '제22조'], '건축법 시행규칙': ['제21조제3항'], '엔지니어링산업 진흥법': ['제31조'], '기타': ['별표 2']}]}, page_content='[제3장 건축물의 건축] 제22조(현장조사·검사 및 확인업무의 대행시 수수료) 법 제27조제3항 및 같은 법 시행규칙 제21조제3항에 따라 현장조사·검사 및 확인업무를 대행하는 사람에게 「엔지니어링산업 진흥법」제31조에 따라 산업통상자원부장관이 공고하는 엔지니어링 사업대가기준에 따라 별표 2에서 정하는 수수료를 다음 각 호의 구분에 따라 지급한다.<개정 2014.4.18.><개정 2023.5.15.>1. 법 제11조에 따른 건축허가 및 법 제14조에 따른 건축신고 전 현장조사ㆍ검사 및 확인업무 대행 시에는 100분의 50<신설 2025.4.9.>2. 삭제<2016.4.6.>3. 삭제<2016.4.6.>4. 법 제22조에 따른 사용승인 및 임시사용승인 전 현장조사·검사 및 확인업무 대행 시에는 100분의 100<개정 2025.4.9.>5. 그 밖에 군수가 행하여야 하는 현장조사·검사 및 확인업무 대행 시에는 100분의 100<개정 2016.4.6.>'),
#  Document(id='2019611_clause_27', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제24조제1항', '제24조제4항'], '건축사법': []}]}, page_content='[제3장 건축물의 건축] 제23조(건축지도원)① 영 제24조제1항에서 조례로 정하는 건축지도원은 다음 각 호의 어느 하나에 해당하는 사람 중에서 군수가 지정한다.1. 삭제<2015.8.10.><개정 2014.4.18.>2. 「건축사법」에 따른 건축사 또는 건축분야의 기술사<개정 2014.4.18.>3. 건축기사 1급 자격소지자로서 2년 이상 건축분야에 종사한 사람4. 건축기사 2급 자격소지자로서 4년 이상 건축분야에 종사한 사람5. 「건축사법」에 따른 건축사보로 2년 이상 근무한 경력이 있는 사람<개정 2014.4.18.>6. 4년제 대학의 건축 관련 학과 졸업자로서 3년 이상 실무경력이 있는 사람7. 2년제 대학의 건축 관련 학과 졸업자로서 5년 이상 실무경력이 있는 사람8. 고등학교 건축 관련 학과 졸업자로서 7년 이상 실무경력이 있는 사람② 제1항에 따른 건축지도원 중 군 소속 공무원이 아닌 사람에게는 예산의 범위에서 보수를 지급할 수 있다.<개정 2014.4.18.>③ 영 제24조제4항에 따른 건축지도원의 지정 절차 및 보수기준 등에 대해서는 규칙으로 정한다.<개정 2014.4.18.>'),
#  Document(id='2019611_clause_28', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제52조의2제3항'], '건축물의 분양에 관한 법률': ['제3조'], '건축물관리법': ['제13조']}]}, page_content='[제3장 건축물의 건축] 제23조의2(실내건축)① 법 제52조의2제3항에 따른 실내건축이 적정하게 시공되었는지에 대한 검사 대상 건축물은 다중이용건축물 및「건축물의 분양에 관한 법률」제3조에 따른 건축물로 하며, 현장 조사·검사 및 확인업무 대행자가 건축물사용승인 신청 시 확인한다.<신설 2018.4.11.><개정 2021.8.4.>② 법 제52조의2제3항에 따른 검사의 주기는 대상 건축물에 대하여 사용승인일부터 5년 이내에 최초로 실시하고, 검사를 시작한 날을 기준으로 3년마다 실시한다. 다만, 「건축물관리법」 제13조에 따른 정기점검을 실시한 경우에는 해당 연도의 검사로 갈음할 수 있다.<신설 2021.8.4.>'),
#  Document(id='2019611_clause_29', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'자연재해대책법': ['제12조'], '건축법 시행령': ['제34조제1항']}]}, page_content='[제3장 건축물의 건축] 제23조의3(거실을 설치할 수 있는 지하층) 법 제53조제2항에서 “조례로 정하는 경우”란 「자연재해대책법」 제12조에 따른 자연재해위험개선 지구 중 침수위험지구 또는 침수위험지구에서 50미터 이내가 아니면서 다음 각 호의 어느 하나에 해당하는 경우를 말한다.1. 영 제34조제1항의 피난층인 지하층에 설치하는 거실로서 허가권자가 피난에 지장이 없다고 인정하는 경우2. 지상층과 동일가구로 구성되어 내부 계단을 통하여 지상으로 피난이 가능한 경우3. 그 밖에 위원회의 심의를 거쳐 피난에 지장이 없는 구조라고 인정되는 경우[신설 2025.4.9.]'),
#  Document(id='2019611_clause_30', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {'조경면적': '제1항에 따른 조경 등에 필요한 면적'}, 'links': [{'건축법': ['제42조제1항'], '건축법 시행령': ['제27조제1항제5호', '제27조제1항제10호']}]}, page_content='[제4장 건축물의 대지 및 도로 [제목변경 2014.4.18.]] 제24조(대지의 조경)① 건축주는 법 제42조제1항에 따라 면적 200제곱미터 이상인 대지에 건축하는 경우에는 다음 각 호의 기준에 따른 조경 등에 필요한 면적을 확보하여야 한다.<개정 2014.4.18.>1. 연면적(같은 대지에 2동 이상의 건축물이 있는 경우에는 이들 연면적의 합계로 한다. 이하 이 조에서 같다)이 2천제곱미터 이상인 건축물 : 대지면적의 100분의 15 이상<개정 2014.4.18.>2. 연면적 1천제곱미터 이상 2천제곱미터 미만인 건축물 : 대지면적의 100분의 10 이상3. 연면적 1천제곱미터 미만인 건축물 : 대지면적의 100분의 5 이상4. 삭제<2015.8.10.>② 제1항에도 불구하고 영 제27조제1항제5호 및 제10호에 따라 다음 각 호의 어느 하나에 해당하는 건축물은 조경 등의 필요한 조치를 하지 아니할 수 있다.<개정 2009.11.10.><개정 2014.4.18.>1. 전통시장 형태의 도매시장 및 소매시장 안의 건축물<개정 2014.4.18.>2. 학교, 군사시설, 교정시설3. 도시지역 외에서의 창고 건축물<개정 2014.4.18.><개정 2015.8.10.>4. 중심상업지역 또는 일반상업지역의 대지면적 300제곱미터 이하인 건축물<개정 2014.4.18.>5. 관광지 또는 관광단지에 설치하는 관광시설<신설 2009.11.10.>6. 전문휴양업의 시설 또는 종합휴양업의 시설<신설 2009.11.10.>7. 관광·휴양형 지구단위계획구역에 설치하는 관광시설<신설 2009.11.10.>8. 골프장<신설 2009.11.10.>9.그 밖에 군수가 녹지보존에 지장이 없다고 인정하여 지정·공고한 구역의 건축물<개정 2009.11.10.><개정 2014.4.18.>③ 제1항에 따른 조경 등에 필요한 면적(이하 "조경면적"이라 한다)산정은 다음 각 호에서 정하는 바에 따른다.1. 공지 또는 지표면으로부터 높이 2미터 미만인 옥외부분의 조경면적은 그 면적을 모두 산입한다.2. 지표면으로부터 높이가 2미터 이상인 옥외부분의 조경면적은 3분의 2에 해당하는 면적을 조경면적으로 산입한다. 다만, 조경면적으로 산정하는 면적은 법 제42조제1항에 따른 조경면적의 100분의 50을 초과할 수 없다.<개정 2014.4.18.>3. 대지상 조경, 옥상 조경 시 대지 외곽, 건축물 외곽으로부터 조경부분의 최소폭은 1미터 이상으로 하여야 한다.<개정 2014.4.18.>④ 군수는 나무심기에 부적합한 대지나 수목의 성장이 불가능한 대지에 있어서는 나무를 심는 대신에 제1항에 따른 조경면적에 해당하는 면적 이상의 대지에 파고라ㆍ조각물ㆍ정원석ㆍ연못ㆍ분수대ㆍ고정 분재 등 조경시설물을 설치하게 할 수 있다.[전문개정 2014.4.18.]'),
#  Document(id='2019611_clause_31', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'기타': ['제25조']}]}, page_content='[제4장 건축물의 대지 및 도로 [제목변경 2014.4.18.]] 제25조 삭제<2023.5.15.>'),
#  Document(id='2019611_clause_32', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제28조제2항'], '기타': ['별표 1 제21호']}]}, page_content='[제4장 건축물의 대지 및 도로 [제목변경 2014.4.18.]] 제25조의2(대지와 도로의 관계) 영 제28조제2항에 따라 연면적의 합계가 2천제곱미터(공장인 경우에는 3천제곱미터) 이상인 건축물의 대지는 너비 6미터 이상의 도로에 4미터 이상 접하여야 한다. 다만, 영 별표 1의 제21호에 따른 동물 및 식물 관련 시설(도축장 및 도계장은 제외)은 제외한다.<개정 2009.11.10.><개정2014.4.18.><개정 2015.8.10.>'),
#  Document(id='2019611_clause_33', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제45조제1항제2호']}]}, page_content='[제4장 건축물의 대지 및 도로 [제목변경 2014.4.18.]] 제26조(도로의 지정) 법 제45조제1항제2호에 따라 주민이 오랫 동안 행로로 이용하고 있는 사실상의 통로로서 다음 각 호의 어느 하나에 해당하는 경우에는 이해관계인의 동의를 받지 아니하고 위원회의 심의를 거쳐 도로로 지정할 수 있다.<개정 2014.4.18.>1. 복개된 하천 및 도랑2. 안전에 지장이 없는 제방도로3. 공원계획에 따라 설치된 공원안 도로4. 사실상 주민이 사용하고 있는 통로로서 같은 통로를 이용하여 건축허가(신고)된 사실이 있는 건축물의 진·출입로5. 사실상 도로로서 새마을사업 등으로 포장 또는 확장된 도로'),
#  Document(id='2019611_clause_34', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법': ['제57조제1항'], '건축법 시행령': ['제80조']}]}, page_content='[제5장 대지와 건축물의 관계] 제27조(대지의 분할 제한) 법 제57조제1항 및 영 제80조에 따른 대지는 다음 각 호의 어느 하나에 해당하는 면적에 못 미치게 분할 할 수 없다.[제목변경 2014.4.18.]<개정 2014.4.18.>1. 주거지역 : 60제곱미터2. 상업지역 : 150제곱미터3. 공업지역 : 150제곱미터4. 녹지지역 : 200제곱미터5. 제1호부터 제4호까지에 해당되지 않는 지역 : 60제곱미터'),
#  Document(id='2019611_clause_35', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제81조제1항제3호', '제81조제4항']}]}, page_content='[제5장 대지와 건축물의 관계] 제28조(맞벽건축을 할 수 있는 구역)① 영 제81조제1항제3호에 따라 맞벽건축을 할 수 있는 구역은 미관지구, 한옥 보전·진흥을 위하여 군수가 지정하는 구역으로 한다.<개정 2014. 4.18.>② 영 제81조제4항에 따른 맞벽 대상건축물은 공동주택·숙박시설·위락시설·공장·위험물저장 및 처리시설·분뇨 및 쓰레기처리시설·동물관련시설·묘지관련시설·장례식장을 제외한 용도로서 2동 이하로 하여야 한다.<개정 2014.4.18.>③제2항에 따른 맞벽건축물 중 건축연면적 1천제곱미터 이상 또는 5층 이상의 건축물은 위원회의 심의를 받아야 한다.'),
#  Document(id='2019611_clause_36', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'기타': ['제29조']}]}, page_content='[제5장 대지와 건축물의 관계] 제29조 삭제<2022.4.13.>'),
#  Document(id='2019611_clause_37', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'기타': ['제30조']}]}, page_content='[제5장 대지와 건축물의 관계] 제30조 삭제<2017.9.25.>'),
#  Document(id='2019611_clause_38', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'건축법 시행령': ['제86조제1항', '제86조제3항', '제86조제3항제2호'], '건축법': ['제61조제4항']}]}, page_content='[제5장 대지와 건축물의 관계] 제31조(일조 등의 확보를 위한 건축물의 높이제한)① 영 제86조제1항에 따라 전용주거지역이나 일반주거지역에서 건축물을 건축하는 경우 건축물의 각 부분을 정북방향으로의 인접 대지경계선으로부터 다음 각 호에서 정하는 거리 이상 띄어 건축하여야 한다.<개정 2014.4.18.>1. 삭제<2014.4.18.>2. 높이 10미터 이하인 부분 : 인접 대지경계선으로부터 1.5미터 이상<개정 2014.4.18.><개정 2023.12.26.>3. 높이 10미터를 초과하는 부분 : 인접 대지경계선으로부터 해당 건축물 각 부분 높이의 2분의 1 이상<개정 2014.4.18.><개정 2023.12.26.>② 영 제86조제3항에 따른 다세대주택의 경우에는 채광을 위한 창문 등이 있는 벽면에서 부터 직각 방향으로 인접 대지경계선까지의 수평거리 2미터 이상을 띄어 건축하여야 한다.<개정 2014.4.18.><개정 2017.9.25.>③ 삭제<2017.9.25.>④ 법 제61조제4항에 따라 2층 이하로서 높이가 8미터 이하인 건축물에는 다음 각 호의 어느 하나에 해당하는 경우에는 제1항을 적용하지 아니한다.<개정 2014.4.18.>1. 정북방향으로 도로, 공원, 광장, 하천, 철도 등 건축이 금지된 공지에 접하는 대지인 경우<개정 2014.4.18.>2. 정북방향으로 접하고 있는 대지의 소유자와 합의한 경우⑤ 영 제86조제3항제2호에 따라 공동주택은 다음 각 호의 기준에 적합하게 거리 이상을 띄어 건축하여야 한다.<개정 2009.11.10.><개정 2016.7. 25.>1. 채광을 위한 창문 등이 있는 벽면으로부터 직각 방향으로 건축물 각 부분 높이의 0.7배(도시형 생활주택의 경우에는 0.4배) 이상2. 제1호에도 불구하고 서로 마주보는 건축물 중 높은 건축물(높은 건축물을 중심으로 마주보는 두 동의 축이 시계방향으로 정동에서 정서 방향인 경우만 해당한다)의 주된 개구부(거실과 주된 침실이 있는 부분의 개구부를 말한다)의 방향이 낮은 건축물을 향하는 경우에는 10미터 이상으로서 낮은 건축물 각 부분의 높이의 0.7배(도시형 생활주택의 경우에는 0.4배) 이상<개정 2022.4.13.>'),
#  Document(id='2019611_clause_39', metadata={'자치법규ID': '2019611', '자치법규명': '가평군 건축 조례', '자치법규일련번호': '2028113', '지자체기관명': '경기도 가평군', '시행일자': '20250409', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '3296', '전화번호': '031-580-2395', '담당부서명': '건설도시국 건축과', '자치법규발의종류': '', '공포일자': '20250409', '약어': {}, 'links': [{'전통시장 및 상점가 육성을 위한 특별법': ['제53조'], '전통시장 및 상점가 육성을 위한 특별법 시행령': ['제31조']}]}, page_content='[제5장 대지와 건축물의 관계] 제32조(건축물의 높이제한 특례) 「전통시장 및 상점가 육성을 위한 특별법」제53조 및 같은 법 시행령 제31조에 따라 일반주거지역이나 준주거지역 및 준공업지역에 위치한 시장이 시장정비사업으로 공동주택을 갖춘 복합형 상가건물을 건축하는 경우에 건축물의 각 부분의 높이는 그 부분의 채광을 위한 창문 등이 있는 벽면으로 부터 직각 방향으로 인접대지 경계선까지의 수평거리의 4배로 건축하여야 한다.<개정 2014.4.18.>'),
# ...
#  Document(id='2211263_clause_4', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {'영': '건축물관리법 시행령'}, 'links': [{'건축물관리법 시행령': ['제8조제1항제1호'], '다중이용업소의 안전관리에 관한 특별법 시행령': ['제2조제1호부터 제8호까지']}]}, page_content='제4조(정기점검 대상) 「건축물관리법 시행령」(이하“영”이라 한다) 제8조제1항제1호에서 “조례로 정하는 건축물”이란 연면적이 2천제곱미터 이상인 건축물로서 「다중이용업소의 안전관리에 관한 특별법 시행령」제2조제1호부터 제8호까지의 업소 중 영업장 면적이 1천제곱미터 이상인 건축물을 말한다.'),
#  Document(id='2211263_clause_5', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {'구조전문위원회': '거제시 건축구조전문위원회'}, 'links': [{'건축물관리법 시행령': ['제9조제1항제2호'], '거제시 건축 조례': ['제5조의2']}]}, page_content='제5조(긴급점검 대상) 영 제9조제1항제2호에서“조례로 정하는 경우”란 기초 침하, 좌굴, 그 밖에 구조적 손상 등으로 건축물의 안전이 의심되는 경우로서 「거제시 건축 조례」제5조의2에 따른 거제시 건축구조전문위원회(이하 “구조전문위원회”라 한다)의 자문 결과 점검이 필요하다고 인정하는 경우를 말한다.'),
#  Document(id='2211263_clause_6', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법': ['제15조제1항제1호', '제13조', '제14조'], '시설물의 안전 및 유지관리에 관한 특별법': ['제7조'], '도시 및 주거환경정비법': ['제2조'], '건축물관리법 시행령': ['제10조제1항제7호']}]}, page_content='제6조(소규모 노후 건축물등 점검 대상)① 법 제15조제1항제1호에서“조례로 정하는 규모의 건축물”이란 3층 이하로서 연면적 1천제곱미터 이하인 건축물 중 구조전문위원회의 자문 결과 점검이 필요하다고 인정되는 경우를 말한다. 다만, 다음 각 호의 어느 하나에 해당하는 건축물은 제외한다.1. 법 제13조 및 제14조에 따른 정기점검 및 긴급점검대상 건축물2. 「시설물의 안전 및 유지관리에 관한 특별법」제7조에 따른 시설물3. 「도시 및 주거환경정비법」 제2조에 따른 정비구역 내 조합 설립인가를 받은 건축물② 영 제10조제1항제7호에서 “조례로 정하는 건축물”이란 다음 각호와 같다.<개정 2022.7.7.>1. 석축·옹벽 등에 인접하여 건축된 건축물로서 구조안전의 확보가 곤란할 것으로 우려되는 건축물2. 20년이 경과된 노후 굴뚝'),
#  Document(id='2211263_clause_7', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법 시행령': ['제11조제1항제2호']}]}, page_content='제7조(안전진단 대상) 영 제11조제1항제2호에서 “조례로 정하는 경우”란 다음 각 호의 어느 하나에 해당하는 경우를 말한다.1. 구조전문위원회의 자문 결과 구조안전성능 저하가 우려되는 경우2. 관할 소방서의 점검 결과 화재안전성능 저하가 우려되어 안전 진단 요청이 있을 경우'),
#  Document(id='2211263_clause_8', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법 시행령': ['제21조제1항제3호'], '건축법': ['제83조']}]}, page_content='제8조(건축물 해체신고 대상) 영 제21조제1항제3호에서 “조례로 정하는 건축물”이란 「건축법」 제83조에 따른 축조신고 대상 공작물을 말한다.'),
#  Document(id='2211263_clause_9', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법': ['제30조제2항제1호', '제30조제2항제2호', '제30조제2항제3호'], '유통산업발전법': ['제2조제3호']}]}, page_content='제8조의2(건축물 해체의 허가 대상)① 법 제30조제2항제1호에 따라 “해당 건축물 주변의 일정 반경 내에 조례로 정하는 시설이 있는 경우”란 해당 건축물 외벽으로부터 5미터 이내에 다음 각 호의 어느 하나에 해당하는 시설물이 있는 경우를 말한다.1. 버스 정류장2. 횡단보도3. 육교 및 지하도 출입구② 법 제30조제2항제2호에 따라 “조례로 정하는 폭 이상의 도로가 있는 경우”란 해당 건축물의 외벽으로부터 건축물의 높이에 해당하는 범위 내에 폭이 20미터 이상인 도로가 있는 경우를 말한다.③ 법 제30조제2항제3호에 따라 “조례로 정하는 경우”란 해당 건축물의 대지와 「유통산업발전법」 제2조제3호에 따른 대규모점포가 접한 경우를 말한다.<신설 2022.7.7.>'),
#  Document(id='2211263_clause_10', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법 시행령': ['제23조제4호']}]}, page_content='제9조(해체공사감리자 교체) 영 제23조제4호에서 “조례로 정하는 경우”란 다음 각 호의 어느 하나에 해당하는 경우를 말한다.1. 해체공사감리자가 감리와 관련하여 관리자 등에게 계약한 대가 이외의 금품을 요구 또는 수수한 경우2. 해체공사감리자의 직무태만·품위손상 및 그 밖의 사유로 해체공사감리자로 적합하지 아니하다고 시장이 인정하는 경우'),
#  Document(id='2211263_clause_11', metadata={'자치법규ID': '2211263', '자치법규명': '거제시 건축물관리 조례', '자치법규일련번호': '1715199', '지자체기관명': '경상남도 거제시', '시행일자': '20220707', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1945', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20220707', '약어': {}, 'links': [{'건축물관리법 시행령': ['제31조제5항'], '감정평가 및 감정평가사에 관한 법률': ['제2조제4호', '제33조']}]}, page_content='제10조(빈 건축물 정비 감정평가법인등의 선정) 시장은 영 제31조제5항에 따라 감정평가법인등(「감정평가 및 감정평가사에 관한 법률」제2조제4호에 따른 감정평가법인등을 말한다)을 선정할 때에는 「감정평가 및 감정평가사에 관한 법률」제33조에 따른 한국감정평가사협회에 추천을 의뢰하여 추천받은 자를 감정평가법인등으로 선정할 수 있다.'),
#  Document(id='2022362_clause_1', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제1조(목적) 이 조례는 도시 경관향상 및 녹지공간 확보를 위한 건축물 옥상녹화의 지원 및 관리 등에 필요한 사항을 규정함을 목적으로 한다.'),
#  Document(id='2022362_clause_2', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {'건축물': '「건축법」제2조제1항제2호에서 규정하는 건축물', '옥상유효면적': '사람의 출입 및 이용 가능한 건축물의 지붕에서 승강기탑, 계단탑, 장식탑, 물탱크, 냉각탑, 태양 전지판 등 건축물 관리에 필요한 설비 설치면적을 제외한 면적', '옥상조경': '이 조례에서 정하는 옥상녹화와 조경시설', '옥상녹화': '식물생육이 부적합한 불투수층의 건축물의 옥상(屋上)이나 지붕 등의 인공지반(이하 “옥상”이라 한다) 위에 자연지반과 유사하게 토양층을 새롭게 형성하여 그 위에 생태적ㆍ기능적ㆍ심미적인 경관을 조성하기 위하여 식물을 이용하여 식생공간을 만드는 것을', '조경시설': '환경 친화적으로 사람들이 편리하게 휴식(休息)ㆍ여가(餘暇)에 이용할 수 있도록 파고라·벤치·정자(亭子: 벽이 없고 기둥과 지붕만 있는 건물)·환경조형물·보행통로·정원석·수경, 그 밖에 이와 비슷한 시설과 생태연못, 동물 이동통로 및 먹이공급시설 등 생물의 서식처 조성과 관련된 생태적 시설로서 옥상녹화에 부수되는 시설', '관리책임자': '옥상조경을 설치한 건축주(소유자 포함) 또는 관리주체'}, 'links': [{'건축법': ['제2조제1항제2호']}]}, page_content='제2조(정의) 이 조례에서 사용하는 용어의 뜻은 다음 각 호와 같다.1. “건축물”이란「건축법」제2조제1항제2호에서 규정하는 건축물을 말한다.2. “옥상유효면적”이란 사람의 출입 및 이용 가능한 건축물의 지붕에서 승강기탑, 계단탑, 장식탑, 물탱크, 냉각탑, 태양 전지판 등 건축물 관리에 필요한 설비 설치면적을 제외한 면적을 말한다.3. “옥상조경”이란 이 조례에서 정하는 옥상녹화와 조경시설을 말한다.4. “옥상녹화”란 식물생육이 부적합한 불투수층의 건축물의 옥상(屋上)이나 지붕 등의 인공지반(이하 “옥상”이라 한다) 위에 자연지반과 유사하게 토양층을 새롭게 형성하여 그 위에 생태적ㆍ기능적ㆍ심미적인 경관을 조성하기 위하여 식물을 이용하여 식생공간을 만드는 것을 말한다.5. “조경시설”이란 환경 친화적으로 사람들이 편리하게 휴식(休息)ㆍ여가(餘暇)에 이용할 수 있도록 파고라·벤치·정자(亭子: 벽이 없고 기둥과 지붕만 있는 건물)·환경조형물·보행통로·정원석·수경, 그 밖에 이와 비슷한 시설과 생태연못, 동물 이동통로 및 먹이공급시설 등 생물의 서식처 조성과 관련된 생태적 시설로서 옥상녹화에 부수되는 시설을 말한다.6. “관리책임자”란 옥상조경을 설치한 건축주(소유자 포함) 또는 관리주체를 말한다.'),
#  Document(id='2022362_clause_3', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제3조(적용 범위) 이 조례는 시 행정구역 내에서 건축 중이거나 이미 건축된 건축물에 대하여 해당 조례에 규정된 건축물만 적용한다.'),
#  Document(id='2022362_clause_4', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'기타': ['제7조제2항', '제1항']}]}, page_content='제4조(지원계획의 수립)① 시장은 효율적인 옥상녹화사업의 추진을 위하여 보조금 지원계획을 수립·시행하여야 한다.② 시장은 옥상녹화사업의 보조금 지원계획을 수립하고자 하는 때에는 제7조제2항에 따라 제출된 옥상녹화사업의 보조금지원 신청자료를 기초로 한다.③ 시장은 제1항에 따라 지원계획을 수립한 때에는 보조금 지원신청자에게 그 사실을 통지하여야 한다.'),
#  Document(id='2022362_clause_5', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제5조(지원대상) 옥상녹화사업의 지원대상은 다음 각 호와 같다.1. 병원, 복지ㆍ문화 시설 등 시민의 활용도와 공공성이 높은 건축물2. 어린이집, 유치원 등의 체험학습장으로 활용이 가능한 건축물3. 시민의 자유로운 출입이 가능하고 옥상녹화 활용도가 높은 상업용ㆍ업무용 건축물4. 그 밖에 시장이 필요하다고 인정하는 건축물'),
#  Document(id='2022362_clause_6', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'건축법': ['제42조']}]}, page_content='제6조(옥상녹화 기준 등)① 옥상녹화사업의 건축물 옥상녹화 기준은 다음 각 호와 같다.1. 옥상유효면적이 100제곱미터 이상이면 옥상유효면적의 50제곱미터 이상2. 옥상유효면적이 100제곱미터 미만이면 옥상유효면적의 2분의 1 이상(최소면적은 30제곱미터로 한다)② 보조금의 지원은 옥상녹화사업계획서에 따른 옥상녹화 사업비의 100분의 50 이내로 지원하되, 예산의 범위에서 조정하여 지원할 수 있다. 다만, 건축허가를 받아 설치하는「건축법」제42조에 따른 법정 의무조경과 옥상조경 중 조경시설에 대해서는 지원하지 아니한다.'),
#  Document(id='2022362_clause_7', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제7조(옥상녹화사업 지원 신청)① 시장은 옥상녹화사업의 보조금 지원 신청에 필요한 사항을 시공보, 인터넷 등을 통하여 공고하여야 한다.② 보조금의 지원 신청은 별지 제1호서식의 옥상녹화사업 보조금지원신청서에 따른다.'),
#  Document(id='2022362_clause_8', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'기타': ['제7조제2항', '제5조 각 호']}]}, page_content='제8조(지원대상자의 선정)① 시장은 제7조제2항에 따라 제출된 보조금지원신청서를 기초로 파급효과와 주변여건 등을 감안하여 제5조 각 호에 따라 순위(각 호의 선순번을 우선한다)를 부여하고 예산의 범위에서 지원대상자를 선정한다.② 옥상녹화사업 지원대상자를 선정할 때에는 다음 각 호를 고려하여야 한다.1. 이 조례와 예산의 목적에의 적합 여부2. 보조사업 내용의 적정 여부3. 보조금 지원의 필요성, 타당성4. 옥상녹화 사업비 산정의 적합 여부5. 옥상녹화계획서, 옥상조경사업의 효과6. 자부담 능력③ 보조금의 교부 대상은 옥상조경계획에 따라 옥상조경을 하더라도 해당 건축물의 구조안전에 영향을 주지 아니하는 건축물에 한정한다.'),
#  Document(id='2022362_clause_9', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제9조(옥상녹화 식재기준) 건축물의 옥상녹화를 하는 때에는 옥상유효면적, 설계적재하중, 각종 설비나 유지ㆍ관리 조건, 이용목적 등을 감안하여 가능한 넓은 면적을 확보하여야 하며, 조경 식재기준은 다음 각 호와 같다.1. 조경에 따른 하중이 설계적재하중을 넘지 않도록 한다.2. 녹지는 식목 등을 유지ㆍ육성하는 식재토양 및 배수층 등으로 구성한다.3. 식재토양은 토양 중에 수분이 충분히 유지 가능한 자재를 사용하고, 식재하는 수종의 높이에 따라 토양의 두께 또는 지지대를 확보한다.4. 토양의 건조를 방지하기 위하여 지피식물이나 덩굴식물 등을 사용하고, 급수전 등 관수를 위한 설비를 설치하여야 한다. 또한 식물의 유지ㆍ관리나 건조에 따라 양호한 육성이 곤란하다고 예측되는 경우에는 건조에 강한 식물을 식재한다.5. 바람의 영향이 강한 장소에서는 바람이 직접 부딪치는 곳에 방풍을 위한 수벽 등을 설치하고, 지주나 뿌리받침의 지지대 등을 사용하여 뿌리의 안정을 도모한다.6. 건축물이나 공중에 위해(危害)가 발생하지 않도록 한다.'),
#  Document(id='2022362_clause_10', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'기타': ['제1항', '제2항', '제3항', '별지 제2호서식', '별지 제3호서식', '별지 제4호서식']}]}, page_content='제10조(보조금의 교부 신청 및 결정)① 건축물의 관리책임자가 옥상녹화를 위하여 필요한 사업비를 보조 받고자 하는 때에는 별지 제2호서식의 옥상녹화사업의 보조금 교부신청서와 별지 제3호서식의 옥상녹화사업계획서에 다음 각 호의 서류를 붙여 시장에게 제출하여야 한다.1. 건축사 또는 건축구조기술사가 확인한 해당 건축물 구조안전 확인서2. 옥상녹화사업을 시행할 수 있는 권리를 증명하는 서류3. 옥상녹화도면(조경계획배치도, 식재계획서), 시방서, 설계예산서② 시장은 제1항의 신청서가 제출된 날부터 7일 이내에 보조금의 교부 여부를 결정하고, 별지 제4호서식의 보조금교부결정서를 건축물의 관리책임자에게 통지하여야 한다.③ 시장은 제2항에 따른 보조금의 교부를 결정함에 있어 이 조례와 예산이 정하는 보조금의 교부 목적을 달성함에 필요한 조건을 붙일 수 있다.'),
#  Document(id='2022362_clause_11', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'기타': ['제10조제1항', '제12조']}]}, page_content='제11조(옥상녹화사업의 계획 변경)① 관리책임자는 보조금 지원 결정통지를 받은 옥상녹화사업의 계획을 변경하려면 변경하기 전에 시장에게 신고하여야 한다. 이 경우 옥상녹화사업의 변경에 관하여는 제10조제1항을 준용한다. 다만, 다음 각 호의 어느 하나에 해당하는 경미한 사항의 변경은 그러하지 아니하다.1. 옥상녹화를 위한 식생공간 면적의 100분의 5 이하의 면적 변경2. 옥상녹화의 식재 토심 두께의 100분의 10 이하의 변경② 제1항 각 호에서 정하는 경미한 사항의 변경은 제12조에 따른 옥상녹화사업완료서를 제출할 때 옥상녹화사업변경계획서를 함께 제출하여야 한다.'),
#  Document(id='2022362_clause_12', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제12조(보조사업의 신고) 관리책임자는 다음 각 호의 어느 하나에 해당하는 사유가 발생하였을 때에는 지체 없이 시장에게 신고하여야 한다.1. 보조사업이 시작되었거나 완료되었을 때2. 보조사업을 폐지하였을 때3. 관리책임자가 해산 또는 파산하였을 때'),
#  Document(id='2022362_clause_13', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제13조(보조금 교부)① 관리책임자는 옥상녹화를 위한 식생공간사업의 공사를 마친 때에는 시장에게 별지 제5호서식의 옥상녹화사업완료서를 제출하여야 한다.② 시장은 제1항에 따른 옥상녹화사업완료서를 받으면 14일 이내에 관리책임자에게 해당 보조금을 교부하여야 한다.'),
#  Document(id='2022362_clause_14', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제14조(유지ㆍ관리)① 옥상녹화의 관리기간 및 관리책임은 다음 각 호와 같으며, 옥상녹화사업 후 물주기, 잡초제거작업 등 사후관리는 관리책임자의 책임으로 한다.1. 옥상녹화사업 후 관리기간은 보조금 지급일로부터 5년으로 한다.2. 관리기간 내에 고사목 등 하자 발생 시는 관리책임자가 책임 보수하도록 한다.② 시장은 옥상녹화에 대하여 연 1회 이상 유지ㆍ관리실태를 조사하여야 하며, 그 결과를 별지 제6호서식의 옥상조경 시설대장에 기록ㆍ관리하여야 한다.'),
#  Document(id='2022362_clause_15', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제15조(감독) 시장은 보조금의 적정한 집행을 위하여 필요하다고 인정할 때에는 보조금을 교부받은 자에게 보조사업에 관한 보고를 하게 할 수 있으며, 시 소속 공무원으로 하여금 관계 장부ㆍ서류 또는 그 사업내용을 검사하게 하거나 감독상 필요한 처분을 할 수 있다.'),
#  Document(id='2022362_clause_16', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}, 'links': [{'국토교통부 고시 『조경기준』': [], '거제시 지방보조금 관리조례': []}]}, page_content='제16조(준용) 이 조례에서 규정하지 아니한 조경기준에 관한 사항은 국토교통부 고시 『조경기준』, 보조금 지원에 관한 사항은 「거제시 지방보조금 관리조례」를 준용한다. <개정 2015.1.7. 2017.11.9.>'),
#  Document(id='2022362_clause_17', metadata={'자치법규ID': '2022362', '자치법규명': '거제시 건축물 옥상녹화 지원 조례', '자치법규일련번호': '1310905', '지자체기관명': '경상남도 거제시', '시행일자': '20171109', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '1599', '전화번호': '055-639-4733', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20171109', '약어': {}}, page_content='제17조(시행규칙) 이 조례의 시행에 필요한 사항은 규칙으로 정한다.'),
#  Document(id='2022363_clause_1', metadata={'자치법규ID': '2022363', '자치법규명': '거제시 건축 조례', '자치법규일련번호': '2081407', '지자체기관명': '경상남도 거제시', '시행일자': '20250925', '제개정정보': '일부개정', '자치법규종류': 'C0001', '공포번호': '2301', '전화번호': '055-639-4673', '담당부서명': '건축과', '자치법규발의종류': '', '공포일자': '20250925', '약어': {}, 'links': [{'건축법': [], '건축법 시행령': [], '건축법 시행규칙': [], '전통시장 및 상점가 육성을 위한 특별법': [], '전통시장 및 상점가 육성을 위한 특별법 시행령': []}]}, page_content='[제1장  총    칙] 제1조(목적) 이 조례는 「건축법」,「건축법 시행령」, 「건축법 시행규칙」,「전통시장 및 상점가 육성을 위한 특별법」,「전통시장 및 상점가 육성을 위한 특별법 시행령」에서 위임한 사항과 그 시행에 필요한 사항을 규정함을 목적으로 한다.<개정 2009.12.9, 2013.12.6>'),
#  ...]

# %%
print(documents[0].metadata["자치법규명"])
print(documents[0].metadata["지자체기관명"])
print(documents[0].metadata["약어"])
print(documents[0].metadata["links"])
print(documents[0].page_content)
# Out:
# 가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례
# 경기도 가평군
# {}
# [{'자연재해대책법': ['제27조제2항']}]
# 제1조(목적) 이 조례는 「자연재해대책법」 제27조제2항의 규정에 따라 건축물관리자의 제설·제빙에 관한 사항을 구체적으로 정함으로써 눈 또는 얼음으로 인한 주민의 불편을 최소화하고, 안전을 꾀함을 목적으로 한다.

# %%
id_list = []
idx_list = []
for i in range(len(documents)):
    idx = documents[i].metadata["자치법규ID"]
    if idx not in id_list:
        id_list.append(idx)
        idx_list.append(i)

# %%
idx_list[:2]
# Out:
# [0, 9]

# %%
x = idx_list[0]
y = idx_list[1]
content = "자치법규명: " + documents[x].metadata["자치법규명"] + "\n"
content += "지자체기관명: " + documents[x].metadata["지자체기관명"] + "\n법규 내용:\n"
for z in range(x,y):
    content += documents[z].page_content + "\n"
print(content)
# Out:
# 자치법규명: 가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례
# 지자체기관명: 경기도 가평군
# 법규 내용:
# 제1조(목적) 이 조례는 「자연재해대책법」 제27조제2항의 규정에 따라 건축물관리자의 제설·제빙에 관한 사항을 구체적으로 정함으로써 눈 또는 얼음으로 인한 주민의 불편을 최소화하고, 안전을 꾀함을 목적으로 한다.
# 제2조(정의) 이 조례에서 사용하는 용어의 뜻은 다음과 같다. <개정 2017.7.31.>1. “도로”라 함은 「도로법」에 따른 도로, 그 밖에 일반 교통에 사용되는 모든 곳을 말한다.2. “차도”라 함은 연석선(차도와 보도를 구분하는 돌 등으로 이어진 선을 말한다), 안전표지, 그 밖에 이와 비슷한 공작물로써 그 경계를 표시하여 모든 차의 교통에 사용하도록 된 도로의 부분을 말한다.3. “보도(步道)”라 함은 연석선, 안전표지, 그 밖에 이와 비슷한 공작물로써 그 경계를 표시하여 보행자(유모차 및 신체장애인용 의자차를 포함한다)의 통행에 사용하도록 되어있는 도로의 부분을 말한다. <개정 2017.3.6.>4. “이면도로”라 함은 「도로법」에 따른 고속국도ㆍ일반국도ㆍ지방도ㆍ군도 및 농어촌도로(「농어촌도로정비법」에 따른 도로를 말한다)가 아닌 일반의 교통에 사용되는 도로로서 차도와 보도의 구분이 없는 폭 12미터 미만의 도로를 말한다.5. “보행자전용도로”라 함은 보행자만이 다닐 수 있도록 안전표지 및 그 밖에 이와 비슷한 공작물로써 표시한 도로를 말한다.6. “제설ㆍ제빙작업”이라 함은 도로상의 눈 또는 얼음을 제거하거나 녹게 하는 재료 및 모래 등을 뿌려서 보행자와 차량의 안전한 통행에 지장이 없도록 하는 것을 말한다.7. “건축물관리자”라 함은 건축물의 소유자ㆍ점유자 또는 관리자로서 그 건축물의 관리 책임이 있는 사람을 말한다.8. “시설물의 지붕”이라 함은 「자연재해대책법 시행령」제22조의8에 따른 시설물의 지붕을 말한다. <신설 2017.7.31.>
# 제3조(건축물관리자의 제설ㆍ제빙 책임) 건축물관리자는 관리하고 있는 건축물의 대지에 접한 보도, 이면도로, 보행자전용도로, 시설물의 지붕에 대한 제설ㆍ제빙작업을 하여야 한다. <신설 2017.7.31.>
# 제4조(제설ㆍ제빙작업의 책임순위) 건축물관리자의 제설ㆍ제빙 책임순위는 다음 각 호와 같다. 다만, 건축물관리자간 합의가 된 경우에는 합의된 순위에 따른다.1. 소유자가 건축물 내에 거주하는 경우에는 소유자, 점유자 또는 관리자 순으로 한다.2. 소유자가 건축물 내에 거주하지 않는 경우에는 점유자, 관리자 또는 소유자 순으로 한다.
# 제5조(제설ㆍ제빙작업의 책임범위) 건축물관리자가 하여야 하는 제설ㆍ제빙작업의 책임범위는 다음 각 호와 같다.(별표 예시도 참조)1. 보도는 건축물의 대지에 접한 보도의 전체 구간2. 이면도로 및 보행자전용도로는 건축물의 대지에 접한 도로의 중앙선 또는 중앙부분까지의 구간3. 시설물의 지붕은 최상층의 지붕면의 구간(옥탑층이 있을 경우 옥탑층의 지붕구간도 포함한다.) 또는 여러 층에 복합적으로 지붕이 형성된 경우 모든 지붕구간 <신설 2017.7.31.>
# 제6조(제설ㆍ제빙작업의 시기) 건축물관리자는 제설ㆍ제빙작업을 눈이 그친 때부터 3시간 이내에 완료하여야 한다. 다만, 야간(일몰 후부터 다음 날 일출 전까지)에 눈이 내린 때에는 다음 날 오전 11시까지 제설ㆍ제빙작업을 완료하여야 한다.
# 제7조(제설ㆍ제빙작업의 방법) 건축물관리자는 보행자나 차량의 안전한 통행에 지장이 없도록 삽, 빗자루 등의 작업도구를 이용하여 다음 각 호와 같이 제설ㆍ제빙작업을 하여야 한다.1. 보도ㆍ이면도로 및 보행자전용도로의 눈이나 얼음 : 도로의 가장자리나 공터 등으로 옮긴다.2. 얼음 제거가 어려운 경우에는 얼음을 녹게 하는 재료나 모래 등을 사용하고, 얼음이 녹은 후에는 뿌려진 모래 등을 깨끗이 제거한다.3. 시설물의 지붕에서 발생되는 눈은 시설물의 대지 안에 옮긴다. 다만, 대지 안에 여유공간이 없을 경우 보도의 가장자리나 공터 등으로 옮긴다. <신설 2017.7.31.>
# 제8조(제설ㆍ제빙작업의 도구 비치ㆍ관리) 건축물관리자는 제설ㆍ제빙작업에 필요한 작업도구를 건축물 내에 매년 12월 1일부터 다음해 3월 15일까지 비치·관리하여야 한다. <개정 2017.7.31.>
# 제9조(시행규칙) 이 조례의 시행에 필요한 사항은 규칙으로 정한다. <개정 2017.7.31.>

# %%
system_message ="""당신은 법률 문서로부터 질의응답 데이터를 생성하는 전문가입니다.
제공된 문서의 내용을 분석하고, 사용자가 실제로 질문할 수 있는 질의(Q)와 그에 대응하는 근거 기반의 답변(A)을 생성하세요.

# Question Guidelines:
질문은 두 가지 타입으로 분류할 수 있습니다. 각각 2개씩 총 4개의 데이터셋을 생성하세요.
- 질문에는 법률명이나 조항과 같이 구체적인 항목이 명시되어 있지 않습니다.
- 실제 사용자는 어떤 문서의 어떤 부분을 참고해야 원하는 답변을 얻을 수 있는지 모른 채 질문합니다.

1. 문서 내부 기반(Intra)
- 오직 해당 문서(chunk) 내에서 답을 찾을 수 있어야 한다.
- 질문 예시: 용어 정의, 의무 주체, 책임 순서, 시기, 방법 등
- 답변은 반드시 해당 문서 내용에 근거해야 하며, 다른 법령 인용 금지.

2. 외부 참조 기반 (Cross-document)
- chunk 안에 다른 법률이나 시행령, 규칙이 언급된 경우 그 조항을 참조해야 완전한 답변이 나올 질문을 생성한다.
- 질문은 사용자가 ‘그 조항의 의미’를 묻는 형태로 만든다.
- 답변은 “이 문서에서 언급된 ○○법 제○조제○항에 따르면…”처럼 근거를 병기한다.
- `link_reference` 필드에 해당 법령명을 명시한다.

# Answer Guidelines:
- 제공된 문서에는 자치법규명, 지자체기관명이 명시되어있습니다. 반드시 "**해당 지자체**"에 대한 답변임을 명시하세요. 예) 서울특별시 종로구의 경우, ...
- 제공된 문서의 내용을 기반으로 구체적으로 작성하세요.

# Output 형식:
- `type`: "intra", "cross"
- `question`: **Question Guidelines**을 따른 사용자의 법률적 질문
- `answer`: **Answer Guidelines**을 따른 답변
- `legal_reference`: 답변에 직접적으로 근거한 조항 번호 또는 문장
- `reasoning`: 왜 이 답변이 도출되었는지 설명
- `link_reference`: 문서 내 link된 다른 법령 조항

# 주의:
- 'answer' key에 반드시 "**해당 지자체**"에 대한 답변임을 명시하세요.
- 반드시 **유효한 JSON 형식**으로 반환합니다.
- 해당하는 내용이 없다면, 빈 값으로 반환하세요. 예) "link_reference": ""
"""

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

model = ChatOllama(
    model="gpt-oss:120b-cloud",
    temperature=0.2,
    max_tokens = 1024,
    timeout=None,
    max_retries=2,
    reasoning = None,
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_message),
    ("user", "{question}")
])

chain = prompt | model

# 일반 Chain 생성
chain = prompt | model | JsonOutputParser()
chain
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 법률 문서로부터 질의응답 데이터를 생성하는 전문가입니다.\n제공된 문서의 내용을 분석하고, 사용자가 실제로 질문할 수 있는 질의(Q)와 그에 대응하는 근거 기반의 답변(A)을 생성하세요.\n\n# Question Guidelines:\n질문은 두 가지 타입으로 분류할 수 있습니다. 각각 2개씩 총 4개의 데이터셋을 생성하세요.\n- 질문에는 법률명이나 조항과 같이 구체적인 항목이 명시되어 있지 않습니다.\n- 실제 사용자는 어떤 문서의 어떤 부분을 참고해야 원하는 답변을 얻을 수 있는지 모른 채 질문합니다.\n\n1. 문서 내부 기반(Intra)\n- 오직 해당 문서(chunk) 내에서 답을 찾을 수 있어야 한다.\n- 질문 예시: 용어 정의, 의무 주체, 책임 순서, 시기, 방법 등\n- 답변은 반드시 해당 문서 내용에 근거해야 하며, 다른 법령 인용 금지.\n\n2. 외부 참조 기반 (Cross-document)\n- chunk 안에 다른 법률이나 시행령, 규칙이 언급된 경우 그 조항을 참조해야 완전한 답변이 나올 질문을 생성한다.\n- 질문은 사용자가 ‘그 조항의 의미’를 묻는 형태로 만든다.\n- 답변은 “이 문서에서 언급된 ○○법 제○조제○항에 따르면…”처럼 근거를 병기한다.\n- `link_reference` 필드에 해당 법령명을 명시한다.\n\n# Answer Guidelines:\n- 제공된 문서에는 자치법규명, 지자체기관명이 명시되어있습니다. 반드시 "**해당 지자체**"에 대한 답변임을 명시하세요. 예) 서울특별시 종로구의 경우, ...\n- 제공된 문서의 내용을 기반으로 구체적으로 작성하세요.\n\n# Output 형식:\n- `type`: "intra", "cross"\n- `question`: **Question Guidelines**을 따른 사용자의 법률적 질문\n- `answer`: **Answer Guidelines**을 따른 답변\n- `legal_reference`: 답변에 직접적으로 근거한 조항 번호 또는 문장\n- `reasoning`: 왜 이 답변이 도출되었는지 설명\n- `link_reference`: 문서 내 link된 다른 법령 조항\n\n# 주의:\n- \'answer\' key에 반드시 "**해당 지자체**"에 대한 답변임을 명시하세요.\n- 반드시 **유효한 JSON 형식**으로 반환합니다.\n- 해당하는 내용이 없다면, 빈 값으로 반환하세요. 예) "link_reference": ""\n'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='{question}'), additional_kwargs={})])
# | ChatOllama(model='gpt-oss:120b-cloud', temperature=0.2)
# | JsonOutputParser()

# %%
output = chain.invoke({"question": content})
output
# Out:
# [{'type': 'intra',
#   'question': '가평군 건축물관리자 조례에서 “제설ㆍ제빙작업”이란 무엇인가요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 “제설ㆍ제빙작업”을 도로상의 눈 또는 얼음을 제거하거나 녹게 하는 재료 및 모래 등을 뿌려서 보행자와 차량의 안전한 통행에 지장이 없도록 하는 행위로 정의하고 있습니다.',
#   'legal_reference': '제2조(정의) 6.',
#   'reasoning': '조례 제2조 제6항에 ‘제설ㆍ제빙작업’의 정의가 명시되어 있어, 해당 조항을 직접 인용하여 답변을 도출했습니다.',
#   'link_reference': ''},
#  {'type': 'intra',
#   'question': '가평군 건축물관리자는 눈이 그친 후 언제까지 제설·제빙작업을 완료해야 하나요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 건축물관리자가 눈이 그친 때부터 3시간 이내에 제설·제빙작업을 완료하도록 규정하고 있으며, 야간에 눈이 내린 경우에는 다음 날 오전 11시까지 완료하도록 정하고 있습니다.',
#   'legal_reference': '제6조(제설ㆍ제빙작업의 시기)',
#   'reasoning': '조례 제6조에 눈이 그친 시점과 야간에 눈이 내린 경우의 완료 시한이 구체적으로 규정되어 있어, 이를 근거로 답변을 작성했습니다.',
#   'link_reference': ''},
#  {'type': 'intra',
#   'question': '가평군 건축물관리자는 제설·제빙에 필요한 작업도구를 언제부터 언제까지 비치·관리해야 하나요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 건축물관리자가 매년 12월 1일부터 다음 해 3월 15일까지 제설·제빙에 필요한 작업도구를 건축물 내에 비치·관리하도록 규정하고 있습니다.',
#   'legal_reference': '제8조(제설ㆍ제빙작업의 도구 비치ㆍ관리)',
#   'reasoning': '조례 제8조에 도구 비치·관리 기간이 명시되어 있어, 해당 조항을 직접 인용해 답변을 구성했습니다.',
#   'link_reference': ''},
#  {'type': 'cross',
#   'question': '조례에서 정의하고 있는 “도로”는 도로법에 따라 어떻게 정의되나요?',
#   'answer': '해당 지자체인 경기도 가평군 조례 제2조(정의) 1에 따르면, “도로”는 「도로법」에 따른 도로와 그 밖에 일반 교통에 사용되는 모든 곳을 의미합니다. 즉, 도로법이 규정하는 도로와 일반 교통이 이루어지는 모든 구역을 포함합니다.',
#   'legal_reference': '제2조(정의) 1.',
#   'reasoning': '조례는 ‘도로’의 의미를 도로법에 의존하고 있음을 명시하고 있으므로, 도로법의 정의를 참고해야 정확한 의미를 파악할 수 있습니다.',
#   'link_reference': '도로법'},
#  {'type': 'cross',
#   'question': '조례에서 언급된 “시설물의 지붕”은 자연재해대책법 시행령 제22조의8에 따라 어떤 대상을 말하나요?',
#   'answer': '해당 지자체인 경기도 가평군 조례 제2조(정의) 8에 따르면, “시설물의 지붕”은 「자연재해대책법 시행령」 제22조의8이 규정하는 시설물의 지붕을 의미합니다. 즉, 자연재해대책법 시행령에서 정의한 건축물·시설물의 상부 구조물(지붕) 전체를 포함합니다.',
#   'legal_reference': '제2조(정의) 8.',
#   'reasoning': '조례는 ‘시설물의 지붕’ 정의를 자연재해대책법 시행령 제22조의8에 의존하고 있으므로, 해당 시행령 조항을 참조해야 정확한 의미를 알 수 있습니다.',
#   'link_reference': '자연재해대책법 시행령 제22조의8'},
#  {'type': 'cross',
#   'question': '조례에서 “이면도로”의 정의에 포함되지 않는 도로는 어떤 법령에 의해 규정되나요?',
#   'answer': '해당 지자체인 경기도 가평군 조례 제2조(정의) 4에 따르면, “이면도로”는 「도로법」에 따른 고속국도·일반국도·지방도·군도 및 「농어촌도로정비법」에 따른 농어촌도로가 아닌, 차도와 보도의 구분이 없는 폭 12미터 미만의 일반 교통용 도로를 의미합니다. 따라서 고속국도·일반국도·지방도·군도·농어촌도로는 ‘이면도로’에 포함되지 않으며, 이는 도로법 및 농어촌도로정비법에 의해 규정됩니다.',
#   'legal_reference': '제2조(정의) 4.',
#   'reasoning': '조례는 ‘이면도로’를 정의하면서 도로법과 농어촌도로정비법에 해당하는 도로들을 제외하고 있음을 명시하고 있으므로, 해당 외부 법령을 참고해야 정확한 범위를 이해할 수 있습니다.',
#   'link_reference': '도로법, 농어촌도로정비법'}]

# %%
output[0]
# Out:
# {'type': 'intra',
#  'question': '가평군 건축물관리자 조례에서 “제설ㆍ제빙작업”이란 무엇인가요?',
#  'answer': '해당 지자체인 경기도 가평군에서는 “제설ㆍ제빙작업”을 도로상의 눈 또는 얼음을 제거하거나 녹게 하는 재료 및 모래 등을 뿌려서 보행자와 차량의 안전한 통행에 지장이 없도록 하는 행위로 정의하고 있습니다.',
#  'legal_reference': '제2조(정의) 6.',
#  'reasoning': '조례 제2조 제6항에 ‘제설ㆍ제빙작업’의 정의가 명시되어 있어, 해당 조항을 직접 인용하여 답변을 도출했습니다.',
#  'link_reference': ''}

# %%
x = idx_list[0]
y = idx_list[1]
content = "자치법규명: " + documents[x].metadata["자치법규명"] + "\n"
content += "지자체기관명: " + documents[x].metadata["지자체기관명"] + "\n법규 내용:\n"
for z in range(x,y):
    content += documents[z].page_content + "\n"
output = chain.invoke({"question": content})

# %%
{"자치법규ID":documents[x].metadata["자치법규ID"],
 "자치법규명": documents[x].metadata["자치법규명"]}

# %%
# 결과 저장용 리스트
output = []

# 인덱스 페어 순회
# for i in range(len(idx_list) - 1):
for i in range(100):
    x = idx_list[i]
    y = idx_list[i + 1]

    # 콘텐츠 구성
    content = (
        "자치법규명: " + documents[x].metadata["자치법규명"] + "\n"
        + "지자체기관명: " + documents[x].metadata["지자체기관명"] + "\n"
        + "법규 내용:\n"
    )

    for z in range(x, y):
        content += documents[z].page_content + "\n"
    # LLM 호출
    result = chain.invoke({"question": content})
    print(result)

    # result가 리스트인 경우, 각 항목에 법규 ID/명 추가
    if isinstance(result, list):
        for r in result:
            r["자치법규ID"] = documents[x].metadata.get("자치법규ID", "")
            r["자치법규명"] = documents[x].metadata.get("자치법규명", "")
            output.append(r)
    else:
        # 만약 단일 객체로 나왔다면 그 자체를 래핑
        result["자치법규ID"] = documents[x].metadata.get("자치법규ID", "")
        result["자치법규명"] = documents[x].metadata.get("자치법규명", "")
        output.append(result)
# Out:
# [{'type': 'intra', 'question': '건축물관리자는 눈이 그친 뒤 제설·제빙 작업을 언제까지 완료해야 하나요?', 'answer': '경기도 가평군의 건축물관리자는 눈이 그친 시점부터 3시간 이내에 제설·제빙 작업을 완료해야 합니다. 다만, 야간(일몰 후부터 다음 날 일출 전까지)에 눈이 내린 경우에는 다음 날 오전 11시까지 작업을 마쳐야 합니다.', 'legal_reference': '제6조(제설ㆍ제빙작업의 시기)', 'reasoning': '조례 제6조에 ‘건축물관리자는 제설ㆍ제빙작업을 눈이 그친 때부터 3시간 이내에 완료하여야 한다. 다만, 야간에 눈이 내린 경우에는 다음 날 오전 11시까지 완료하여야 한다.’고 명시되어 있어, 해당 조항을 직접 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '제설·제빙 작업에 대한 책임순위는 어떻게 정해져 있나요?', 'answer': '경기도 가평군에서는 건축물관리자 간의 제설·제빙 책임순위가 다음과 같이 정해져 있습니다. ① 소유자가 건축물 내에 거주하는 경우에는 소유자 → 점유자 → 관리자 순으로 책임이 부여됩니다. ② 소유자가 건축물 내에 거주하지 않는 경우에는 점유자 → 관리자 → 소유자 순으로 책임이 부여됩니다. 단, 건축물관리자 간에 합의가 있으면 합의된 순위가 적용됩니다.', 'legal_reference': '제4조(제설ㆍ제빙작업의 책임순위)', 'reasoning': '조례 제4조에 책임순위에 대한 구체적인 규정이 명시되어 있어, 해당 조항을 그대로 인용해 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘도로’라는 용어는 이 조례에서 어떻게 정의되고, 도로법과는 어떤 관계가 있나요?', 'answer': '경기도 가평군의 이 조례에서 ‘도로’는 제2조(정의) 1항에 따라 “도로법에 따른 도로, 그 밖에 일반 교통에 사용되는 모든 곳”으로 정의됩니다. 즉, 도로법이 규정하는 도로를 포함하고, 그 외에 일반 교통에 이용되는 모든 구역도 도로로 간주됩니다.', 'legal_reference': '제2조(정의) 1항', 'reasoning': '조례 제2조에서 ‘도로’의 정의를 직접 제시하고 있으며, 정의문 안에 ‘도로법에 따른 도로’라는 표현이 포함되어 있어 도로법과의 관계를 명확히 알 수 있습니다.', 'link_reference': '도로법'}, {'type': 'cross', 'question': '‘시설물의 지붕’이란 무엇이며, 자연재해대책법 시행령 제22조의8은 어떤 내용을 담고 있나요?', 'answer': '경기도 가평군의 이 조례에서 ‘시설물의 지붕’은 제2조(정의) 8항에 따라 “자연재해대책법 시행령 제22조의8에 따른 시설물의 지붕”으로 정의됩니다. 자연재해대책법 시행령 제22조의8은 시설물의 지붕을 자연재해에 대비해 관리·보호해야 할 대상으로 규정하고 있으며, 이 조례는 그 정의를 그대로 적용하고 있습니다.', 'legal_reference': '제2조(정의) 8항', 'reasoning': '조례 제2조 8항에서 ‘시설물의 지붕’이 자연재해대책법 시행령 제22조의8에 의거한다는 문구가 명시되어 있어, 해당 시행령 조항을 참조해야 완전한 의미 파악이 가능합니다.', 'link_reference': '자연재해대책법 시행령 제22조의8'}]
# [{'type': 'intra', 'question': '가평군 건축물관리 조례의 목적은 무엇인가요?', 'answer': '해당 지자체인 경기도 가평군의 건축물관리 조례는 「건축물관리법」, 같은 법 시행령 및 같은 법 시행규칙에서 조례로 정하도록 위임된 사항과 그 시행에 필요한 사항을 규정함을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’ 항목으로 조례가 규정하고자 하는 범위와 목표가 명시되어 있어, 해당 조항만으로 목적을 정확히 알 수 있다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군 건축물관리 조례에서 지정된 건축물관리점검기관을 지정할 수 없을 경우 군수는 어떤 절차를 밟아야 하나요?', 'answer': '해당 지자체인 경기도 가평군의 경우, 군수는 제8조 제2항에 따라 지정할 수 없는 경우 즉시 도지사에게 통보해야 합니다.', 'legal_reference': '제8조(건축물관리점검기관의 지정 등)②', 'reasoning': '조례 제8조 제2항에 ‘군수는 제1항의 각 호에 따라 건축물관리점검기관을 지정할 수 없을 경우 즉시 경기도지사에게 통보해야 한다’는 규정이 직접 명시되어 있다.', 'link_reference': ''}, {'type': 'cross', 'question': '정기점검 대상이 되는 건축물은 어떤 외부 규정에 따라 정의되나요?', 'answer': '이 문서에서 언급된 건축물관리법 시행령 제8조제1항제1호에 따르면, ‘조례로 정하는 건축물’은 다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목 등에서 정한 용도로 사용되는 바닥면적의 합계가 1천 제곱미터 이상인 건축물을 말합니다. 따라서 가평군에서는 해당 시행령에 따라 정기점검 대상 건축물을 판단합니다.', 'legal_reference': '제4조(정기점검 대상)', 'reasoning': '조례 제4조는 정기점검 대상 건축물을 정의하면서 직접 ‘건축물관리법 시행령 제8조제1항제1호’를 인용하고 있다. 따라서 정답은 해당 시행령 조항을 근거로 해야 한다.', 'link_reference': '건축물관리법 시행령 제8조제1항제1호'}, {'type': 'cross', 'question': '해체공사감리자를 지정할 때 적용되는 외부 규정은 무엇이며, 지정이 제한되는 경우는 어떤 경우인가요?', 'answer': '이 문서에서 언급된 건축물관리법 시행령 제22조에 따라 해체공사감리자를 지정합니다. 해당 시행령에 따르면, 업무정지·휴업 중인 자, 2회 이상 지정 거부한 자, 건축사사무소를 폐업하거나 자격을 반납한 자, 건설기술용역사업자 등록이 취소된 자, 지정 제외를 요청한 자, 그리고 계약 대가 이외의 금품·이익을 요구·수수한 자는 해체공사감리자로 지정할 수 없습니다.', 'legal_reference': '제10조(건축물 해체공사감리자의 지정 등)①', 'reasoning': '조례 제10조는 해체공사감리자 지정 기준을 명시하면서 ‘건축물관리법 시행령 제22조’에 근거하고 있다. 따라서 외부 규정과 제한 사유는 해당 시행령 조항을 인용해 설명한다.', 'link_reference': '건축물관리법 시행령 제22조'}]
# [{'type': 'intra', 'question': '가평군 건축 조례의 목적은 무엇인가요?', 'answer': '해당 지자체인 경기도 가평군의 건축 조례는 「건축법」·「건축법 시행령」·「건축법 시행규칙」에서 조례로 정하도록 위임된 사항과 그 시행에 필요한 사항을 정함을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 목적은 제1조에 명시되어 있으며, 해당 조문을 그대로 인용하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군 건축위원회의 위원장은 누가 맡으며, 어떻게 선출되나요?', 'answer': '해당 지자체인 경기도 가평군의 건축위원회 위원장은 업무 담당국장이 위원장으로 지정되며, 부위원장은 위원 중에서 선출됩니다.', 'legal_reference': '제6조(구성) 제2항', 'reasoning': '위원장의 직무와 선출 방법은 제6조 제2항에 규정되어 있어, 해당 조문을 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘건축조례로 정하는 비율’이란 무엇이며, 어느 법령에 근거를 두고 있나요?', 'answer': '해당 지자체인 경기도 가평군에서는 ‘건축조례로 정하는 비율’이 건축법 시행령 제6조제2항에 따라 140% 이하로 정해져 있습니다. 즉, 건축법 시행령이 해당 비율의 기준을 제공합니다.', 'legal_reference': '제3조(적용의 완화) 제3항', 'reasoning': '조례 본문에서 ‘건축조례로 정하는 비율’이 건축법 시행령 제6조제2항에 따라 140% 이하라고 명시하고 있으므로, 이를 근거로 답변을 구성했습니다.', 'link_reference': '건축법 시행령'}, {'type': 'cross', 'question': '조경 면적을 면제받을 수 있는 건축물은 어떤 경우이며, 그 근거가 되는 조례와 외부 법령은 무엇인가요?', 'answer': '해당 지자체인 경기도 가평군에서는 연면적이 2천㎡ 이상인 건축물이라도 건축법 시행령 제27조제1항제5호 및 제10호에 해당하는 경우(예: 전통시장 형태의 도매·소매시장 안의 건축물, 학교·군사시설·교정시설 등)에는 조경 등을 하지 않아도 됩니다. 따라서 조경 면제 기준은 조례 제24조와 건축법 시행령 제27조를 함께 적용합니다.', 'legal_reference': '제24조(대지의 조경) 제2항', 'reasoning': '조례 제24조 제2항에서 조경 면제 사유를 규정하고 있으며, 해당 사유는 건축법 시행령 제27조제1항제5호·제10호에 명시되어 있어 두 조문을 함께 인용해 답변을 만들었습니다.', 'link_reference': '건축법 시행령'}]
# [{'type': 'intra', 'question': '건축심의를 신청하려면 어떤 서류들을 제출해야 하나요?', 'answer': '경기도 가평군에서는 건축심의를 신청하고자 하는 자가 별지 제1호서식의 심의신청서와 함께 다음 9가지 서류를 첨부하여 군수에게 제출하도록 규정하고 있습니다. 1) 건축계획서, 2) 색채계획서(그래픽배치도, 색채개요, 선정색채, 색채계획), 3) 투시도 또는 조감도, 4) 위치도 및 계획대지 주변현황(계획대지 주변 100미터 이내 건축물의 높이·규모·배치·벽면 선 및 입면전개도), 5) 배치도, 6) 평면도, 7) 입면도, 8) 주단면도(구조계획 설명 포함), 9) 대지조성 및 토지굴착계획서(길이 10미터 이상의 토지굴착공사 또는 높이 5미터 이상의 옹벽 등의 공사를 수반하는 경우).', 'legal_reference': '제3조(건축심의 신청 서류)①', 'reasoning': '문서의 제3조에 건축심의 신청 시 제출해야 할 서류 목록이 구체적으로 열거되어 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군 소위원회는 어떻게 구성되며, 위원장은 누구에 의해 지정되나요?', 'answer': '경기도 가평군 소위원회는 가평군 건축위원회 위원장을 포함하여 최대 6명 이내의 위원으로 구성됩니다. 위원장은 위원 중에서 위원장이 지명하는 자가 되며, 위원은 위원장이 지명하는 건축사 1명, 군의회의원 1명, 관계공무원 1명, 여성 1명으로 구성됩니다.', 'legal_reference': '제5조(소위원회의 구성)①, ②', 'reasoning': '제5조에 소위원회의 구성 인원수와 위원장의 지정 절차가 명시되어 있어, 이를 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '업무대행수수료를 청구하려면 건축법 제27조제1항이 어떤 의미를 갖나요?', 'answer': '경기도 가평군에서는 제8조에 따라 현장조사·검사 및 확인업무를 대행한 자가 건축법 제27조제1항에 근거하여 군수에게 업무대행수수료를 청구할 수 있습니다. 건축법 제27조제1항은 대행업무에 대한 수수료 청구권을 인정하고 있으므로, 이 조항에 따라 가평군도 동일하게 수수료 청구가 가능함을 의미합니다.', 'legal_reference': '제8조(업무대행수수료 청구)', 'reasoning': '문서의 제8조는 건축법 제27조제1항을 근거로 수수료 청구를 규정하고 있으므로, 해당 법 조문의 의미를 설명함으로써 답변을 완성했습니다.', 'link_reference': '건축법 제27조제1항'}, {'type': 'cross', 'question': '건축지도원을 지정하려면 법 제37조제1항이 어떤 요건을 제시하고 있나요?', 'answer': '경기도 가평군에서는 제11조에 따라 군수가 건축지도원을 지정하려면 법 제37조제1항이 요구하는 요건을 충족해야 합니다. 건축법 제37조제1항은 건축지도원의 자격 및 지정 절차에 관한 기본 요건을 규정하고 있으며, 가평군은 조례 제23조제1항에 따른 적격성을 검정하여 해당 요건을 만족하는 자를 지정하도록 하고 있습니다.', 'legal_reference': '제11조(건축지도원의 지정)', 'reasoning': '제11조는 건축법 제37조제1항을 근거로 건축지도원 지정 요건을 명시하고 있으므로, 해당 법 조문의 의미를 설명하여 답변을 구성했습니다.', 'link_reference': '건축법 제37조제1항'}]
# [{'type': 'intra', 'question': '가평군 군계획 조례는 어떤 목적을 가지고 제정되었나요?', 'answer': '해당 지자체인 경기도 가평군의 군계획 조례는 「국토의 계획 및 이용에 관한 법률」 및 그 시행령·시행규칙 등에서 조례로 정하도록 한 사항과 그 시행에 필요한 사항을 규정함을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘이 조례는 … 조례로 정하도록 한 사항과 그 시행에 필요한 사항을 규정함을 목적으로 한다’라고 명시되어 있어 목적을 직접 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군 군계획 조례에 따라 군기본계획을 수립·승인하는 주체는 누구입니까?', 'answer': '해당 지자체인 경기도 가평군에서는 군수(가평군수)가 군기본계획을 수립하고, 경기도지사의 승인을 받아야 합니다.', 'legal_reference': '제3조(군기본계획의 위상)', 'reasoning': '조례 제3조에 ‘군수(이하 “군수”라 한다)가 수립하는 … 군기본계획은 … 경기도지사의 승인을 받은 군기본계획은 …’이라고 규정하고 있어 주체를 명확히 알 수 있습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '공청회를 개최할 때 공고해야 하는 매체와 시기는 어떻게 정해져 있나요?', 'answer': '해당 지자체인 경기도 가평군에서는 공청회를 개최할 경우, 「국토의 계획 및 이용에 관한 법률 시행령」 제12조제1항 각 호의 사항에 따라 일간신문 2곳 이상, 군보, 군 인터넷 홈페이지 및 군청·읍·면사무소 게시판에 공청회 개최예정일 14일 전까지 1회 이상 공고해야 합니다.', 'legal_reference': '제5조(공청회 개최방법)①', 'reasoning': '조례 제5조는 공청회 공고 방법을 구체적으로 규정하고 있으며, 해당 조항에서 ‘영 제12조제1항 각 호의 사항을 … 14일 전까지 1회 이상 공고’라고 명시하고 있어 외부 법령(국토의 계획 및 이용에 관한 법률 시행령)과 연계된 요구사항을 확인할 수 있습니다.', 'link_reference': '국토의 계획 및 이용에 관한 법률 시행령'}, {'type': 'cross', 'question': '군기본계획을 수립하고자 할 때 별도의 추진기구를 운영할 수 있는 근거는 어디에 있나요?', 'answer': '해당 지자체인 경기도 가평군에서는 군기본계획을 수립하고자 할 경우, 「국토의 계획 및 이용에 관한 법률」 제18조에 따라 별도의 추진기구를 한시적으로 운영할 수 있습니다.', 'legal_reference': '제4조(추진기구 및 자문단 운영)①', 'reasoning': '조례 제4조는 ‘법 제18조에 따라 군기본계획을 수립하고자 하는 경우에는 별도의 추진기구를 한시적으로 운영할 수 있다’고 규정하고 있어, 외부 법령(국토의 계획 및 이용에 관한 법률 제18조)과 직접 연결됩니다.', 'link_reference': '국토의 계획 및 이용에 관한 법률'}]
# [{'type': 'intra', 'question': '가평군 녹색건축물 조성 지원 조례에서 “녹색건축물”이란 무엇으로 정의하고 있나요?', 'answer': '해당 지자체인 경기도 가평군의 조례 제2조(정의) 제1호에 따르면 “녹색건축물”이란 「녹색건축물 조성 지원법」 제2조제1호에 따른 건축물을 말합니다.', 'legal_reference': '제2조 제1호', 'reasoning': '조례의 제2조(정의) 항목에서 용어별 정의를 명시하고 있으며, 1번 항목이 바로 ‘녹색건축물’의 정의이므로 해당 조문을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군 녹색건축물 조성 지원 조례에 따라 녹색건축물 조성 지원 사업을 심의·결정하는 위원회는 누가 설치하고 운영하나요?', 'answer': '해당 지자체인 경기도 가평군의 조례 제8조에 따라 군수가 가평군 녹색건축물조성심의위원회를 설치·운영하며, 위원회의 구체적인 운영은 「가평군 건축 조례」에 따라 가평군 건축위원회가 대행합니다.', 'legal_reference': '제8조', 'reasoning': '조례 제8조는 위원회의 설치·운영 주체와 운영 방식에 대해 명시하고 있으므로, 해당 조문을 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '가평군 녹색건축물 조성 지원 조례 제5조에서 언급된 ‘법 제24조’는 어떤 내용이며, 시범사업 지정에 어떤 근거가 되나요?', 'answer': '이 문서에서 언급된 녹색건축물 조성 지원법 제24조에 따르면, 지방자치단체장은 녹색건축물에 대한 주민 인식 제고 및 조성 촉진을 위해 시범사업을 지정할 수 있습니다. 따라서 가평군은 해당 법 제24조를 근거로 제5조에서 시범사업을 지정할 수 있는 권한을 갖게 됩니다. 해당 지자체인 경기도 가평군은 이 근거에 따라 공공기관 사업, 기존주택 전환 사업 등 다양한 시범사업을 추진할 수 있습니다.', 'legal_reference': '제5조', 'reasoning': '조례 제5조는 ‘법 제24조에 따라’ 시범사업을 지정할 수 있다고 명시하고 있어, 해당 법 조문의 의미를 해석해야 정확한 근거를 제공할 수 있습니다. 따라서 법 제24조의 내용(시범사업 지정 권한)을 설명하고 조례와 연결시켰습니다.', 'link_reference': '녹색건축물 조성 지원법 제24조'}, {'type': 'cross', 'question': '가평군 녹색건축물 조성 지원 조례 제5조에서 ‘녹색건축물 조성 지원법 시행령 제17조’가 정하는 사업이란 무엇이며, 어떤 종류의 사업이 포함되나요?', 'answer': '이 문서에서 언급된 녹색건축물 조성 지원법 시행령 제17조에 따르면, 녹색건축물 전환을 위한 사업으로서 기존 주택 외의 건축물을 녹색건축물로 전환하는 사업이 포함됩니다. 따라서 가평군은 제5조에 따라 제17조에서 정하는 해당 사업을 시범사업으로 지정할 수 있습니다. 해당 지자체인 경기도 가평군은 이 조항을 근거로 기존 주택 외 건축물의 녹색전환 사업을 추진하게 됩니다.', 'legal_reference': '제5조', 'reasoning': '조례 제5조는 ‘녹색건축물 조성 지원법 시행령 제17조에서 정하는 사업’이라는 표현을 사용하고 있어, 해당 시행령 조문의 구체적 내용을 파악해야 합니다. 따라서 시행령 제17조가 정의하는 사업 범위를 설명하고 조례와 연결했습니다.', 'link_reference': '녹색건축물 조성 지원법 시행령 제17조'}]
# [{'type': 'intra', 'question': '가평군 수도급수 조례에서 “급수설비”가 어떻게 정의되어 있나요?', 'answer': '해당 지자체인 가평군에서는 급수설비를 ‘수도사업자가 일반의 수요자에게 원수 또는 정수를 공급하기 위하여 설치한 배수관으로부터 분기하여 설치된 급수관(옥내급수관을 포함한다)·계량기·저수조·수도꼭지·그 밖에 급수를 위하여 필요한 기구’를 의미합니다.', 'legal_reference': '제2조(정의) 1호', 'reasoning': '조례 제2조(정의)에서 급수설비의 구체적인 구성 요소와 의미를 명시하고 있기 때문에, 해당 조문을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '가평군에서 오래된 계량기나 동파된 계량기를 교체할 경우 비용을 누가 부담하나요?', 'answer': '해당 지자체인 가평군에서는 옥외 급수설비 및 증설 공사의 비용은 원칙적으로 신청인이 부담하지만, ‘노후 계량기 및 동파계량기의 교체’와 같은 경우는 군에서 부담하도록 규정하고 있습니다.', 'legal_reference': '제11조(공사비 부담 및 급수설비 관리) 1항 1호', 'reasoning': '제11조는 공사비 부담 주체를 구체적으로 구분하고 있으며, 1호에 ‘노후 계량기 및 동파계량기의 교체’가 군 부담으로 명시돼 있어 이를 근거로 답변했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '수도법 제14조제3항이 규정하는 급수공사에 사용되는 자재의 기준은 무엇인가요?', 'answer': '해당 지자체인 가평군에서는 급수공사에 사용되는 자재가 ‘수도법 제14조제3항 및 같은 법 시행령 제24조의2가 정한 기준에 적합해야 한다’고 규정하고 있습니다. 즉, 자재는 수도법이 정한 품질·안전 기준을 충족해야 하며, 이를 위반할 경우 공사 승인이 제한될 수 있습니다.', 'legal_reference': '제9조(공사의 시행) 2항', 'reasoning': '조례 제9조(공사의 시행) 2항에서 급수공사에 사용되는 자재는 수도법 제14조제3항 및 시행령 제24조의2의 기준에 적합해야 한다고 명시하고 있어, 해당 법 조문을 근거로 답변을 구성했습니다.', 'link_reference': '수도법 제14조제3항'}, {'type': 'cross', 'question': '계량에 관한 법률이 규정하는 사용공차 범위는 무엇이며, 가평군 수도급수 조례에서는 어떻게 적용되나요?', 'answer': '해당 지자체인 가평군에서는 ‘수도계량기의 이상이 계량에 관한 법률이 정한 사용공차 범위를 초과할 경우, 그 월분의 사용량 및 요금을 정정하고 과부족이 있을 경우 환급·추징·다음 달 요금 정산 등을 할 수 있다’고 규정하고 있습니다. 즉, 계량에 관한 법률이 정한 허용 오차를 초과하면 조례에 따라 요금 정정 및 보상이 이루어집니다.', 'legal_reference': '제27조(수도계량기의 이상 시험) 2항', 'reasoning': '조례 제27조(수도계량기의 이상 시험) 2항에서 사용공차 초과 시 요금 정정 및 환급·추징 절차를 명시하고 있으며, 이는 ‘계량에 관한 법률’이 정한 사용공차 범위를 기준으로 한다고 명시돼 있어 해당 법 조문을 근거로 답변을 작성했습니다.', 'link_reference': '계량에 관한 법률'}]
# [{'type': 'intra', 'question': '제4조에 따르면 같은 제증명을 여러 사람이 동시에 신청할 경우 수수료는 어떻게 부과되나요?', 'answer': '해당 지자체인 경기도 가평군에서는 제4조 제1항 및 제2항에 따라, 같은 제증명을 2통 이상 신고하거나 신청할 때는 1통당 1건, 혹은 1명당 1건으로 수수료를 부과합니다. 다만, 가족이 같은 사항을 신청하는 경우는 예외이며, 여러 사람이 동시에 같은 공부·도면을 열람 청구할 경우에도 1명당 1건으로 수수료가 부과됩니다.', 'legal_reference': '제4조 제1항·제2항', 'reasoning': '문서 내 제4조에서 ‘제증명 등을 같은 것으로 2통 이상 신고하거나 신청할 때… 1통 또는 1명당 1건으로 하여 수수료를 징수한다’고 명시하고 있으며, 예외 조항과 열람 청구에 대한 규정도 동일 조에 포함되어 있기 때문에 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '이미 납부한 수수료가 있는데 발급이 취소되거나 내용이 달라진 경우에는 어떻게 처리되나요?', 'answer': '해당 지자체인 경기도 가평군에서는 제6조에 따라, 증명이 발급되지 않은 상태에서 신청서를 취소·변경하거나, 발급된 내용이 신청 내용과 다르게 발급된 경우 이미 납부한 수수료를 전액 반환하도록 규정하고 있습니다.', 'legal_reference': '제6조', 'reasoning': '문서의 제6조는 ‘증명이 발급되지 않은 상태에서 신청한 서류를 취소·변경하는 경우와 발급내용이 신청내용과 다르게 발급된 경우에는 이미 납부한 수수료를 전액 반환한다’고 명시하고 있어, 해당 조항을 직접 인용해 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘지방자치법 제156조제1항 단서’에 따라 전국적 통일이 필요한 수수료는 어떤 기준을 적용하나요?', 'answer': '해당 지자체인 경기도 가평군은 제3조 제1호에서 ‘지방자치법 제156조제1항 단서에 따른 전국적 통일이 필요한 수수료의 징수기준에 관한 규정’에 따라 정해진 별표를 그대로 적용합니다. 즉, 전국적으로 통일된 기준에 따라 수수료를 산정하고, 별표에 명시된 금액을 그대로 징수합니다.', 'legal_reference': '제3조 제1호', 'reasoning': '문서의 제3조 제1호는 ‘지방자치법 제156조제1항 단서에 따른 … 규정’에서 정한 수수료는 규정 별표를 따른다고 명시하고 있습니다. 따라서 해당 조항을 근거로 외부 법령(지방자치법)과 그 시행규칙을 참조해야 완전한 답변이 됩니다.', 'link_reference': '지방자치법 제156조제1항 단서'}, {'type': 'cross', 'question': '‘전자정부법 제7조’에 따라 전자적으로 민원처리 시 수수료를 징수할 수 있는 방법은 무엇인가요?', 'answer': '해당 지자체인 경기도 가평군은 제5조 제2항에서 ‘전자정부법 제7조에 따라 전자적으로 민원처리 하는 경우 정보통신망을 이용하여 전자화폐·전자결제 등의 방법으로 수수료를 징수할 수 있다’고 규정하고 있습니다. 따라서 전자정부법 제7조가 허용하는 전자화폐, 전자결제, 신용카드 등 다양한 전자결제 수단을 이용해 수수료를 징수할 수 있습니다.', 'legal_reference': '제5조 제2항', 'reasoning': '문서의 제5조 제2항은 전자정부법 제7조를 직접 인용하며, 전자민원 처리 시 정보통신망을 이용한 전자화폐·전자결제 등으로 수수료를 징수할 수 있다고 명시하고 있습니다. 따라서 외부 법령(전자정부법)과의 연계가 필요한 답변이 됩니다.', 'link_reference': '전자정부법 제7조'}]
# [{'type': 'intra', 'question': '제설·제빙 작업은 눈이 그친 시점부터 언제까지 완료해야 하나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시에서는 건축물관리자가 눈이 그친 때부터 4시간 이내에 제설·제빙 작업을 완료하도록 규정하고 있습니다. 다만, 야간(일몰 후부터 다음날 일출 전까지)에 눈이 내린 경우에는 다음날 낮 12시까지 작업을 마쳐야 합니다.', 'legal_reference': '제5조(제설·제빙 작업의 시기)', 'reasoning': '문서의 제5조에 제설·제빙 작업을 완료해야 하는 시기가 명시되어 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '건축물관리자가 해야 할 제설·제빙 작업의 구체적인 범위는 어떻게 정해져 있나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시에서는 건축물관리자가 보도의 전체 구간, 이면도로 및 보행자 전용도로는 건축물 대지경계선으로부터 1미터까지, 그리고 시설물의 지붕에 대해 제설·제빙 작업을 해야 한다고 규정하고 있습니다.', 'legal_reference': '제4조(제설·제빙 작업의 책임범위)', 'reasoning': '문서의 제4조에 각 작업 대상과 그 범위가 구체적으로 열거되어 있어, 이를 직접 인용하여 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '자연재해대책법 제27조제2항은 이 조례의 목적에 어떤 근거를 제공하나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시에서는 자연재해대책법 제27조제2항에서 위임된 건축물관리자의 제설·제빙 책임범위를 구체화하기 위해 이 조례를 제정했습니다. 즉, 자연재해대책법이 건축물관리자에게 제설·제빙 의무를 부여하고, 이를 상세히 규정하기 위한 근거법으로 작용하고 있습니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례 제1조는 자연재해대책법 제27조제2항을 근거로 삼아 조례 목적을 명시하고 있으므로, 해당 법 조항이 조례의 근거임을 확인할 수 있습니다.', 'link_reference': '자연재해대책법 제27조제2항'}, {'type': 'cross', 'question': '도로법 제2조제1호에서 정의하는 ‘도로’는 이 조례에서 어떻게 적용되나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시에서는 도로법 제2조제1호에서 정의한 ‘도로’를 제2조(정의)에서 “도로”란 도로법 제2조제1호를 말한다는 규정으로 채택하고 있습니다. 따라서 조례에서 ‘도로’라는 용어가 사용될 때는 도로법이 정의한 의미와 동일하게 적용됩니다.', 'legal_reference': '제2조(정의) 1항', 'reasoning': '조례 제2조는 ‘도로’라는 용어의 정의를 도로법 제2조제1호에 의존한다고 명시하고 있어, 도로법의 정의가 조례에 직접 반영된다는 점을 근거로 답변을 작성했습니다.', 'link_reference': '도로법 제2조제1호'}]
# [{'type': 'intra', 'question': '강원특별자치도 강릉시에서 정기점검을 받게 되는 건축물은 어떤 기준을 만족해야 하나요?', 'answer': '강원특별자치도 강릉시에서는 연면적이 3,000제곱미터 이상이며, 다중이용업소 중 영업장 면적이 1,000제곱미터 이상인 건축물을 정기점검 대상 건축물로 정하고 있습니다.', 'legal_reference': '제4조', 'reasoning': '조례 제4조에 ‘정기점검’ 항목에서 연면적 3천제곱미터 이상인 건축물과 다중이용업소 중 영업장 면적이 1천제곱미터 이상인 건축물을 명시하고 있기 때문에 해당 기준을 직접 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도 강릉시에서 긴급점검이 필요하다고 판단되는 경우는 누가 결정하나요?', 'answer': '강원특별자치도 강릉시에서는 구조전문위원회의 자문 결과 점검이 필요하다고 인정되는 경우와 강릉시장이 건축물의 안전 확보를 위해 점검이 필요하다고 판단하는 경우에 긴급점검 대상이 됩니다.', 'legal_reference': '제5조', 'reasoning': '조례 제5조에 긴급점검 대상에 해당하는 두 가지 경우(구조전문위원회 자문, 시장 판단)를 명시하고 있어, 이를 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘건축물관리법 시행령 제8조제1항제1호’가 강원특별자치도 강릉시 정기점검 대상 건축물의 정의에 어떤 의미가 있나요?', 'answer': '‘건축물관리법 시행령 제8조제1항제1호’는 정기점검 대상 건축물을 ‘연면적 3천제곱미터 이상인 건축물 중 다중이용업소의 영업장 면적이 1천제곱미터 이상인 경우’로 정의하고 있습니다. 강원특별자치도 강릉시 조례는 이 시행령 조항을 그대로 적용하여 정기점검 대상 건축물을 규정하고 있습니다.', 'legal_reference': '제4조', 'reasoning': '조례 제4조에서 정기점검 대상 건축물의 정의를 제시하면서 ‘건축물관리법 시행령 제8조제1항제1호’를 인용하고 있으므로, 해당 시행령 조항의 의미를 설명하는 것이 답변에 필요합니다.', 'link_reference': '건축물관리법 시행령 제8조제1항제1호'}, {'type': 'cross', 'question': '‘건축법 제20조제3항’은 강원특별자치도 강릉시에서 건축물 해체 신고 대상에 어떤 영향을 미치나요?', 'answer': '‘건축법 제20조제3항’은 해체 행위가 수반되는 축조신고 대상 가설건축물을 규정하고 있습니다. 강원특별자치도 강릉시 조례 제8조는 이 조항을 근거로 하여, 해당 가설건축물(해체 행위가 수반되는 경우)을 해체 신고 대상에 포함시키고 있습니다.', 'legal_reference': '제8조', 'reasoning': '조례 제8조에서 건축물 해체의 신고 대상에 ‘건축법 제20조제3항에 따른 축조신고 대상 가설건축물’이 포함된다고 명시하고 있어, 해당 법 조문의 의미를 설명해야 완전한 답변이 됩니다.', 'link_reference': '건축법 제20조제3항'}]
# [{'type': 'intra', 'question': '강릉시 건축위원회는 몇 명 이상의 위원으로 구성되어야 하나요?', 'answer': '강릉시 건축위원회는 위원장 1명과 부위원장 1명을 포함하여 최소 25명, 최대 150명 이하의 위원으로 구성되어야 합니다. 이는 강릉시 건축 조례 제3조(건축위원회의 구성 등)②에 명시되어 있습니다.', 'legal_reference': '제3조(건축위원회의 구성 등)②', 'reasoning': '조례 제3조는 위원회의 구성 인원 수와 위원장·부위원장의 포함 여부를 구체적으로 규정하고 있으므로, 해당 조문을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강릉시 건축위원회는 심의 요청을 받은 경우 언제까지 회의를 개최해야 하나요?', 'answer': '강릉시 건축위원회는 심의 접수일부터 30일 이내에 회의를 개최해야 합니다. 이는 강릉시 건축 조례 제6조(건축위원회의 회의 등)⑤에 규정되어 있습니다.', 'legal_reference': '제6조(건축위원회의 회의 등)⑤', 'reasoning': '조례 제6조는 심의대상 건축물에 대한 회의 소집 시한을 명시하고 있으므로, 해당 조문을 직접 인용해 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '건축법 제4조제1항이 강릉시 건축위원회 설립에 어떤 근거를 제공하나요?', 'answer': '강릉시 건축 조례 제3조(건축위원회의 구성 등)①에 따르면, "건축법 제4조제1항에 따라 시에 건축위원회를 둔다"고 명시되어 있습니다. 따라서 건축법 제4조제1항은 지방자치단체가 건축위원회를 설치할 수 있는 법적 근거를 제공하며, 강릉시가 이를 조례로 구체화한 것입니다.', 'legal_reference': '제3조(건축위원회의 구성 등)①', 'reasoning': '조례 제3조는 건축법 제4조제1항을 직접 인용하여 위원회 설치 근거를 명시하고 있으므로, 해당 조문을 근거로 답변을 구성했습니다.', 'link_reference': '건축법'}, {'type': 'cross', 'question': '주택법 제15조가 강릉시 건축위원회의 심의대상에 어떤 건축물을 포함시키는지 설명해 주세요.', 'answer': '강릉시 건축 조례 제4조(건축위원회의 심의대상)①에 따르면, "주택법 제15조에 따른 사업계획승인 대상 건축물 중 150세대 이상인 건축물" 및 "주택법 제15조제1항 단서에 해당하는 주택 외의 시설과 주택을 동일 건축물로 건축하는 건축물 중 150세대 이상이거나 연면적 합계가 5,000㎡ 이상인 건축물" 등이 심의대상에 포함됩니다. 이는 주택법 제15조가 대규모 주거사업을 정의하고, 해당 조례가 이를 구체적으로 적용한 것입니다.', 'legal_reference': '제4조(건축위원회의 심의대상)①', 'reasoning': '조례 제4조는 주택법 제15조를 인용하여 심의대상 건축물의 구체적 요건을 규정하고 있으므로, 해당 조문을 근거로 답변을 작성했습니다.', 'link_reference': '주택법'}]
# [{'type': 'intra', 'question': '강릉시가 도시기본계획에 대한 공청회를 개최하려면 언제까지 어떤 내용을 공고해야 하나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시는 도시기본계획에 대한 공청회를 개최하고자 할 경우, 공청회 개최 예정일 14일 전까지 개최목적, 개최예정일시 및 장소, 수립 또는 변경하고자 하는 도시기본계획의 개요 등 그 밖에 필요한 사항을 1회 이상 공고하고, 시보, 시 홈페이지, 읍·면사무소 및 동 주민센터 게시판 등을 통해 주민에게 알려야 합니다.', 'legal_reference': '제5조(도시기본계획의 수립을 위한 공청회 개최방법 등)②', 'reasoning': '문서의 제5조 제2항에 공청회 공고 시기와 내용이 명시되어 있어, 해당 조항만으로 답을 도출할 수 있다.', 'link_reference': ''}, {'type': 'intra', 'question': '강릉시 도시계획위원회의 위원장은 누구이며, 그 직무는 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도 강릉시의 도시계획위원회 위원장은 부시장이며, 위원장은 회의를 소집하고 의장을 맡는 등 위원회의 업무를 총괄합니다.', 'legal_reference': '제65조(구성)②', 'reasoning': '제65조 제2항에 위원장의 직위와 역할이 직접 규정되어 있어, 해당 조항만으로 답을 구성하였다.', 'link_reference': ''}, {'type': 'cross', 'question': '『국토의 계획 및 이용에 관한 법률』 제3조가 규정하는 기본원칙은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도 강릉시의 국토이용 및 관리는 『국토의 계획 및 이용에 관한 법률』 제3조의 기본원칙을 바탕으로 자연환경의 보전과 자원의 효율적 활용을 통하여 환경적으로 건전하고 지속가능한 발전을 이루면서 접근성·편의성·안정성을 고려한 도시계획을 수립·집행하는 것을 기본방향으로 합니다.', 'legal_reference': '제2조(국토이용 및 관리의 기본방향) – 해당 조문에서 법 제3조의 기본원칙을 언급함', 'reasoning': '조례 제2조는 강릉시가 국토의 계획 및 이용에 관한 법률 제3조의 기본원칙을 근거로 한다고 명시하고 있으므로, 해당 법률 조항의 의미를 설명하기 위해 조례를 근거로 답변한다.', 'link_reference': '국토의 계획 및 이용에 관한 법률'}, {'type': 'cross', 'question': '『국토의 계획 및 이용에 관한 법률 시행령』 제12조제4항은 공청회 개최 시 어떤 절차를 정하고 있나요?', 'answer': '해당 지자체인 강원특별자치도 강릉시에서는 도시기본계획에 대한 공청회를 개최하고자 할 경우, 『국토의 계획 및 이용에 관한 법률 시행령』 제12조제4항에 따라 미리 도시계획위원회의 의견을 청취할 수 있으며, 이는 공청회 개최 전 절차로 규정되어 있습니다.', 'legal_reference': '제5조(도시기본계획의 수립을 위한 공청회 개최방법 등)① – 시행령 제12조제4항을 언급', 'reasoning': '조례 제5조 제1항에서 시행령 제12조제4항에 따라 공청회 전 절차가 필요함을 명시하고 있으므로, 해당 시행령 조항의 의미를 설명하기 위해 조례를 근거로 답변한다.', 'link_reference': '국토의 계획 및 이용에 관한 법률 시행령'}]
# [{'type': 'intra', 'question': '강릉시에서 급수공사를 직접 시공할 경우와 시공업자를 지정하여 위탁시공할 경우, 착공 기한은 각각 어떻게 정해져 있나요?', 'answer': '해당 지자체인 강릉시에서는 급수공사를 직접 시공할 경우에는 공사비 납부일부터 7일 이내에 착공해야 하며, 시공업자를 지정하여 위탁시공할 경우에는 공사계약 체결 후 3일 이내에 착공해야 합니다.', 'legal_reference': '제9조 제4항', 'reasoning': '제9조(공사의 시행) 제4항에 ‘급수공사는 시장이 직접 시공할 경우는 공사비 납부일부터 7일 이내에, 시공업자가 시공할 경우는 공사계약 후 3일 이내에 착공하는 것을 원칙으로 한다’고 명시되어 있어 해당 답을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강릉시에서 공용급수설비를 설치하거나 사용할 수 있도록 허가하려면 어떤 조건을 충족해야 하나요?', 'answer': '해당 지자체인 강릉시에서는 시장이 필요하다고 인정하는 경우에만 공용급수설비의 설치 또는 사용을 허가할 수 있으며, 필요하다고 인정될 경우에는 수익자 부담으로 설치·사용하게 할 수 있습니다.', 'legal_reference': '제8조 제1항', 'reasoning': '제8조(공용급수설비의 설치 등) 제1항에 ‘시장 필요시 공용급수설비의 설치·사용을 허가하고, 필요시 수익자 부담으로 할 수 있다’는 규정이 있어 답을 도출했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '수도법 제38조는 강릉시 급수조정에 어떤 내용을 규정하고 있나요?', 'answer': '해당 지자체인 강릉시에서는 수도법 제38조에 따라 수도사업자의 물 공급 및 관리에 관한 기본 원칙을 정하고 있으며, 이는 강릉시가 급수설비와 요금 등을 적정하게 관리하도록 하는 근거가 됩니다.', 'legal_reference': '제1조', 'reasoning': '제1조(목적)에서 ‘수도법 제38조’를 근거법으로 명시하고 있어, 해당 조항의 내용이 강릉시 급수조정에 적용된다는 점을 근거로 답을 구성했습니다.', 'link_reference': '수도법'}, {'type': 'cross', 'question': '지방공기업법 제22조는 강릉시 급수공사의 어떤 부분을 규정하고 있나요?', 'answer': '해당 지자체인 강릉시에서는 지방공기업법 제22조에 따라 지방공기업이 수행하는 급수공사의 운영·관리 및 재정지원 등에 관한 사항을 규정하고 있어, 강릉시가 급수공사를 효율적으로 수행하도록 하는 법적 근거가 됩니다.', 'legal_reference': '제1조', 'reasoning': '제1조(목적)에서 ‘지방공기업법 제22조’를 근거법으로 언급하고 있기 때문에, 해당 조항이 강릉시 급수공사의 운영·관리와 관련된 규정을 제공한다는 점을 근거로 답을 작성했습니다.', 'link_reference': '지방공기업법'}]
# [{'type': 'intra', 'question': '건축기본계획에 포함되어야 하는 주요 내용은 무엇인가요?', 'answer': '강원특별자치도는 건축기본계획에 다음과 같은 사항을 포함하도록 정하고 있습니다. 1) 건축정책의 기본목표 및 추진방향, 2) 건축 현황 및 여건 변화·전망에 관한 사항, 3) 도시 및 농산어촌 경관 향상을 위한 통합된 건축디자인에 관한 사항, 4) 건축 발전 및 지원 대책, 5) 건축기본법 제7조부터 제9조까지의 시책 구현에 관한 사항, 6) 건축문화 기반 구축에 관한 사항, 7) 우수한 건축물·공간환경의 보존 및 관리에 관한 사항, 8) 건축문화 진흥을 위한 홍보·주민참여 방안, 9) 건축디자인 등 건축의 국제경쟁력 향상에 관한 사항, 10) 한옥의 보전 및 진흥에 관한 사항, 11) 건축디자인 시범사업 지정에 관한 사항, 12) 그 밖에 도지사가 필요하다고 인정하는 사항.', 'legal_reference': '제3조(건축기본계획의 내용 등) 제1항', 'reasoning': '문서의 제3조 제1항에 건축기본계획에 포함되어야 할 구체적인 항목들이 열거되어 있어, 이를 그대로 나열하였다.', 'link_reference': ''}, {'type': 'intra', 'question': '건축디자인조정위원회의 위원장은 어떻게 선출되나요?', 'answer': '강원특별자치도에서는 건축디자인조정위원회 위원장을 위원 중에서 호선(互選)하여 선출합니다.', 'legal_reference': '제7조(건축디자인조정위원회의 구성) 제1항', 'reasoning': '제7조 제1항에 위원장은 위원 중에서 호선(互選)한다고 명시되어 있어, 해당 문구를 근거로 답변하였다.', 'link_reference': ''}, {'type': 'cross', 'question': '건축기본법 시행령 제4조제2항에서 말하는 ‘경미한 사항’은 무엇을 의미하나요?', 'answer': '이 문서에서 언급된 건축기본법 시행령 제4조제2항에 따르면 ‘경미한 사항’은 건축기본계획의 기본방향에 중대한 영향을 미치지 않는 사항을 말합니다. 강원특별자치도 건축 기본 조례 제4조에서는 구체적으로 ① 제3조제1항제2호, 제6호부터 제9호까지, 제12호에 해당하는 사항, ② 그 밖에 도지사가 건축기본계획의 기본방향에 중대한 영향을 미치지 않는다고 인정하는 사항을 ‘경미한 사항’으로 정의하고 있습니다.', 'legal_reference': '제4조(건축기본계획의 경미한 사항) 제1항', 'reasoning': '문서의 제4조는 건축기본법 시행령 제4조제2항에서 사용되는 ‘경미한 사항’의 구체적 정의를 제공하고 있다. 따라서 외부 법령의 의미를 설명하기 위해 해당 조례 조항을 근거로 삼았다.', 'link_reference': '건축기본법 시행령 제4조제2항'}, {'type': 'cross', 'question': '건축정책위원회는 어떤 법적 근거에 따라 설치되나요?', 'answer': '이 문서에서 언급된 건축기본법 제18조제1항에 따라 강원특별자치도는 건축정책위원회를 설치합니다. 강원특별자치도 건축 기본 조례 제5조(건축정책위원회 설치 등) 제1항에서도 ‘도지사는 법 제18조제1항에 따라 강원특별자치도건축정책위원회를 둔다’고 규정하고 있어, 해당 법적 근거에 따라 위원회가 설치됩니다.', 'legal_reference': '제5조(건축정책위원회 설치 등) 제1항', 'reasoning': '조례 제5조는 건축정책위원회의 설치 근거를 건축기본법 제18조제1항이라고 명시하고 있다. 따라서 위원회의 법적 근거를 설명하기 위해 두 조항을 함께 인용하였다.', 'link_reference': '건축기본법 제18조제1항'}]
# [{'type': 'intra', 'question': '건축물관리점검기관이 등재사항이 변경된 경우 언제까지 도지사에게 신고해야 합니까?', 'answer': '강원특별자치도에서는 건축물관리점검기관이 등재사항이 변경된 경우, 그 사유가 발생한 날부터 30일 이내에 건축물 생애이력 정보체계를 통해 변경사항을 증명하는 서류를 첨부하여 도지사에게 신고해야 합니다.', 'legal_reference': '제6조(건축물관리점검기관의 관리)①', 'reasoning': '문서의 제6조 제1항에 ‘등재사항이 변경된 경우에는 그 사유가 발생한 날부터 30일 이내에 … 도지사에게 신고해야 한다’고 명시되어 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도에서 건축물관리점검기관을 등재 취소할 수 있는 사유는 무엇인가요?', 'answer': '강원특별자치도에서는 다음 사유가 발생하면 건축물관리점검기관의 등재를 취소할 수 있습니다:\n1. 법 제25조제1항 각 호의 어느 하나에 해당하여 영업정지 또는 과징금 처분을 받은 경우\n2. 국토교통부장관, 도지사 또는 시장·군수가 폐업 사실을 확인한 경우\n3. 영 별표 1에 따른 등재요건을 충족하지 못하게 된 날로부터 30일 이내에 보완하지 않은 경우\n4. 영 별표 1에 따른 등재요건을 충족하지 못하는 사유가 발생하여 시장·군수가 도지사에게 등재 취소를 요청한 경우', 'legal_reference': '제5조(건축물관리점검기관의 등재)④', 'reasoning': '제5조 제4항에 등재 취소 사유가 네 가지로 구체적으로 규정되어 있어, 이를 그대로 열거하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '건축물관리점검기관을 지정하려면 어떤 절차와 서류가 필요하며, 해당 절차는 어떤 법령에 근거하고 있나요?', 'answer': '강원특별자치도에서는 건축물관리점검기관을 지정하려면, 먼저 법 제18조제1항 및 「건축물관리법 시행령」 제12조제4항에 따라 등재명부에서 무작위 추출 방식으로 지정하는 것이 원칙이며, 긴급한 경우에는 해당 지역의 기관을 우선 지정할 수 있습니다. 지정이 이루어지면, 법 제19조 및 같은 법 시행규칙 제7조에 따라 건축물관리점검기관과 관리자에게 별지 제3호서식을 통보해야 합니다. 이 절차는 「건축물관리법」 제18조제1항과 「건축물관리법 시행령」 제12조제4항에 근거합니다.', 'legal_reference': '제7조(건축물관리점검기관의 지정 등)①,②', 'reasoning': '문서의 제7조는 지정 절차와 관련된 법령(법 제18조제1항, 영 제12조제4항, 법 제19조, 시행규칙 제7조)을 명시하고 있으므로, 해당 조항을 근거로 외부 법령을 언급하여 답변을 구성했습니다.', 'link_reference': '건축물관리법 제18조제1항, 건축물관리법 시행령 제12조제4항'}, {'type': 'cross', 'question': '해체공사감리자를 지정할 때 무작위 추출 방식이 적용되는 근거와, 지정이 제한되는 경우는 어떤 법령에 명시되어 있나요?', 'answer': '강원특별자치도에서는 해체공사감리자를 지정할 때, 「건축물관리법 시행령」 제22조제2항에 따라 등재명부에서 무작위 추출 방식으로 지정하는 것이 원칙입니다. 다만, 다음 각 호에 해당하는 경우에는 감리자를 지정할 수 없습니다: ① 업무정지·휴업 중인 자, ② 「건축사법」 또는 「건설기술 진흥법」에 따른 감리자격을 상실하거나 반납한 자, ③ 제10조제2항에 따른 지정 연기·업무 수행 불가 사유가 있는 자, ④ 연 2회 이상 지정 거부한 자, ⑤ 금품·이익을 요구·수수한 자. 이러한 제한 사유는 「건축물관리법 시행령」 제22조제2항에 근거합니다.', 'legal_reference': '제11조(건축물 해체공사감리자의 지정 등)①', 'reasoning': '문서의 제11조는 해체공사감리자 지정 절차와 제한 사유를 명시하고 있으며, 무작위 추출 방식과 제한 사유는 「건축물관리법 시행령」 제22조제2항에 근거하고 있음을 확인하여 답변에 반영했습니다.', 'link_reference': '건축물관리법 시행령 제22조제2항'}]
# [{'type': 'intra', 'question': '강원특별자치도에서 건축주가 미술작품을 설치한 후, 설치 완료 확인 신청을 해야 하는 기간은 언제까지인가요?', 'answer': '강원특별자치도에서는 건축주가 미술작품을 설치한 후, 「건축법」 제22조에 따른 사용승인 신청일로부터 2개월 이내에 별지 제10호서식의 미술작품 설치 완료 확인 신청을 해야 합니다.', 'legal_reference': '제7조 제1항', 'reasoning': '조례 제7조 제1항에 ‘사용승인 신청일로부터 2개월 이내에 도지사에게 별지 제10호서식의 미술작품 설치 완료 확인 신청을 하여야 한다’고 명시되어 있어, 해당 기간을 직접 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도에서 건축물에 미술작품을 설치할 때 적용되는 건축비용 비율은 어떻게 정해지나요?', 'answer': '강원특별자치도에서는 공동주택(건축주가 국가·지방자치단체가 아닌 경우)에는 건축비용의 1천분의 12, 그 외 건축물(건축주가 국가·지방자치단체가 아닌 경우)에는 건축비용의 1천분의 5를 미술작품 설치에 사용하도록 규정하고 있습니다.', 'legal_reference': '제2조', 'reasoning': '조례 제2조는 ‘영 제12조제2항제1호의 공동주택… 건축비용의 1천분의 12, 영 제12조제2항제2호부터 제10호까지… 건축비용의 1천분의 5’라고 명시하고 있어, 비율을 직접 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘문화예술진흥법 제9조제1항’이 의미하는 바는 무엇이며, 강원특별자치도 조례에서 어떻게 적용되고 있나요?', 'answer': '‘문화예술진흥법 제9조제1항’은 건축주가 건축물에 미술작품을 설치하려면 해당 작품을 공중이 감상할 수 있도록 설치해야 한다는 기본 원칙을 규정하고 있습니다. 강원특별자치도 조례에서는 이 조항을 근거로 제4조 제1항에서 “법 제9조제1항에 따라 미술작품을 설치하려는 건축주(이하 ‘건축주’라 한다)는 건축물 또는 그 건축물의 대지 내에 공중이 감상할 수 있도록 설치해야 한다”고 명시함으로써 적용하고 있습니다.', 'legal_reference': '제4조 제1항', 'reasoning': '조례 제4조 제1항은 ‘법 제9조제1항에 따라… 공중이 감상할 수 있도록 설치해야 한다’고 직접 인용하고 있어, 해당 법 조문의 의미와 조례 적용 관계를 확인할 수 있습니다.', 'link_reference': '문화예술진흥법'}, {'type': 'cross', 'question': '‘건축법 제21조’에 따른 착공신고는 언제 해야 하는지, 그리고 강원특별자치도 조례에서는 이 신고와 관련해 어떤 절차를 요구하고 있나요?', 'answer': '‘건축법 제21조’는 건축공사를 시작하기 전에 착공신고를 해야 한다고 규정하고 있습니다. 강원특별자치도 조례에서는 이 신고와 연계하여, 건축주가 미술작품에 대한 감정·평가를 신청하려면 ‘건축법 제21조에 따른 착공신고 후 180일 이내’에 별지 서식을 첨부하여 도지사에게 신청해야 한다고 명시하고 있습니다(제4조 제2항).', 'legal_reference': '제4조 제2항', 'reasoning': '조례 제4조 제2항은 ‘법 제9조의2제1항에 따른 감정·평가를 건축법 제21조에 따른 착공신고 후 180일 이내에… 신청해야 한다’고 규정하고 있어, 건축법의 착공신고 시점과 조례상의 절차를 연결해 설명할 수 있습니다.', 'link_reference': '건축법'}]
# [{'type': 'intra', 'question': '옥상녹화 지원 대상에 해당하는 건축물은 어떤 종류가 있나요?', 'answer': '강원특별자치도에서는 옥상녹화사업의 지원 대상이 구조안전과 방수성능 등을 확보한 건축물로, (1) 시·군 소유 건축물, (2) 지방공기업법에 따른 지방공기업 소유 건축물, (3) 민간건축물이라고 규정하고 있습니다.', 'legal_reference': '제6조 제1항', 'reasoning': '문서의 제6조 제1항에 지원 대상에 대한 구체적인 항목이 명시되어 있어 이를 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '옥상녹화 유지·관리에 대한 책임은 누구에게 있나요?', 'answer': '강원특별자치도에서는 옥상녹화사업을 지원받은 건물주 및 관리자가 조경시설 등의 원형을 보존하도록 유지·관리할 의무가 있습니다.', 'legal_reference': '제10조', 'reasoning': '제10조에 옥상녹화 유지·관리 의무 주체가 명시되어 있어 해당 조항을 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '건축법 제2조제1항제2호에서 정의하는 ‘건축물’은 무엇을 의미하나요?', 'answer': '이 문서에서 언급된 건축법 제2조제1항제2호에 따르면, ‘건축물’은 건축법이 정의한 바와 같이 건축물로서 법령상 규정된 구조물 등을 의미합니다. 따라서 강원특별자치도 옥상녹화 지원 조례는 이 정의에 따라 건축물을 대상으로 합니다.', 'legal_reference': '제2조 제1항 2호(정의) – 문서 내에서 건축법을 인용', 'reasoning': '문서의 제2조에서 ‘건축물’이 건축법 제2조제1항제2호에 따른 것이라고 명시하고 있어, 해당 외부 법령의 정의를 근거로 답변을 구성했습니다.', 'link_reference': '건축법 제2조제1항제2호'}, {'type': 'cross', 'question': '강원특별자치도 건축 조례 제3조 및 제9조에 따라 강원특별자치도건축위원회가 수행할 수 있는 역할은 무엇인가요?', 'answer': '이 문서에서 언급된 강원특별자치도 건축 조례 제3조 및 제9조에 따르면, 강원특별자치도건축위원회 또는 전문위원회는 옥상녹화 선정심의위원회를 별도로 구성하기 어려운 경우 그 기능을 대신 수행할 수 있습니다. 즉, 옥상녹화 선정 등에 필요한 심의·평가 업무를 담당하게 됩니다.', 'legal_reference': '제8조(위원회 구성 및 운영) – 문서 내에서 해당 조례 조항을 언급', 'reasoning': '제8조에서 옥상녹화 선정심의위원회를 구성하기 어려운 경우 강원특별자치도 건축 조례 제3조 및 제9조에 따른 건축위원회가 그 기능을 수행한다는 내용을 확인했으며, 이를 근거로 답변을 작성했습니다.', 'link_reference': '강원특별자치도 건축 조례 제3조, 제9조'}]
# [{'type': 'intra', 'question': '강원특별자치도 건축위원회의 회의는 누가 소집하고, 회의 소집 시 통지는 언제까지 해야 하나요?', 'answer': '해당 지자체에서는 건축위원회의 회의는 도지사가 요구하거나 위원장이 필요하다고 인정할 때 소집합니다. 회의를 소집하고자 할 때에는 회의 일정과 안건을 회의 개최 7일 전까지 위원 및 요청기관의 장에게 통지해야 합니다(단, 기밀유지·긴급 등 부득이한 사유가 있는 경우는 예외).', 'legal_reference': '제8조(회의)①, ②', 'reasoning': '조례 제8조(회의)①에 회의 소집 주체가 도지사와 위원장임을 명시하고, ②항에 회의 일정·안건 통지는 회의 개최 7일 전까지 해야 한다는 규정을 두고 있기 때문에 해당 내용으로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도 건축위원회의 위원 임기는 어떻게 정해지며 연임이 가능한가요?', 'answer': '해당 지자체에서는 위원장·부위원장·위원의 임기는 3년이며, 한 차례만 연임할 수 있습니다. 다만, 공무원인 위원은 그 직에 있는 동안 재임합니다.', 'legal_reference': '제7조(임기)①, ②', 'reasoning': '조례 제7조(임기)①에 임기가 3년이고 한 차례 연임 가능하다고 규정하고 있으며, ②항에서 공무원 위원의 경우 직에 있는 동안 재임한다는 예외 규정을 확인하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '건축허가 사전승인 대상에서 제외되는 경우는 어떤 기준에 따라 정해지나요?', 'answer': '해당 지자체에서는 사전승인 대상에서 제외되는 경우를 건축법 제11조제2항제1호 단서에 따라 정하고 있습니다. 조례 제2조의2(건축허가 사전승인)①에 따르면, (1) 층수가 21층 미만이고 연면적 합계가 10만㎡ 미만인 건축물, (2) 건축법 제2조제2항제21호부터 제23호, 제25호·제26호에 해당하는 용도의 건축물이 사전승인 대상에서 제외됩니다.', 'legal_reference': '제2조의2(건축허가 사전승인)①', 'reasoning': '조례는 사전승인 제외 기준을 건축법 제11조제2항제1호 단서에 연계하고 있으며, 조례 본문에 구체적인 제외 대상(층수·연면적·용도)들을 명시하고 있기 때문에 두 조문을 함께 인용해 답변을 작성했습니다.', 'link_reference': '건축법 제11조제2항제1호'}, {'type': 'cross', 'question': '공사감리자를 모집하고 지정하는 절차는 어떤 법령을 근거로 하고 있나요?', 'answer': '해당 지자체에서는 공사감리자 모집 및 지정 절차를 법 제25조제2항 및 시행령 제19조의2제3항을 근거로 하고 있습니다. 조례 제25조(공사감리자의 모집 및 지정)①에 따라 도지사는 시장·군수와 협의하여 연 1회 이상 정기적으로 공개모집하고, 공고기간은 20일 이상이어야 하며, 지정 절차와 관리 방안도 해당 법령에 따라 시행됩니다.', 'legal_reference': '제25조(공사감리자의 모집 및 지정)①', 'reasoning': '조례 제25조는 공사감리자 모집·지정에 관한 구체적 절차를 규정하고 있으며, 앞부분에 ‘법 제25조제2항 및 영 제19조의2제3항에 따라’라는 근거 조항을 명시하고 있어 해당 법령을 함께 인용해 답변을 구성했습니다.', 'link_reference': '건축법 제25조제2항, 건축법 시행령 제19조의2제3항'}]
# [{'type': 'intra', 'question': '이 조례는 어떤 목적을 가지고 제정되었나요?', 'answer': '해당 지자체인 강원특별자치도는 공공건축물 공사를 발주할 때 기계설비공사를 건설공사와 분리하여 발주함으로써 기계설비의 품질향상과 부실시공 방지를 목표로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례 제1조에 목적이 명시되어 있어 해당 목적을 직접 인용함.', 'link_reference': ''}, {'type': 'intra', 'question': '공공건축물 공사의 분리발주 가능 여부를 검토해야 하는 주체는 누구인가요?', 'answer': '강원특별자치도지사는 건설공사의 예산편성과 기본설계 등 사업의 계획 단계부터 분리발주 가능 여부를 검토하여야 합니다.', 'legal_reference': '제5조 제3항', 'reasoning': '제5조 ③에 도지사의 책무로 명시되어 있음.', 'link_reference': ''}, {'type': 'cross', 'question': '‘건설공사’라는 용어는 해당 조례에서 어떻게 정의되고, 그 정의는 어느 법령에 근거하고 있나요?', 'answer': '해당 지자치인 강원특별자치도에서는 ‘건설공사’를 ‘건설산업기본법 제2조제4호’에서 정의한 건설공사로 이해합니다. 즉, 건설산업기본법에 따라 정의된 건설공사를 의미합니다.', 'legal_reference': '제2조(정의) 1.', 'reasoning': '조례 제2조 1항에서 ‘건설공사’는 건설산업기본법 제2조제4호에 따른다고 명시하고 있어, 외부 법령을 참조해야 함.', 'link_reference': '건설산업기본법 제2조제4호'}, {'type': 'cross', 'question': '‘기계설비공사’는 어떤 내용으로 정의되어 있으며, 그 정의는 어느 시행령에 근거하고 있나요?', 'answer': '강원특별자치도에서는 ‘기계설비공사’를 ‘건설산업기본법 시행령 제7조 별표 1’에 따라 정의된 기계설비공사로 해석합니다. 따라서 해당 시행령 별표에 명시된 기계설비공사의 범위가 적용됩니다.', 'legal_reference': '제2조(정의) 2.', 'reasoning': '조례 제2조 2항에서 ‘기계설비공사’는 건설산업기본법 시행령 제7조 별표 1에 따른다고 명시되어 있어, 외부 시행령을 인용해야 함.', 'link_reference': '건설산업기본법 시행령 제7조 별표 1'}]
# [{'type': 'intra', 'question': '‘공공시설’이란 무엇을 의미합니까?', 'answer': '‘공공시설’은 강원특별자치도, 강원특별자치도 소속 행정기관, 투자기관 및 출연기관 또는 이들 기관이 강원특별자치도민(이하 “도민”이라 한다)의 편의증진을 목적으로 건립한 어린이·청소년·노인·장애인 시설, 문화·체육시설, 교량, 주차장, 공원 등의 시설을 말합니다. **해당 지자체**인 강원특별자치도에 적용됩니다.', 'legal_reference': '제2조(정의) 1항', 'reasoning': '문서의 제2조 정의 부분에 ‘공공시설’에 대한 구체적인 의미가 명시되어 있으므로, 해당 조항을 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '건립비용을 공개해야 하는 최소 금액은 얼마입니까?', 'answer': '건립비용이 1억원 이상인 경우에 한해 공개해야 합니다. 따라서 1억원 미만의 건립비용은 공개 대상에 포함되지 않습니다. **해당 지자체**인 강원특별자치도에 적용됩니다.', 'legal_reference': '제4조(공개범위)①', 'reasoning': '제4조 제1항에 ‘1억원 이상의 건립비용이 사용된 공공시설 및 공공건축물에 대하여 공개한다’는 규정이 명시되어 있어, 최소 공개 금액을 직접 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '제6조에서 언급된 시행규칙은 어떤 내용을 포함해야 하나요?', 'answer': '이 문서에서 언급된 **강원특별자치도 공공시설 및 공공건축물의 건립비용 공개에 관한 시행규칙**에 따르면, 이 조례의 시행에 필요한 구체적인 사항(예: 준공석·준공판의 형식·부착 위치·표시 방법 등)을 정해야 합니다. **해당 지자체**인 강원특별자치도에 적용됩니다.', 'legal_reference': '제6조(시행규칙)', 'reasoning': '제6조는 ‘이 조례의 시행에 필요한 사항은 규칙으로 정한다’고 규정하고 있으며, 이는 별도의 시행규칙에 구체적인 시행 절차와 형식을 명시하도록 요구하고 있습니다.', 'link_reference': '강원특별자치도 공공시설 및 공공건축물의 건립비용 공개에 관한 시행규칙'}, {'type': 'cross', 'question': '제6조에 따라 시행규칙을 제정하는 주체는 누구입니까?', 'answer': '이 문서에서 언급된 **강원특별자치도 공공시설 및 공공건축물의 건립비용 공개에 관한 시행규칙**은 강원특별자치도지사(또는 도청) 등 해당 지자체의 행정기관이 제정합니다. **해당 지자체**인 강원특별자치도에 적용됩니다.', 'legal_reference': '제6조(시행규칙)', 'reasoning': '제6조는 ‘이 조례의 시행에 필요한 사항은 규칙으로 정한다’고 명시하고 있으며, 일반적으로 조례를 제정하는 주체인 도지사·도청이 시행규칙을 마련하게 됩니다. 따라서 규칙 제정 주체는 강원특별자치도의 행정기관이라고 해석할 수 있습니다.', 'link_reference': '강원특별자치도 공공시설 및 공공건축물의 건립비용 공개에 관한 시행규칙'}]
# [{'type': 'intra', 'question': '강원특별자치도 공사중단 장기방치 건축물 정비지원 조례의 목적은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도에서는 이 조례가 공사가 중단되어 장기간 방치된 건축물의 안전문제와 사회·경제적 위해를 해소하기 위한 사항을 규정하는 것을 목적으로 하고 있습니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’ 항목이 명시되어 있으며, 해당 문구에 따라 조례의 목적을 직접 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도 도지사는 언제 공사중단 건축물에 대한 안전관리 비용을 지원할 수 있나요?', 'answer': '해당 지자체인 강원특별자치도에서는 도지사가 현장의 미관을 저해하고 안전을 위한 조치가 불가피하다고 판단될 경우, 법 제6조의 정비계획에 따라 예산 범위 내에서 시장·군수에게 안전관리 등 비용의 일부를 지원할 수 있습니다.', 'legal_reference': '제3조(안전관리 지원 등)①', 'reasoning': '조례 제3조 ①항에 도지사의 지원 조건과 절차가 구체적으로 규정되어 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘공사중단 장기방치 건축물의 정비 등에 관한 특별조치법’ 제6조는 정비계획에 대해 어떤 내용을 규정하고 있나요?', 'answer': '해당 지자체인 강원특별자치도에서는 이 조례에서 언급된 바와 같이, ‘공사중단 장기방치 건축물의 정비 등에 관한 특별조치법’ 제6조에 따르면 정비계획을 수립하고 이를 토대로 공사중단 건축물의 안전 및 정비에 필요한 구체적인 방안을 마련하도록 규정하고 있습니다.', 'legal_reference': '공사중단 장기방치 건축물의 정비 등에 관한 특별조치법 제6조', 'reasoning': '조례 제3조 ①항에서 해당 법의 제6조를 근거로 도지사의 지원 여부를 판단하도록 하고 있으므로, 법 제6조의 내용이 정비계획 수립에 관한 규정임을 확인했습니다.', 'link_reference': '공사중단 장기방치 건축물의 정비 등에 관한 특별조치법'}, {'type': 'cross', 'question': '‘강원특별자치도 건축 조례’ 제3조에 따르면 강원특별자치도 건축위원회의 역할은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도에서는 ‘강원특별자치도 건축 조례’ 제3조에 따라 강원특별자치도 건축위원회는 건축 관련 정책·계획 수립 및 심의, 그리고 공사중단 장기방치 건축물 정비와 관련된 자문 및 의견 제시 등의 역할을 수행하도록 규정하고 있습니다.', 'legal_reference': '강원특별자치도 건축 조례 제3조', 'reasoning': '조례 제5조 ①항에서 자문단 구성 시 건축위원회의 위원을 포함시킬 수 있다고 명시하고 있으며, 이는 건축위원회의 역할이 자문 및 정책 수립에 있음을 암시합니다. 따라서 해당 조례 제3조를 근거로 위원의 역할을 설명했습니다.', 'link_reference': '강원특별자치도 건축 조례'}]
# [{'type': 'intra', 'question': '이 조례의 목적은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도교육청은 장애인·노인·임산부 등이 안전하고 편리하게 공공건축물을 이용할 수 있도록 장애물 없는 생활환경 인증 취득 등 지원에 필요한 사항을 규정하기 위해 이 조례를 제정했습니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’ 항목으로 조례가 규정하고 있는 목표와 취지를 명시하고 있기 때문에, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '사립학교 건축물에 대한 장애물 없는 생활환경 인증은 누가 취득해야 하나요?', 'answer': '해당 지자체인 강원특별자치도교육청이 관할하는 사립학교의 경우, 사립학교를 설치·경영하는 학교법인 또는 사립학교경영자가 해당 건축물에 대해 장애물 없는 생활환경 인증을 취득해야 합니다.', 'legal_reference': '제5조(인증취득의무)', 'reasoning': '제5조에서 사립학교를 설치·경영하는 학교법인 또는 사립학교경영자가 인증을 취득해야 한다고 명시하고 있어, 이를 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘장애물 없는 생활환경 인증’이란 무엇을 의미하나요?', 'answer': '해당 지자체인 강원특별자치도교육청이 적용하는 ‘장애물 없는 생활환경 인증’은 「장애인·노인·임산부 등의 편의증진 보장에 관한 법률」 제10조의2에 따라 부여되는 인증을 의미합니다.', 'legal_reference': '제2조(정의)', 'reasoning': '조례 제2조에서 해당 인증을 ‘법 제10조의2에 따른 인증’이라고 정의하고 있으므로, 정의 조항을 근거로 답변을 도출했습니다.', 'link_reference': '장애인·노인·임산부 등의 편의증진 보장에 관한 법률'}, {'type': 'cross', 'question': '인증 취득 지원을 신청하려면 어떤 서류를 제출해야 하나요?', 'answer': '해당 지자체인 강원특별자치도교육청에 지원을 신청하려면, 신청자는 「장애물 없는 생활환경 인증에 관한 규칙」 제6조제1항에 따라 인증서 사본을 첨부하여 교육감에게 신청해야 합니다.', 'legal_reference': '제6조(인증취득지원) ②', 'reasoning': '조례 제6조 제2항에서 지원 신청 시 ‘규칙 제6조제1항에 따른 인증서 사본’을 첨부해야 한다고 명시하고 있어, 이를 근거로 답변을 구성했습니다.', 'link_reference': '장애물 없는 생활환경 인증에 관한 규칙'}]
# [{'type': 'intra', 'question': '강원특별자치도의 녹색건축물 조성 지원 조례는 어떤 목적을 가지고 있나요?', 'answer': '해당 지자체인 강원특별자치도의 녹색건축물 조성 지원 조례는 건축물 온실가스 배출량을 감축하고 녹색건축물을 확대함으로써 저탄소 녹색성장을 실현하고 도민의 복리 향상에 기여하는 것을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’ 항목으로 명시되어 있어, 조례가 추구하는 궁극적인 목표가 바로 이 문구임을 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강원특별자치도는 녹색건축물 조성계획을 어떻게, 몇 년마다 수립해야 하나요?', 'answer': '해당 지자체인 강원특별자치도는 도지사가 국토교통부장관이 수립하는 녹색건축물 기본계획에 따라 녹색건축물 조성계획을 5년마다 수립·시행해야 합니다.', 'legal_reference': '제6조(녹색건축물 조성계획의 수립 등) ①', 'reasoning': '제6조는 도지사가 ‘5년마다’ 조성계획을 수립·시행하도록 규정하고 있으므로, 주기와 책임 주체가 명확히 제시됩니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘녹색건축물 조성 지원법’ 제2조제1호에서 정의하는 “녹색건축물”은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도 조례에 따르면, ‘녹색건축물’은 「녹색건축물 조성 지원법」 제2조제1호에서 정의된 건축물을 의미합니다. 즉, 해당 법에서 정한 녹색건축물 기준을 충족하는 건축물을 말합니다.', 'legal_reference': '제2조(정의) 1.', 'reasoning': '조례 제2조 제1항에서 ‘녹색건축물’의 정의를 직접적으로 ‘녹색건축물 조성 지원법 제2조제1호에 따른 건축물’이라고 명시하고 있어, 외부 법령의 해당 조항을 참조해야 정확한 의미를 파악할 수 있습니다.', 'link_reference': '녹색건축물 조성 지원법'}, {'type': 'cross', 'question': '‘녹색건축물 조성 지원법 시행령’ 제8조가 규정하는 건축물 에너지 소비 총량 관리의 내용은 무엇인가요?', 'answer': '해당 지자체인 강원특별자치도 조례 제10조에 따르면, 도지사는 「녹색건축물 조성 지원법」 제11조와 그 시행령 제8조에 따라 건축물의 에너지 소비 총량을 설정하고 이를 관리할 수 있습니다. 시행령 제8조는 건축물별 에너지 소비 총량 한도를 정하고, 그 한도 초과 여부를 모니터링·관리하도록 규정하고 있습니다.', 'legal_reference': '제10조(건축물의 에너지 소비 총량관리 등) ①', 'reasoning': '조례 제10조는 시행령 제8조를 직접 인용하면서 에너지 소비 총량을 설정·관리할 수 있는 근거를 제공하고 있습니다. 따라서 시행령 제8조의 구체적 내용(에너지 소비 총량 한도 설정 및 관리)은 외부 법령을 참조해야 정확히 이해할 수 있습니다.', 'link_reference': '녹색건축물 조성 지원법 시행령'}]
# [{'type': 'intra', 'question': '강원특별자치도 상수원보호구역 내에서 허가 대상이 되는 건축물·공작물에는 어떤 종류가 포함되나요?', 'answer': '해당 지자체인 강원특별자치도에서는 제2조(허가 대상 건축물 등의 종류 및 규모)①에 따라 다음과 같은 건축물·공작물이 허가 대상에 포함됩니다. 1) 농림업용 취수시설 2) 농림업 체험·실습시설(연면적 300㎡ 이하) 3) 도서관·운동장 4) 주민자치센터 5) 비영업용 소규모 공동목욕장 6) 지역특산물 판매장(법정 리·동별 1개, 200㎡ 이하) 7) 액화석유가스(LPG) 소형저장탱크(저장능력 3톤 미만) 8) 주민복지회관(법정 리·동별 1개, 연면적 1,000㎡ 이하, 음식물 조리·제공시설은 100㎡ 이하).', 'legal_reference': '제2조(허가 대상 건축물 등의 종류 및 규모)①', 'reasoning': '문서의 제2조 제1항에 허가 대상 건축물·공작물의 구체적인 목록이 명시되어 있으므로, 해당 조항을 그대로 인용하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '지역특산물 판매장은 어떤 면적 제한을 가지고 있나요?', 'answer': '해당 지자체인 강원특별자치도에서는 제2조(허가 대상 건축물 등의 종류 및 규모)②의 4호에 따라 지역특산물 판매장은 법정 리·동별로 1개씩, 연면적 200㎡ 이하로 제한됩니다.', 'legal_reference': '제2조(허가 대상 건축물 등의 종류 및 규모)② 4호', 'reasoning': '문서 내에서 지역특산물 판매장에 대한 면적 제한이 명시된 조항을 직접 인용했기 때문에, 해당 조항을 근거로 답변을 제공했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '농림업 체험·실습시설에서 발생하는 하수가 어떻게 처리되어야 하는지 ‘하수도법 제2조제9호’는 무엇을 규정하고 있나요?', 'answer': '해당 지자체인 강원특별자치도에서는 제2조(허가 대상 건축물 등의 종류 및 규모)①에 따라 농림업 체험·실습시설(연면적 300㎡ 이하)에서 발생하는 하수는 ‘하수도법 제2조제9호’에 따라 공공하수처리시설에 유입시키거나 전량 위탁 처리해야 합니다. 즉, 하수는 반드시 공공 하수처리 시설에 연결하거나 전문 처리업체에 위탁해야 함을 의미합니다.', 'legal_reference': '제2조(허가 대상 건축물 등의 종류 및 규모)①', 'reasoning': '문서에서는 하수 처리에 대한 요구 사항을 ‘하수도법 제2조제9호’를 인용하여 규정하고 있으므로, 해당 법령 조항의 의미를 설명함으로써 완전한 답변을 제공했습니다.', 'link_reference': '하수도법 제2조제9호'}, {'type': 'cross', 'question': '‘상수원관리규칙 제12조제3호카목’에서 말하는 “조례로 정하는 건축물이나 그 밖의 공작물”은 무엇을 의미하나요?', 'answer': '해당 지자체인 강원특별자치도에서는 제2조(허가 대상 건축물 등의 종류 및 규모)①에 따라 ‘상수원관리규칙 제12조제3호카목’이 의미하는 “조례로 정하는 건축물이나 그 밖의 공작물”은 다음과 같은 항목들을 포함합니다. 1) 농림업용 취수시설 2) 농림업 체험·실습시설(연면적 300㎡ 이하) 등. 즉, 규칙에서 정의한 바와 같이 조례에서 별도로 규정한 건축물·공작물 목록을 가리킵니다.', 'legal_reference': '제2조(허가 대상 건축물 등의 종류 및 규모)①', 'reasoning': '문서에서는 ‘상수원관리규칙 제12조제3호카목’이 조례에서 정의한 건축물·공작물 목록을 그대로 인용하고 있으므로, 해당 규칙 조항이 의미하는 바를 조례 내용과 연결하여 설명했습니다.', 'link_reference': '상수원관리규칙 제12조제3호카목'}]
# [{'type': 'intra', 'question': '우수건축자산을 등록하려면 어떤 절차를 거쳐야 하나요?', 'answer': '해당 지자체인 강원특별자치도에서는 도지사가 소유자의 신청을 받은 후 건축위원회의 심의를 거쳐 등록 여부를 결정하고, 등록이 승인되면 신청인에게 등록증을 발급하도록 규정하고 있습니다.', 'legal_reference': '제8조 제1항~제3항', 'reasoning': '조례 제8조는 도지사가 신청을 받고 건축위원회의 심의를 거쳐 우수건축자산 등록 여부를 결정하고, 등록증을 발급하도록 명시하고 있기 때문에 이 절차를 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '건축자산 진흥구역 협의체는 몇 명까지 구성할 수 있나요?', 'answer': '해당 지자체인 강원특별자치도에서는 협의체를 위원장 1명, 부위원장 1명을 포함하여 15명 이내의 위원으로 구성하도록 정하고 있습니다.', 'legal_reference': '제11조 제2항', 'reasoning': '조례 제11조 제2항에 협의체 구성 인원에 대한 제한이 명시되어 있어, 위원장·부위원장을 포함한 총 15명 이내라는 규정을 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘우수건축자산’이란 무엇을 의미하나요?', 'answer': '이 문서에서 언급된 바와 같이, ‘우수건축자산’은 한옥 등 건축자산의 진흥에 관한 법률 제10조제1항에 따라 강원특별자치도지사가 소유자의 신청을 받아 등록한 건축자산을 의미합니다. 해당 조례 제2조 제2항이 이 정의를 법률에 근거하여 설명하고 있습니다.', 'legal_reference': '제2조 제2항', 'reasoning': '조례 제2조 제2항은 ‘우수건축자산’이 법 제10조제1항에 따라 도지사가 등록하는 건축자산이라고 정의하고 있으므로, 해당 법률 조항을 근거로 의미를 설명했습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률 제10조제1항'}, {'type': 'cross', 'question': '특례 적용 계획서에 포함되어야 할 내용은 무엇인가요?', 'answer': '이 문서에 따르면, 특례 적용 계획서는 한옥 등 건축자산의 진흥에 관한 법률 제14조제2항제5호에 따라 우수건축자산의 주요 가치 유지 방안, 특례 적용 및 미적용인 경우를 비교할 수 있는 개략설계도서, 그리고 도지사가 필요하다고 인정하는 기타 사항을 포함해야 합니다. 조례 제9조 제1항이 이 법 조항을 인용하고 있습니다.', 'legal_reference': '제9조 제1항', 'reasoning': '조례 제9조 제1항은 법 제14조제2항제5호에 따라 특례 적용 계획서에 포함될 사항을 구체적으로 열거하고 있으므로, 해당 법 조항을 근거로 답변을 구성했습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률 제14조제2항제5호'}]
# [{'type': 'intra', 'question': '강원특별자치도에서 한옥 건축 지원을 신청한 후 공사를 시작하기 전에 어떤 서류를 제출해야 하나요?', 'answer': '강원특별자치도에서는 공사를 착수하기 전에 별지 제2호서식의 착수신고서를 시장·군수에게 제출해야 합니다. 다만, 「건축법」 제21조에 따라 착공신고서를 이미 제출한 경우에는 착수신고서를 별도로 제출할 필요가 없습니다.', 'legal_reference': '제5조(착수 및 완료신고)①②', 'reasoning': '제5조에 ‘대상자는 공사를 착수하기 전에 별지 제2호서식의 착수신고서를 시장·군수에게 제출하여야 한다’고 명시되어 있으며, 이어서 ‘「건축법」제21조에 따라 착공신고서를 제출한 경우 이를 생략 할 수 있다’는 예외 조항이 포함되어 있기 때문에 이 답변이 도출되었습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '우수건축자산 지원을 신청하려면 어떤 절차와 서류가 필요한가요?', 'answer': '강원특별자치도에서는 우수건축자산 지원을 받고자 하는 사람은 별지 제1호서식의 우수건축자산 지원신청서를 시장·군수에게 제출해야 합니다. 시장·군수는 이를 검토하고 지원 기준에 적합하면 검토의견서를 첨부하여 도지사에게 제출합니다.', 'legal_reference': '제2조(우수건축자산 지원)①②', 'reasoning': '제2조는 우수건축자산 지원 신청 절차를 구체적으로 규정하고 있으며, 신청서 제출 대상과 검토·제출 절차를 명시하고 있기 때문에 해당 내용이 답변의 근거가 됩니다.', 'link_reference': ''}, {'type': 'cross', 'question': '한옥 건축 및 한옥마을 조성 지원을 받기 위한 신청인의 거주 요건은 무엇인가요?', 'answer': '강원특별자치도에서는 한옥 건축 및 한옥마을 조성 지원을 받기 위해서는 신청인이 「한옥 등 건축자산의 진흥에 관한 법률」 제25조에 따라 지원계획서 접수일 이전에 도내에 주민등록을 두고 실제로 거주하고 있어야 합니다. 이는 제3조(한옥건축 및 한옥마을 조성 지원대상 및 기준)①에 명시된 요건과 일치합니다.', 'legal_reference': '제3조(한옥건축 및 한옥마을 조성 지원대상 및 기준)①', 'reasoning': '제3조①은 지원 대상자를 정의하면서 해당 법률 제25조에 따른 거주 요건을 직접 언급하고 있으므로, 이 조항을 근거로 답변을 도출했습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률'}, {'type': 'cross', 'question': '착수신고서를 제출하지 않아도 되는 경우는 어떤 경우인가요?', 'answer': '강원특별자치도에서는 착수신고서를 별도로 제출하지 않아도 되는 경우는 신청인이 이미 「건축법」 제21조에 따라 착공신고서를 제출한 경우입니다. 이 경우 제5조(착수 및 완료신고)②에 따라 착수신고서를 생략할 수 있습니다.', 'legal_reference': '제5조(착수 및 완료신고)②', 'reasoning': '제5조②는 ‘다만, 「건축법」제21조에 따라 착공신고서를 제출한 경우 이를 생략 할 수 있다’고 명시하고 있어, 해당 법령 조항을 근거로 답변을 구성했습니다.', 'link_reference': '건축법'}]
# [{'type': 'intra', 'question': '전라남도 강진군에서 건축물관리자는 눈이 그친 후 제설·제빙작업을 언제까지 완료해야 합니까?', 'answer': '전라남도 강진군의 『강진군 건축물 관리자의 제설 및 제빙책임에 관한 조례』 제6조(제설·제빙작업의 시기)에 따르면, 건축물관리자는 눈이 그친 때로부터 3시간 이내에 제설·제빙작업을 완료해야 합니다. 다만, 야간(일몰 후부터 다음날 일출 전까지)에 눈이 내린 경우에는 다음날 오전 10시까지 작업을 마쳐야 합니다.', 'legal_reference': '제6조(제설·제빙작업의 시기)', 'reasoning': '조례 제6조에 제설·제빙작업을 완료해야 하는 구체적인 시기가 명시되어 있어, 해당 조항을 직접 인용하여 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '전라남도 강진군에서 건축물관리자가 담당해야 하는 제설·제빙작업의 책임범위는 어디까지인가요?', 'answer': '전라남도 강진군의 『강진군 건축물 관리자의 제설 및 제빙책임에 관한 조례』 제5조(제설·제빙작업의 책임범위)에 따르면, 건축물관리자가 해야 할 제설·제빙작업의 책임범위는 다음과 같습니다. ① 보도는 건축물의 대지에 접한 보도의 전체 구간, ② 이면도로 및 보행자 전용도로는 건축물의 대지에 접한 도로의 중앙선 또는 중앙부분까지, ③ 시설물의 지붕은 최상층 지붕면(옥탑층이 있을 경우 옥탑층 포함) 및 복합적으로 형성된 모든 지붕 구간을 포함합니다.', 'legal_reference': '제5조(제설·제빙작업의 책임범위)', 'reasoning': '조례 제5조에 책임범위가 구체적으로 열거되어 있으므로, 해당 조항을 그대로 인용해 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '자연재해대책법 제27조 제2항은 건축물관리자의 제설·제빙 책임에 대해 어떤 내용을 규정하고 있나요?', 'answer': '이 문서에서 언급된 자연재해대책법 제27조 제2항에 따르면, 건축물관리자는 해당 건축물의 대지에 접한 보도·이면도로·보행자 전용도로 등에 대해 제설·제빙 작업을 수행할 의무가 있습니다. 이는 지방자치단체가 구체적인 책임 범위와 시기 등을 정하도록 위임하는 규정으로, 강진군은 이를 구체화하여 제1조(목적)에서 명시하고 있습니다. 따라서 전라남도 강진군의 조례는 자연재해대책법이 부여한 기본 의무를 구체적으로 구현한 것입니다.', 'legal_reference': '자연재해대책법 제27조 제2항', 'reasoning': '조례 제1조에서 자연재해대책법 제27조 제2항을 위임받아 제정된 목적을 밝히고 있으므로, 해당 법 조문의 의미를 설명함으로써 질문에 답변했습니다.', 'link_reference': '자연재해대책법'}, {'type': 'cross', 'question': '도로법에서 정의하는 ‘도로’는 무엇을 의미하나요?', 'answer': '이 문서에서 언급된 도로법에 따르면, ‘도로’는 도로법에 따른 도로와 그 밖의 일반 교통에 사용되는 모든 장소를 의미합니다. 즉, 도로법이 규정한 공공도로뿐만 아니라 사유지 등에서 일반 교통에 이용되는 모든 구역을 포함합니다. 전라남도 강진군은 조례 제2조(정의)에서 이 정의를 인용하여 ‘도로’를 정의하고 있습니다.', 'legal_reference': '도로법 제1조(정의) (예시)', 'reasoning': '조례 제2조에서 도로법에 따른 도로의 정의를 직접 인용하고 있으므로, 도로법의 해당 조항을 근거로 답변을 구성했습니다.', 'link_reference': '도로법'}]
# [{'type': 'intra', 'question': '강진군 건축물관리 조례의 목적은 무엇인가요?', 'answer': '전라남도 강진군의 건축물관리 조례는 「건축물관리법」 및 그 시행령·시행규칙에서 조례로 정하도록 위임된 사항과 그 시행에 필요한 사항을 규정함을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’이라는 항목으로 조례가 규정하고자 하는 범위와 목표를 명시하고 있기 때문에, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '강진군에서 정기점검 대상이 되는 건축물은 어떤 기준을 만족해야 하나요?', 'answer': '전라남도 강진군에서는 정기점검 대상 건축물을 ‘다중이용업소 중 영업장 면적 합계가 1천제곱미터 이상인 건축물’으로 정의하고 있습니다. 이는 「건축물관리법 시행령」 제8조제1항제1호에서 ‘조례로 정하는 건축물’이라 규정한 내용과 일치합니다.', 'legal_reference': '제4조(정기점검 대상)', 'reasoning': '조례 제4조에서 정기점검 대상 건축물의 구체적인 기준을 명시하고 있으므로, 해당 조항을 직접 인용하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '정기점검 대상 건축물에 해당하는 ‘조례로 정하는 건축물’의 의미는 무엇인가요?', 'answer': '전라남도 강진군 건축물관리 조례 제4조에 따르면, ‘조례로 정하는 건축물’은 「건축물관리법 시행령」 제8조제1항제1호에서 정의된 바와 같이 ‘다중이용업소 중 해당업소의 영업장 면적 합계가 1천제곱미터 이상인 건축물’입니다.', 'legal_reference': '제4조(정기점검 대상)', 'reasoning': '조례 자체에서는 ‘조례로 정하는 건축물’의 구체적 의미를 제시하지 않고, 해당 의미를 건축물관리법 시행령 제8조제1항제1호에 위임하고 있기 때문에, 그 조항을 근거로 답변을 제시했습니다.', 'link_reference': '건축물관리법 시행령 제8조제1항제1호'}, {'type': 'cross', 'question': '건축물 해체 신고 대상에 포함되는 ‘조례로 정하는 건축물’은 어떤 건축물을 의미하나요?', 'answer': '전라남도 강진군 건축물관리 조례 제8조에 따르면, ‘조례로 정하는 건축물’은 ① 「건축법」 제20조제1항에 따른 가설건축물, ② 「건축법」 제83조에 따른 축조신고대상 공작물을 의미합니다.', 'legal_reference': '제8조(건축물 해체의 신고 대상)', 'reasoning': '조례 제8조에서 해체 신고 대상 건축물을 정의하면서, 해당 건축물이 건축법 제20조제1항 및 제83조에 규정된 가설건축물 또는 축조신고대상 공작물임을 명시하고 있기 때문에, 그 조항을 근거로 답변을 구성했습니다.', 'link_reference': '건축법 제20조제1항, 건축법 제83조'}]
# [{'type': 'intra', 'question': '연면적이 1만 제곱미터 이상인 건축물 중 어떤 용도에 해당하면 전라남도 강진군이 문화예술 공간 설치를 권장하나요?', 'answer': '전라남도 강진군은 연면적이 10,000㎡ 이상이며 건축법 시행령 별표 1에 따라 다음 용도 중 하나에 해당하는 건축물(공동주택(기숙사 제외), 근린생활시설, 문화·집회시설 중 공연장·집회장·관람장, 판매·영업시설, 의료시설 중 병원, 업무시설, 숙박시설, 위락시설, 공공용시설 중 방송국·전신전화국·촬영소 등)에게 문화예술 공간 설치를 권장합니다.', 'legal_reference': '제3조(문화예술 공간의 설치권장 대상 건축물 등 범위)①', 'reasoning': '문서의 제3조①에 연면적 1만㎡ 이상 건축물 중 해당 용도 목록을 명시하고 있어, 해당 지자체가 권장 대상임을 확인할 수 있다.', 'link_reference': ''}, {'type': 'intra', 'question': '전라남도 강진군에서 장식 설치에 사용해야 하는 건축비용 비율은 어떻게 정해져 있나요?', 'answer': '전라남도 강진군은 연면적 10,000㎡ 이상 건축물에 대해 장식 설치에 사용해야 하는 건축비용 비율을 다음과 같이 정하고 있습니다. 공동주택(기숙사 제외)은 1천분의 12, 그 외(근린생활시설·문화·집회시설·판매·영업시설·의료시설·업무시설·숙박시설·위락시설·공공용시설 등)은 1천분의 5를 적용합니다.', 'legal_reference': '제9조(장식에 사용하는 건축비용의 비율)①', 'reasoning': '문서의 제9조에 각 건축물 유형별 비율이 명시되어 있어, 해당 지자체의 규정으로 직접 인용한다.', 'link_reference': ''}, {'type': 'cross', 'question': '문화예술진흥법 제5조제2항에서 말하는 ‘공연장·전시장 등의 문화예술 공간’은 무엇을 의미하나요?', 'answer': '전라남도 강진군은 이 조례에서 문화예술진흥법 제5조제2항을 근거로 ‘공연장·전시장 등의 문화예술 공간’이라고 규정하고 있습니다. 해당 법 조항은 공연, 전시, 문화 행사 등을 위한 전용 공간을 의미하며, 이는 강진군이 권장하는 문화예술 공간 설치 대상에 해당합니다.', 'legal_reference': '제3조(문화예술 공간의 설치권장 대상 건축물 등 범위)①(문화예술 공간 설치 권장 대상)에서 문화예술진흥법 제5조제2항을 언급', 'reasoning': '문서의 제3조①는 문화예술진흥법 제5조제2항을 인용하여 문화예술 공간의 정의를 제시하고 있으므로, 해당 법 조항의 의미를 설명하기 위해 외부 법령을 참조한다.', 'link_reference': '문화예술진흥법 제5조제2항'}, {'type': 'cross', 'question': '문화예술진흥법 시행령 제12조제4항에서 정의하는 ‘장식’에는 어떤 종류가 포함되나요?', 'answer': '전라남도 강진군은 이 조례에서 ‘장식’의 정의를 문화예술진흥법 시행령 제12조제4항에 따라 규정하고 있습니다. 해당 시행령은 감정·평가를 거친 회화·조각·공예·사진·서예 등 조형 예술물과 벽화·분수대·상징탑 등 환경조형물을 포함합니다.', 'legal_reference': '제2조(정의) 3항에서 ‘장식’의 정의를 문화예술진흥법 시행령 제12조제4항에 따라 제시', 'reasoning': '문서의 제2조③은 ‘장식’의 범위를 외부 시행령 조항에 의존하고 있으므로, 해당 조항을 참조해 답변한다.', 'link_reference': '문화예술진흥법 시행령 제12조제4항'}]
# ...
# [{'type': 'intra', 'question': '경상북도 건축위원회의 위원 수는 최소와 최대가 각각 얼마이며, 위원장은 어떤 역할을 하나요?', 'answer': '해당 지자체인 경상북도 건축위원회는 위원장 및 부위원장을 포함하여 40명 이상 100명 이하의 위원으로 구성됩니다. 위원장은 위원회의 직무를 총괄하고 위원회를 대표하며, 부위원장은 위원장을 보좌하고 위원장 유고 시 그 직무를 대행합니다.', 'legal_reference': '제4조(구성 등)①', 'reasoning': '조례 제4조(구성 등)①에 위원 수와 구성에 대한 최소·최대 인원수가 명시되어 있으며, 위원장의 직무와 부위원장의 역할도 같은 조항에 규정되어 있기 때문에 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '공사감리자를 공개모집하고 지정하는 절차는 어떻게 이루어지나요?', 'answer': '해당 지자체인 경상북도에서는 도지사가 시장·군수와 협의하여 연 1회 이상 정기적으로 공사감리자를 공개모집하고, 인터넷 홈페이지·세움터·건축사협회 등에서 20일 이상 공고합니다. 신청 건축사는 별지 제1호 서식으로 등록신청을 하고, 등록취소 사유가 없을 경우 별지 제2호 서식에 따라 공사감리자 등록명부에 등재·관리됩니다. 지정은 허가권자가 무작위로 선정하며, 지정 후 7일 이내에 건축주·감리자·도지사에게 통보하고 지정대장에 기록합니다.', 'legal_reference': '제8조(공사감리자의 모집 및 지정)①~⑥', 'reasoning': '조례 제8조 전반에 공사감리자의 모집, 신청, 등록, 지정 절차와 공고 요건 등이 상세히 규정되어 있어 해당 조항을 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '전통사찰에 해당하는 건축물에 대한 적용 완화 기준은 어디에 규정되어 있나요?', 'answer': '해당 지자체인 경상북도에서는 전통사찰에 해당하는 건축물에 대한 적용 완화 기준이 「건축법」 제5조제1항 및 「건축법 시행령」 제6조제1항제4호와 연계되어 규정됩니다. 구체적으로는 조례 제2조의2(적용의 완화)①에 따라 전통사찰(「전통사찰의 보존 및 지원에 관한 법률」 제2조 및 같은 법 시행령 제3조에 따른) 및 도지사가 지정한 전통한옥 지역의 건축물에 대해 법 제2조제1항제11호, 제44조, 제46조의 기준을 최소 범위 이내로 완화하여 적용할 수 있다고 명시하고 있습니다.', 'legal_reference': '제2조의2(적용의 완화)①', 'reasoning': '조례 제2조의2는 건축법 및 건축법 시행령의 특정 조항과 전통사찰 관련 법률을 연결하여 적용 완화 기준을 규정하고 있으므로, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': '건축법 제5조제1항, 건축법 시행령 제6조제1항제4호, 전통사찰의 보존 및 지원에 관한 법률 제2조'}, {'type': 'cross', 'question': '건축허가 사전승인 대상 건축물의 정의는 어느 법령에 근거하고 있나요?', 'answer': '해당 지자체인 경상북도에서는 건축허가 사전승인 대상 건축물의 정의가 「건축법」 제11조제2항제1호 단서에 근거하고 있으며, 조례 제2조의3(건축허가 사전승인의 예외)에서 해당 정의를 구체화하고 있습니다. 이 조항에 따르면, 층수가 30층 미만이고 연면적 합계가 10만 제곱미터 미만인 건축물 및 특정 사업시행계획인가를 받은 건축물이 사전승인 대상에 해당합니다.', 'legal_reference': '제2조의3(건축허가 사전승인의 예외)', 'reasoning': '조례 제2조의3은 건축법 제11조제2항제1호 단서에 따라 사전승인 대상 건축물을 정의하고 있으므로, 해당 조항을 근거로 답변을 구성했습니다.', 'link_reference': '건축법 제11조제2항제1호'}]
# [{'type': 'intra', 'question': '이 조례의 목적은 무엇인가요?', 'answer': '해당 지자체인 경상북도는 공공건축물 공사를 발주할 때 기계설비공사를 건설공사와 분리하여 발주할 수 있도록 하는데 필요한 사항을 규정함으로써 지역경제 활성화에 기여하는 것을 목적으로 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 제1조에 ‘목적’ 항목으로 조례가 규정하고 있는 목표가 명시되어 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '경상북도 내 공공건축물에 설치되는 기계설비의 품질 향상과 산업 경쟁력 강화를 위해 누가 어떤 역할을 해야 하나요?', 'answer': '해당 지자체인 경상북도에서는 도지사가 도내 공공건축물에 설치되는 기계설비의 품질향상과 기계설비산업의 경쟁력 강화를 위하여 노력해야 합니다.', 'legal_reference': '제4조(도지사의 책무)', 'reasoning': '조례 제4조에 도지사의 책무가 명시되어 있어, 도지사의 역할을 직접 인용하여 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘건설공사’라는 용어는 어떤 법령에 따라 정의되며, 그 의미는 무엇인가요?', 'answer': '이 문서에서 언급된 「건설산업기본법」 제2조제4호에 따르면, ‘건설공사’는 건설산업기본법에서 정의한 건설공사를 의미합니다. 따라서 해당 지자체인 경상북도에서도 이 정의에 따라 건설공사를 해석합니다.', 'legal_reference': '제2조(정의) 1.', 'reasoning': '조례 제2조 제1항에서 ‘건설공사’의 정의가 「건설산업기본법」 제2조제4호에 의존한다고 명시하고 있으므로, 해당 법령을 근거로 의미를 설명했습니다.', 'link_reference': '건설산업기본법 제2조제4호'}, {'type': 'cross', 'question': '‘기계설비공사’는 어떤 시행령에 근거하여 정의되며, 그 구체적인 내용은 무엇인가요?', 'answer': '이 문서에서 언급된 「건설산업기본법 시행령」 별표 1에 따라 ‘기계설비공사’는 별표 1에 규정된 기계설비공사를 의미합니다. 따라서 해당 지자체인 경상북도에서도 별표 1에 명시된 범위와 요건에 따라 기계설비공사를 구분하고 있습니다.', 'legal_reference': '제2조(정의) 2.', 'reasoning': '조례 제2조 제2항에서 ‘기계설비공사’가 「건설산업기본법 시행령」 별표 1에 따른다고 명시하고 있어, 해당 시행령을 근거로 정의를 제시했습니다.', 'link_reference': '건설산업기본법 시행령 별표 1'}]
# [{'type': 'intra', 'question': '경상북도 공공건축물에 대한 소방시설공사 분리발주 조례는 어떤 목적을 가지고 있나요?', 'answer': '해당 지자체인 경상북도는 공공건축물 공사를 추진함에 있어 건설공사와 소방시설공사를 분리하여 발주함으로써 소방시설의 품질향상과 도민의 안전에 기여하고자 합니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례 제1조에 목적을 명시하고 있어, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '소방시설공사를 분리발주하지 않아도 되는 경우는 어떤 경우인가요?', 'answer': '해당 지자체인 경상북도에서는 소방시설공사를 다른 건설공사와 분리하여 도급하지 않아도 되는 경우는 다음과 같습니다. 1) 분리하여 도급계약을 체결하면 하나의 목적물을 완성할 수 없는 경우, 2) 분리하여 도급계약을 체결하면 하자책임구분이 명확하지 않은 경우, 3) 그 밖의 공사의 성질상 분리하여 발주할 수 없는 경우.', 'legal_reference': '제5조(소방시설공사 분리발주) 1~3호', 'reasoning': '조례 제5조에 분리발주 예외 사유가 구체적으로 규정되어 있어 이를 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '소방시설 설치·유지 및 안전관리에 관한 법률 제2조제1항제1호에서 정의하는 소방시설은 무엇인가요?', 'answer': '이 문서에서 언급된 소방시설은 「소방시설 설치·유지 및 안전관리에 관한 법률」 제2조제1항제1호 및 같은 법 시행령 제3조에 따라 소화설비, 경보설비, 피난설비, 소화용수설비 및 그 밖의 소화활동설비를 말합니다. 따라서 해당 법률의 해당 조항에 따르면 소방시설은 위와 같은 설비들을 포함합니다.', 'legal_reference': '제2조(정의) 2호', 'reasoning': '조례 제2조 2호에서 소방시설의 정의를 제시하면서 해당 법률 및 시행령을 인용하고 있으므로, 완전한 의미 파악을 위해 외부 법률 조항을 참조해야 합니다.', 'link_reference': '소방시설 설치·유지 및 안전관리에 관한 법률 제2조제1항제1호'}, {'type': 'cross', 'question': '소방시설공사업법 제2조제1항제1호가 규정하는 소방시설공사의 내용은 무엇인가요?', 'answer': '이 문서에서 언급된 소방시설공사는 「소방시설공사업법」 제2조제1항제1호가 규정하는 업무를 의미합니다. 즉, 소방시설의 설치·유지·보수 등과 관련된 공사를 수행하는 업무를 말합니다.', 'legal_reference': '제2조(정의) 3호', 'reasoning': '조례 제2조 3호에서 소방시설공사의 정의를 해당 법률 조항에 근거하여 제시하고 있으므로, 정확한 의미를 파악하기 위해 외부 법령을 참조해야 합니다.', 'link_reference': '소방시설공사업법 제2조제1항제1호'}]
# [{'type': 'intra', 'question': '경상북도 도지사는 공사중단 장기방치 건축물 정비를 위해 어떤 시책을 수립·시행해야 하나요?', 'answer': '경상북도 도지사는 공사중단 장기방치 건축물 정비를 위해 필요한 시책을 수립하고 시행하여야 합니다. (해당 지자체)', 'legal_reference': '제3조(도지사의 책무)', 'reasoning': '조례 제3조에 도지사의 책무로 ‘필요한 시책을 수립하고 시행’한다는 문구가 명시되어 있어, 해당 조항만으로 답을 도출할 수 있다.', 'link_reference': ''}, {'type': 'intra', 'question': '경상북도에서는 공사중단 건축물 정비기금을 어느 조항에 따라 설치하도록 규정하고 있나요?', 'answer': '경상북도는 제4조 제1항에 따라 도지사가 법 제13조제1항에 근거하여 공사중단 건축물 정비기금을 설치하도록 규정하고 있습니다. (해당 지자체)', 'legal_reference': '제4조(공사중단 건축물 정비기금 설치)①', 'reasoning': '조례 제4조 제1항에 ‘도지사는 법 제13조제1항에 따른 공사중단 건축물 정비기금을 설치하여야 한다’는 문구가 직접 명시되어 있어, 해당 조항만으로 답을 도출할 수 있다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘법 제13조제1항’은 공사중단 건축물 정비기금에 대해 어떤 내용을 규정하고 있나요?', 'answer': '‘법 제13조제1항’에 따르면, 공사중단 장기방치 건축물 정비기금(이하 “정비기금”)을 설치하고 그 운영에 필요한 사항을 정하도록 규정하고 있습니다. 따라서 경상북도는 이 조항에 근거하여 정비기금을 설치해야 합니다. (해당 지자체)', 'legal_reference': '제4조(공사중단 건축물 정비기금 설치)①', 'reasoning': '조례 제4조 제1항에서 도지사가 ‘법 제13조제1항에 따른 공사중단 건축물 정비기금’을 설치해야 한다고 명시하고 있다. 질문은 해당 법 조항의 의미를 묻고 있으므로, 조례와 연계된 법 조항을 근거로 답변한다.', 'link_reference': '공사중단 장기방치 건축물의 정비 등에 관한 특별조치법'}, {'type': 'cross', 'question': '‘법 제7조의2’는 안전조치명령에 관한 비용 지원을 어떻게 규정하고 있나요?', 'answer': '‘법 제7조의2’는 안전조치명령에 소요되는 비용의 전부 또는 일부를 예산 범위 내에서 지원할 수 있도록 규정하고 있습니다. 이에 따라 경상북도 도지사는 해당 조항에 따라 안전조치명령 비용을 보조할 수 있습니다. (해당 지자체)', 'legal_reference': '제8조(안전조치명령 비용 보조)', 'reasoning': '조례 제8조는 ‘도지사는 법 제7조의2에 따른 안전조치명령에 소요되는 비용의 전부 또는 일부를 예산의 범위에서 지원할 수 있다’고 명시하고 있다. 질문은 법 제7조의2의 구체적 의미를 묻고 있으므로, 해당 법 조항을 근거로 답변한다.', 'link_reference': '공사중단 장기방치 건축물의 정비 등에 관한 특별조치법'}]
# [{'type': 'intra', 'question': '해당 조례에서 “공공건축물”이란 무엇을 의미하나요?', 'answer': '해당 지자체인 경상북도교육청이 규정한 바에 따르면, “공공건축물”이란 경상북도교육청 소관 건축물과 「사립학교법」 제2조제1호에 따른 학교 중 경상북도교육감의 지도·감독을 받는 사립학교의 건축물을 말합니다.', 'legal_reference': '제2조(정의) 1.', 'reasoning': '조례 제2조(정의)에서 ‘공공건축물’의 의미를 명확히 규정하고 있으므로, 해당 조문을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '누가 해당 조례에 따라 공공건축물에 대한 인증을 취득해야 하나요?', 'answer': '해당 지자체인 경상북도교육청의 경우, 교육감 및 사립학교를 설치·운영하는 학교법인 또는 학교장이 제3조에 해당하는 공공건축물에 대해 제5조에 따른 인증을 취득하여야 합니다.', 'legal_reference': '제6조(인증취득 등) ①', 'reasoning': '조례 제6조 제1항에 ‘교육감 및 사립학교를 설치·운영하는 학교법인 또는 학교장은… 인증을 취득하여야 한다’고 명시돼 있어, 책임 주체를 직접 확인할 수 있었습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '법 제10조의2제5항에 따르면 인증수수료 지원에 어떤 요건이 있나요?', 'answer': '해당 지자체인 경상북도교육청은 법 제10조의2제5항에 따라 인증수수료를 지원할 수 있으며, 지원을 받으려는 자는 법 제10조의2제5항 및 규칙 제6조제1항에 따른 인증서 사본을 첨부하여 교육감에게 신청해야 합니다.', 'legal_reference': '제7조(지원 등) ①·②', 'reasoning': '조례 제7조는 지원 요건을 구체적으로 규정하고 있으며, 지원 요건에 법 제10조의2제5항과 규칙 제6조제1항을 언급하고 있기 때문에 해당 법 조항을 인용해 답변을 구성했습니다.', 'link_reference': '장애인·노인·임산부 등의 편의증진 보장에 관한 법률 제10조의2 제5항'}, {'type': 'cross', 'question': '‘장애물 없는 생활환경 인증에 관한 규칙’ 제5조가 규정하는 인증 기준은 무엇인가요?', 'answer': '해당 지자체인 경상북도교육청은 인증 기준을 법 제10조의2제5항 및 ‘장애물 없는 생활환경 인증에 관한 규칙’ 제5조에 따라 준용하도록 규정하고 있습니다. 따라서 인증 기준은 해당 규칙 제5조에 명시된 기준을 그대로 적용합니다.', 'legal_reference': '제5조(인증 기준 등)', 'reasoning': '조례 제5조에서 인증 기준을 법과 규칙에 준용한다는 점을 명시하고 있으며, 구체적인 기준은 ‘장애물 없는 생활환경 인증에 관한 규칙’ 제5조에 따르므로 해당 규칙을 인용해 답변을 작성했습니다.', 'link_reference': '장애물 없는 생활환경 인증에 관한 규칙 제5조'}]
# [{'type': 'intra', 'question': '경상북도 녹색건축물 조성 지원에 관한 조례는 어떤 목적을 가지고 있나요?', 'answer': '해당 지자체인 경상북도는 이 조례의 목적을 제1조에서 ‘경상북도 건축물의 온실가스 배출량 감축과 녹색건축물의 확대를 위하여 필요한 사항을 규정함으로써 저탄소 녹색성장 실현 및 도민의 복리 향상에 기여하는 것’이라고 명시하고 있습니다.', 'legal_reference': '제1조(목적)', 'reasoning': '조례의 목적은 제1조에 명확히 규정되어 있으므로, 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '경상북도 녹색건축물 조성계획은 누가, 얼마나 자주 수립해야 하나요?', 'answer': '해당 지자체인 경상북도에서는 도지사가 국토교통부 장관이 수립하는 녹색건축물 기본계획에 따라 5년마다 녹색건축물 조성계획을 수립·시행하도록 제6조에 규정하고 있습니다.', 'legal_reference': '제6조(녹색건축물 조성계획의 수립 등) ①', 'reasoning': '조례 제6조는 도지사의 역할과 계획 수립 주기를 명시하고 있어, 이를 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '‘녹색건축물’이라는 용어는 어떤 법령의 어느 조항에 따라 정의되나요?', 'answer': '해당 지자체인 경상북도에서는 이 조례 제2조 제1호에 따라 ‘녹색건축물’이란 「녹색건축물 조성 지원법」 제2조 제1호에 따른 건축물을 의미합니다.', 'legal_reference': '제2조(정의) 1.', 'reasoning': '조례 자체에서 용어 정의에 다른 법령을 직접 인용하고 있으므로, 해당 법령과 조항을 명시하여 답변을 제공했습니다.', 'link_reference': '녹색건축물 조성 지원법 제2조제1호'}, {'type': 'cross', 'question': '도지사는 건축물의 에너지 소비 총량을 어떻게 관리할 수 있나요?', 'answer': '해당 지자체인 경상북도에서는 도지사가 「녹색건축물 조성 지원법」 제11조 및 그 시행령 제8조에 따라 건축물의 에너지 소비 총량을 설정하고 관리할 수 있다고 제8조 제1항에 규정하고 있습니다.', 'legal_reference': '제8조(건축물의 에너지 소비 총량관리 등) ①', 'reasoning': '조례 제8조는 도지사의 권한을 구체적으로 명시하고 있으며, 해당 권한은 법 제11조와 시행령 제8조에 근거하고 있기에 이를 함께 제시했습니다.', 'link_reference': '녹색건축물 조성 지원법 제11조, 녹색건축물 조성 지원법 시행령 제8조'}]
# [{'type': 'intra', 'question': '주민공동이용시설에는 어떤 종류의 시설이 포함되나요?', 'answer': '경상북도 상수원보호구역 내에서 주민공동이용시설에 해당하는 시설은 도서관, 어린이집, 주민운동장, 주민자치센터, 소규모 공동목욕장(비영업용), 도지사 및 시장·군수가 지역특산물로 인정하여 공고한 지역특산물 판매장(법정 리·동 단위 지역별 1개의 200㎡ 이하), 액화석유가스(LPG) 소형저장탱크(저장능력 3톤 미만), 그리고 주민복지회관(법정 리·동 단위 지역별 1개소로 연면적 1,000㎡ 이하, 단 음식물 조리 및 제공시설을 설치할 경우 연면적 100㎡ 이하) 입니다.', 'legal_reference': '제4조(허가 대상 건축물 등)②', 'reasoning': '조례 제4조 제2항에 주민공동이용시설에 해당하는 구체적인 시설 목록이 명시되어 있기 때문에 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '이 조례는 어느 지역에 적용되나요?', 'answer': '경상북도 상수원보호구역에만 적용됩니다. 즉, 경상북도 내에서 상수원보호구역으로 지정·공고된 지역에 한해 이 조례의 규정이 적용됩니다.', 'legal_reference': '제3조(적용범위)', 'reasoning': '조례 제3조에서 적용 범위가 ‘경상북도 내 상수원보호구역’이라고 명시하고 있으므로, 해당 조항을 근거로 답변을 작성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '수도법 제7조제1항 및 제2항에서 말하는 ‘상수원보호구역’은 무엇을 의미하나요?', 'answer': '해당 지자체인 경상북도에서는, 수도법 제7조제1항 및 제2항에 따라 지정·공고된 구역을 ‘상수원보호구역’이라 정의합니다. 즉, 물 공급의 안전과 위생을 확보하기 위해 법령에 의해 보호되는 지역을 의미합니다.', 'legal_reference': '제2조(정의) 1', 'reasoning': '조례 제2조 1항에서 ‘상수원보호구역’의 정의를 ‘수도법 제7조제1항 및 제2항에 따라 지정·공고된 구역’이라고 규정하고 있어, 해당 법령 조항의 의미를 설명하기 위해 이 조항을 근거로 삼았습니다.', 'link_reference': '수도법 제7조제1항 및 제2항'}, {'type': 'cross', 'question': '상수원관리규칙 제12조제3호에서 규정하는 ‘소득기반시설’은 무엇인가요?', 'answer': '경상북도 상수원보호구역에서 농림업 등에 종사하는 자가 건축하거나 설치하는 시설을 ‘소득기반시설’이라 합니다. 구체적으로는 농림업용 취수시설, 연면적 100㎡ 이하(환경정비구역은 200㎡ 이하)의 지역특산물 체험·실습 시설(오·폐수발생 시설 제외), 그리고 버섯 재배 후 분말 가공을 위한 1가구당 66㎡ 이하의 건조·단순 파쇄시설(오·폐수발생 시설 제외) 등이 포함됩니다.', 'legal_reference': '제2조(정의) 2', 'reasoning': '조례 제2조 2항에서 ‘소득기반시설’의 의미를 ‘상수원관리규칙 제12조제3호에 따라 상수원보호구역에서 농림업 등에 종사하는 자가 건축하거나 설치하는 시설’이라고 정의하고, 제4조 제1항에서 구체적인 예시를 제시하고 있기 때문에 이를 근거로 답변을 구성했습니다.', 'link_reference': '상수원관리규칙 제12조제3호'}]
# [{'type': 'intra', 'question': '경상북도에서 건축자산 기초조사를 실시할 때 도지사가 서면으로 통보해야 하는 내용은 무엇인가요?', 'answer': '해당 지자체인 경상북도는 건축자산 기초조사를 위해 서면으로 다음 5가지 사항을 통보해야 합니다: 1) 제출요청 사유, 2) 제출기한, 3) 제출 방식 및 형태, 4) 제출 자료 내용, 5) 제출 자료의 활용계획.', 'legal_reference': '제4조 제1항', 'reasoning': '문서의 제4조 제1항에 도지사가 건축자산 기초조사 시 서면 통보해야 할 사항을 구체적으로 열거하고 있기 때문에 해당 조항을 근거로 답변을 도출했습니다.', 'link_reference': ''}, {'type': 'intra', 'question': '우수건축자산에 대한 보조금 지원결정이 취소되는 경우는 어떤 경우인가요?', 'answer': '해당 지자체인 경상북도에서는 우수건축자산에 대한 보조금 지원결정이 다음 두 경우에 취소될 수 있습니다: 1) 보조금 지원결정 통지를 받은 날부터 6개월 이내에 공사를 착수하지 않은 경우, 2) 부득이한 사유 등으로 인해 공사를 계속할 수 없는 경우.', 'legal_reference': '제7조 제1항', 'reasoning': '제7조 제1항에 보조금 지원결정 취소 사유가 두 가지로 명시되어 있어, 이를 근거로 답변을 구성했습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '한옥 등 건축자산의 진흥에 관한 법률 제12조 제2항에 따르면 도지사가 어떤 지원을 할 수 있나요?', 'answer': '이 문서에서 언급된 한옥 등 건축자산의 진흥에 관한 법률 제12조 제2항에 따르면, 도지사는 우수건축자산의 관리에 필요한 기술이나 소요비용을 지원할 수 있습니다. 따라서 해당 지자체인 경상북도는 우수건축자산의 관리에 필요한 기술자문, 국내외 지식·정보 제공, 그리고 필요하다고 인정되는 기타 기술지원을 제공할 수 있습니다.', 'legal_reference': '제6조 제1항', 'reasoning': '제6조 제1항에서 도지사는 법 제12조 제2항에 따라 지원할 수 있다고 명시하고 있어, 해당 법 조항의 의미를 해석하여 답변을 도출했습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률'}, {'type': 'cross', 'question': '한옥 등 건축자산의 진흥에 관한 법률 시행령 제7조 제6항에 따라 발급받은 우수 건축자산 등록증 사본은 어떤 용도로 사용되나요?', 'answer': '이 문서에서 언급된 한옥 등 건축자산의 진흥에 관한 법률 시행령 제7조 제6항에 따라 발급받은 우수 건축자산 등록증 사본은 특례적용계획서에 포함되어야 하는 사항으로, 해당 지자체인 경상북도는 이를 특례 적용계획서에 첨부하여 우수 건축자산의 주요 가치 유지 방안을 마련하는 데 사용합니다.', 'legal_reference': '제8조 제1항', 'reasoning': '제8조 제1항은 특례적용계획서에 포함될 사항으로 영 제7조제6항에 따라 발급받은 우수 건축자산 등록증 사본을 명시하고 있어, 해당 조항을 근거로 답변을 구성했습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률 시행령'}]
# [{'type': 'intra', 'question': '우수건축자산의 관리비용 지원을 신청한 후, 지원결정 통지를 받기 전에 공사를 착수하면 안 되는 이유와 착수 신고를 해야 하는 시점은 언제인가요?', 'answer': '해당 지자체인 경상북도에서는 지원결정 통지를 받기 전에 공사를 착수하면 안 됩니다. 지원결정 통지를 받은 경우에만, 공사 착수 5일 전에 별지 제2호서식의 한옥수선 등의 착수 신고서를 도지사에게 제출해야 합니다.', 'legal_reference': '제7조 제1항, 제2항', 'reasoning': '제7조 제1항에 ‘지원결정 통지를 받기 전에 공사를 착수 하여서는 아니 된다’고 명시하고 있으며, 제2항에 ‘지원 결정 통지를 받은 경우에는 공사에 착수하기 5일 전에 착수 신고서를 제출해야 한다’고 규정하고 있기 때문에 위와 같은 절차와 시점이 요구됩니다.', 'link_reference': ''}, {'type': 'intra', 'question': '도지사는 한옥수선 등의 공사가 별표 1의 기준에 적합한지 확인하기 위해 어떤 조치를 할 수 있나요?', 'answer': '해당 지자체인 경상북도 도지사는 한옥수선 등의 공사가 별표 1의 기준에 적합한지 확인하기 위해 현장조사를 실시할 수 있으며, 필요에 따라 지원 대상자 또는 시공자에게 지도와 조언을 할 수 있습니다.', 'legal_reference': '제7조 제3항, 제4항', 'reasoning': '제7조 제3항은 ‘현장조사 등을 실시할 수 있다’고 규정하고, 제4항은 ‘필요한 경우 지도와 조언을 할 수 있다’고 명시하고 있어 도지사의 권한을 확인할 수 있습니다.', 'link_reference': ''}, {'type': 'cross', 'question': '한옥 건축 지원을 받기 위해서는 법 제25조에 따라 어떤 요건을 충족해야 하나요?', 'answer': '해당 지자체인 경상북도에서 한옥 건축 지원을 받으려면, 한옥 등 건축자산의 진흥에 관한 법률 제25조에 따라 ‘한옥건축 및 한옥마을 조성계획서 접수일 이전에 도내에 주민등록을 두면서 실제 거주하고 있는 자’이어야 합니다.', 'legal_reference': '한옥 등 건축자산의 진흥에 관한 법률 제25조', 'reasoning': '제4조 제1항에서 지원 대상자를 ‘법 제25조에 의한 한옥건축 및 한옥마을 조성계획서 접수일 이전에 도내에 주민등록을 두면서 실제 거주하고 있는 자’로 한정하고 있으므로, 해당 법률 조항의 요건이 지원 자격의 근거가 됩니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률 제25조'}, {'type': 'cross', 'question': '한옥수선 등의 착수 신고서를 제출할 때 필요한 서류는 어느 시행령에 규정되어 있나요?', 'answer': '해당 지자체인 경상북도에서는 한옥수선 등의 착수 신고서를 제출할 때 필요한 서류가 한옥 등 건축자산의 진흥에 관한 법률 시행령 제18조에 규정되어 있습니다.', 'legal_reference': '한옥 등 건축자산의 진흥에 관한 법률 시행령 제18조', 'reasoning': '제5조에서 ‘법 제25조 및 한옥 등 건축자산의 진흥에 관한 법률 시행령 제18조에서 정한 서류’를 갖추어 도지사에게 제출하도록 규정하고 있으므로, 착수 신고에 필요한 서류는 해당 시행령에 명시되어 있습니다.', 'link_reference': '한옥 등 건축자산의 진흥에 관한 법률 시행령 제18조'}]

# %%
# 최종 JSON 파일 저장
with open("law_qa_dataset_100.json", "w", encoding="utf-8") as f:
    json.dump(output, f, ensure_ascii=False, indent=2)

print(f"✅ 총 {len(output)}개 항목 저장 완료: law_qa_dataset.json")
# Out:
# ✅ 총 400개 항목 저장 완료: law_qa_dataset.json

# %%
output
# Out:
# [{'type': 'intra',
#   'question': '가평군에서 건축물관리자는 눈이 그친 후 언제까지 제설·제빙 작업을 완료해야 하나요?',
#   'answer': '해당 지자체인 가평군에서는 건축물관리자가 눈이 그친 때부터 3시간 이내에 제설·제빙 작업을 완료해야 합니다. 다만, 야간(일몰 후부터 다음 날 일출 전까지)에 눈이 내린 경우에는 다음 날 오전 11시까지 완료하도록 규정하고 있습니다.',
#   'legal_reference': '제6조(제설ㆍ제빙작업의 시기)',
#   'reasoning': '조례 제6조에 눈이 그친 시점부터 3시간 이내, 야간에는 다음 날 오전 11시까지 완료하도록 명시되어 있기 때문에 해당 조항을 근거로 답변을 도출했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'intra',
#   'question': '가평군에서 건축물 소유자가 건물에 거주하고 있을 때 제설·제빙 책임 순서는 어떻게 되나요?',
#   'answer': '해당 지자체인 가평군에서는 소유자가 건축물 내에 거주하는 경우, 제설·제빙 책임 순서는 소유자 → 점유자 → 관리자 순으로 정해져 있습니다.',
#   'legal_reference': '제4조(제설ㆍ제빙작업의 책임순위) 1호',
#   'reasoning': '조례 제4조 1호에 ‘소유자가 건축물 내에 거주하는 경우에는 소유자, 점유자 또는 관리자 순으로 한다’고 명시되어 있어, 이를 근거로 답변을 작성했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'intra',
#   'question': '가평군 건축물관리자가 담당해야 하는 제설·제빙 작업의 구체적인 범위는 무엇인가요?',
#   'answer': '해당 지자체인 가평군에서는 건축물관리자가 담당해야 하는 제설·제빙 작업의 범위는 다음과 같습니다. ① 보도는 건축물 대지에 접한 보도의 전체 구간, ② 이면도로 및 보행자전용도로는 건축물 대지에 접한 도로의 중앙선 또는 중앙부분까지, ③ 시설물의 지붕은 최상층 지붕면(옥탑층이 있을 경우 옥탑층 포함) 및 복합 지붕이 형성된 경우 모든 지붕 구간입니다.',
#   'legal_reference': '제5조(제설ㆍ제빙작업의 책임범위)',
#   'reasoning': '조례 제5조에 보도, 이면도로·보행자전용도로, 시설물의 지붕에 대한 책임 범위가 각각 구체적으로 규정되어 있어 이를 근거로 답변을 도출했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'cross',
#   'question': '가평군 조례에서 정의하고 있는 ‘도로’는 도로법에 따라 어떻게 정의되나요?',
#   'answer': '이 문서에서 언급된 도로법 제정에 따르면, ‘도로’는 도로법에 따른 도로와 그 밖에 일반 교통에 사용되는 모든 장소를 의미합니다. 따라서 가평군 조례에서 ‘도로’는 도로법이 규정한 도로와 일반 교통에 이용되는 모든 구역을 포괄합니다.',
#   'legal_reference': '제2조(정의) 1호',
#   'reasoning': '조례 제2조 1호에서 ‘도로’는 도로법에 따른 도로와 일반 교통에 사용되는 모든 곳이라고 정의하고 있으므로, 도로법의 정의를 인용해 답변을 구성했습니다.',
#   'link_reference': '도로법',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'cross',
#   'question': '가평군 조례에서 ‘시설물의 지붕’이라고 정의한 내용은 어떤 시행령 조항을 근거로 하고 있나요?',
#   'answer': '이 문서에서 언급된 자연재해대책법 시행령 제22조의8에 따르면, ‘시설물의 지붕’은 해당 시행령이 규정한 시설물의 지붕을 의미합니다. 따라서 가평군 조례의 ‘시설물의 지붕’ 정의는 자연재해대책법 시행령 제22조의8을 근거로 하고 있습니다.',
#   'legal_reference': '제2조(정의) 8호',
#   'reasoning': '조례 제2조 8호에서 ‘시설물의 지붕’은 자연재해대책법 시행령 제22조의8에 따른다고 명시하고 있어, 해당 시행령 조항을 근거로 답변을 작성했습니다.',
#   'link_reference': '자연재해대책법 시행령 제22조의8',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'cross',
#   'question': '가평군 조례에서 ‘이면도로’의 정의에 포함되지 않는 도로는 어떤 법령에 의해 규정되나요?',
#   'answer': '이 문서에서 언급된 농어촌도로정비법에 따라, 고속국도, 일반국도, 지방도, 군도 및 농어촌도로(농어촌도로정비법에 따른 도로) 등은 ‘이면도로’에 포함되지 않습니다. 따라서 가평군 조례의 ‘이면도로’ 정의는 농어촌도로정비법이 규정하는 도로들을 제외한 일반 교통에 사용되는 차도와 보도의 구분이 없는 폭 12미터 미만의 도로를 의미합니다.',
#   'legal_reference': '제2조(정의) 4호',
#   'reasoning': '조례 제2조 4호에서 ‘이면도로’는 도로법에 따른 고속국도·일반국도·지방도·군도·농어촌도로(농어촌도로정비법에 따른 도로) 등을 제외한 도로라고 정의하고 있어, 해당 법령(농어촌도로정비법)을 근거로 답변을 도출했습니다.',
#   'link_reference': '농어촌도로정비법',
#   '자치법규ID': '2019610',
#   '자치법규명': '가평군 건축물관리자의 제설 및 제빙 책임에 관한 조례'},
#  {'type': 'intra',
#   'question': '가평군 내에서 정기점검 대상이 되는 건축물은 어떤 기준을 만족해야 하나요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 건축물관리법 시행령 제8조제1항제1호에서 ‘조례로 정하는 건축물’이라 정의된 바와 같이, 다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목, 제2호, 제3호, 제4호, 제6호, 제7호, 제7의2호, 제7의5호의 용도로 사용되는 바닥면적의 합계가 1천 제곱미터 이상인 건축물을 정기점검 대상에 포함합니다.',
#   'legal_reference': '제4조(정기점검 대상)',
#   'reasoning': '제4조에 정기점검 대상 건축물의 정의와 적용 기준이 명시되어 있어, 해당 조문을 근거로 답변을 도출했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'},
#  {'type': 'intra',
#   'question': '가평군에서 긴급 점검이 시행되는 경우는 어떤 상황인가요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 구조적 손상 등으로 건축물의 안전이 의심되는 경우, 가평군 건축 조례 제10조의2에 따른 가평군 건축위원회 구조전문위원회의 자문 결과 점검이 필요하다고 인정될 때 긴급 점검을 시행합니다.',
#   'legal_reference': '제5조(긴급 점검)',
#   'reasoning': '제5조에서 ‘조례로 정하는 경우’의 정의와 긴급 점검 시행 조건을 직접 제시하고 있기 때문에, 이를 근거로 답변을 구성했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'},
#  {'type': 'intra',
#   'question': '가평군이 건축물관리점검기관을 지정할 때 제외되는 경우는 무엇인가요?',
#   'answer': '해당 지자체인 경기도 가평군에서는 다음 각 호에 해당하는 경우 건축물관리점검기관으로 지정할 수 없습니다: 1) 건축법·건축사법·건설기술 진흥법 등 관련 법령에 따른 업무정지·휴업 중인 경우, 2) 특별한 사유 없이 2회 이상 지정을 거부한 경우, 3) 건축사사무소를 폐업하거나 건축사 자격을 반납한 경우, 4) 건설기술용역사업자의 등록이 취소된 경우, 5) 제3항제1호 각 목의 사유로 업무 수행이 어려워 지정 제외를 요청한 경우, 6) 계약 대가 이외의 금품을 요구·수수한 경우.',
#   'legal_reference': '제8조(건축물관리점검기관의 지정 등)①',
#   'reasoning': '제8조 제1항에 점검기관 지정 제외 사유가 상세히 열거되어 있어, 이를 그대로 인용해 답변을 작성했습니다.',
#   'link_reference': '',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'},
#  {'type': 'cross',
#   'question': '‘다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목’은 어떤 용도를 의미하나요?',
#   'answer': '이 문서에서 언급된 다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목은 ‘다중이용업소’ 중 ‘나목’에 해당하는 용도를 의미합니다. 구체적인 내용은 해당 시행령을 확인해야 합니다.',
#   'legal_reference': '제4조(정기점검 대상) – ‘다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목’ 언급',
#   'reasoning': '조례는 해당 시행령 조항을 인용하고 있으나, 조항의 구체적 의미는 별도의 법령 텍스트에 의존하므로 외부 참조가 필요합니다.',
#   'link_reference': '다중이용업소의 안전관리에 관한 특별법 시행령 제2조제1호나목',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'},
#  {'type': 'cross',
#   'question': '‘건축물관리법 시행령 제8조제1항제1호’에 규정된 ‘조례로 정하는 건축물’의 의미는 무엇인가요?',
#   'answer': '이 문서에서 언급된 건축물관리법 시행령 제8조제1항제1호는 ‘조례로 정하는 건축물’이란 다중이용업소의 안전관리에 관한 특별법 시행령에 따라 특정 용도로 사용되는 바닥면적 합계가 1천 제곱미터 이상인 건축물을 의미한다고 규정하고 있습니다. 정확한 정의는 해당 시행령을 직접 확인해야 합니다.',
#   'legal_reference': '제4조(정기점검 대상) – ‘건축물관리법 시행령 제8조제1항제1호’ 인용',
#   'reasoning': '조례는 시행령 조항을 인용하고 있으나, 그 조항의 상세 내용은 시행령 자체에 명시되어 있어 외부 법령을 참조해야 합니다.',
#   'link_reference': '건축물관리법 시행령 제8조제1항제1호',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'},
#  {'type': 'cross',
#   'question': '‘건축물관리법 시행령 제21조제1항제3호’가 의미하는 ‘조례로 정하는 건축물’은 어떤 경우에 해당하나요?',
#   'answer': '이 문서에서 언급된 건축물관리법 시행령 제21조제1항제3호는 ‘조례로 정하는 건축물’이란 건축법 제20조에 따른 축조신고 대상 가설건축물 중 견본주택이거나, 도시 및 주거환경정비법 제2조에 따른 주거환경개선사업·재개발사업을 위한 정비구역 내 건축물(단, 정비구역 외곽경계 도로에 접한 대지에 건축된 건축물은 제외)인 경우를 말합니다. 자세한 내용은 해당 시행령을 확인하시기 바랍니다.',
#   'legal_reference': '제9조(건축물 해체의 신고) – ‘영 제21조제1항제3호’ 언급',
#   'reasoning': '조례는 시행령 제21조제1항제3호를 인용하고 있으나, 그 구체적 정의는 시행령에 포함되어 있어 외부 법령을 참조해야 합니다.',
#   'link_reference': '건축물관리법 시행령 제21조제1항제3호',
#   '자치법규ID': '2205553',
#   '자치법규명': '가평군 건축물관리 조례'}]

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_community.chat_message_histories import ChatMessageHistory
from langchain_core.chat_history import BaseChatMessageHistory
from langchain_core.runnables.history import RunnableWithMessageHistory
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import JsonOutputParser

# 프롬프트 정의
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            system_message,
        ),
        # 대화기록용 key 인 chat_history 는 가급적 변경 없이 사용하세요!
        # MessagesPlaceholder(variable_name="chat_history"),
        ("human", "#Question:\n{question}"),  # 사용자 입력을 변수로 사용
    ]
)

# llm 생성
# llm = ChatOpenAI()

llm = ChatClovaX(
    model="HCX-005",
    temperature=0.3,
    max_tokens = 1024,
    timeout=None,
    max_retries=2,
    reasoning = None,
)

# 일반 Chain 생성
chain = prompt | llm | JsonOutputParser()
chain
# Out:
# ChatPromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, messages=[SystemMessagePromptTemplate(prompt=PromptTemplate(input_variables=[], input_types={}, partial_variables={}, template='당신은 법률 문서로부터 질의응답 데이터를 생성하는 전문가입니다.\n제공된 문서의 내용을 분석하고, 사용자가 실제로 질문할 수 있는 질의(Q)와 그에 대응하는 근거 기반의 답변(A)을 생성하세요.\n\n# Question Guidelines:\n질문은 두 가지 타입으로 분류할 수 있습니다.\n\n1. 문서 내부 기반(Intra)\n- 오직 해당 문서(chunk) 내에서 답을 찾을 수 있어야 한다.\n- 질문 예시: 용어 정의, 의무 주체, 책임 순서, 시기, 방법 등\n- 답변은 반드시 해당 문서 내용에 근거해야 하며, 다른 법령 인용 금지.\n\n2. 외부 참조 기반 (Cross-document)\n- chunk 안에 다른 법률이나 시행령, 규칙이 언급된 경우 그 조항을 참조해야 완전한 답변이 나올 질문을 생성한다.\n- 질문은 사용자가 ‘그 조항의 의미’를 묻는 형태로 만든다.\n- 답변은 “이 문서에서 언급된 ○○법 제○조제○항에 따르면…”처럼 근거를 병기한다.\n- `link_reference` 필드에 해당 법령명을 명시한다.\n\n# Answer Guidelines:\n- 제공된 문서에는 자치법규명, 지자체기관명이 명시되어있습니다. 반드시 해당 지자체에 대한 답변임을 명시하세요. 예) 서울특별시 종로구의 경우, ...\n- 제공된 문서의 내용을 기반으로 구체적으로 작성하세요.\n\n# Output 형식:\n- `type`: "intra", "cross"\n- `question`: Question Guidelines을 따른 사용자의 법률적 질문\n- `answer`: Answer Guidelines을 따른 답변\n- `legal_reference`: 답변에 직접적으로 근거한 조항 번호 또는 문장\n- `reasoning`: 왜 이 답변이 도출되었는지 설명\n- `link_reference`: 문서 내 link된 다른 법령 조항\n\n# 주의:\n- 반드시 **유효한 JSON 형식**으로 반환합니다.\n- 해당하는 내용이 없다면, 빈 값으로 반환하세요. 예) "link_reference": ""\n'), additional_kwargs={}), HumanMessagePromptTemplate(prompt=PromptTemplate(input_variables=['question'], input_types={}, partial_variables={}, template='#Question:\n{question}'), additional_kwargs={})])
# | ChatClovaX(client=<openai.resources.chat.completions.completions.Completions object at 0x11adb71c0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11adb74f0>, root_client=<openai.OpenAI object at 0x11adb7be0>, root_async_client=<openai.AsyncOpenAI object at 0x11adb77c0>, temperature=0.3, model_kwargs={}, max_retries=2, max_tokens=1024, extra_body={}, api_key=SecretStr('**********'), naver_api_base='https://clovastudio.stream.ntruss.com/v1/openai')
# | JsonOutputParser()

# %%
output = chain.invoke({"question": content})
output
# Out:
# {'type': 'intra',
#  'question': '건축물관리자가 제설·제빙 작업을 해야 하는 대상 지역은 어디인가?',
#  'answer': '건축물관리자는 관리하고 있는 건축물의 대지에 접한 보도, 이면도로, 보행자전용도로, 시설물의 지붕에 대해 제설·제빙 작업을 해야 합니다.',
#  'legal_reference': '제3조(건축물관리자의 제설·제빙 책임)',
#  'reasoning': '조례 제3조에 명확히 규정되어 있으며, 이는 건축물관리자의 구체적인 책임을 나타내고 있습니다.'}
